# %% [markdown]
# ![DHlab_logo_web_no_red.png](attachment:DHlab_logo_web_no_red.png)

# %% [markdown]
# Her vil jeg etablere et Skramkorpus og gjøre ting med det. Jeg vil i første omgang lage korpus og deretter hente ut stedsnavn. Til dette prøver jeg å kombinere Notebooks for korpusbygging og "Navnegrafer".

# %%
import dhlab.nbtext as nb
from dhlab.module_update import css
# %matplotlib inline
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
from dhlab.module_update import update, css
import dhlab.nbtext as nb
from dhlab.nbtext import get_urn, make_graph, get_urn, relaterte_ord, navn, totals
import dhlab.graph_networkx_louvain as gnl
import dhlab.token_map as tm
# %matplotlib inline

plot = lambda x,  lw=3, alpha= 0.7: x.plot(figsize=(15,6), lw=lw, alpha=alpha)

# %%
import warnings
warnings.filterwarnings('ignore')

css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ## Bygger et korpus fra bokhyllasøk

# %% [markdown]
# ### 1.5. Ta vare på eller rediger korpuset i excel

# %% [markdown]
# ## 1.7 Hent frem igjen korpuset for å gjøre operasjoner på det

# %%
skram_korpus_sv = nb.restore_metadata_from_excel('skram_korpus_sv.xls')
skram_korpus_sv
# Out:
#              urn      forfatter    år            tittel  subtittel  forlag  \
# 0  2008012904020  Skram, Amalie  1993  Samlede verker 1        NaN     NaN
# 1  2008011000051  Skram, Amalie  1993  Samlede verker 2        NaN     NaN
# 2  2008010900076  Skram, Amalie  1993  Samlede verker 3        NaN     NaN
# 3  2008012801071  Skram, Amalie  1993  Samlede verker 4        NaN     NaN
# 4  2008012801072  Skram, Amalie  1993  Samlede verker 5        NaN     NaN
# 5  2008012804059  Skram, Amalie  1993  Samlede verker 6        NaN     NaN
# 6  2008012804063  Skram, Amalie  1993  Samlede verker 7        NaN     NaN
#
#     x  x.1  lang  trans
# 0 NaN  NaN   NaN    NaN
# 1 NaN  NaN   NaN    NaN
# 2 NaN  NaN   NaN    NaN
# 3 NaN  NaN   NaN    NaN
# 4 NaN  NaN   NaN    NaN
# 5 NaN  NaN   NaN    NaN
# 6 NaN  NaN   NaN    NaN

# %% [markdown]
# Sjekker nb.names mot urn i korpuset

# %%
wp = nb.names(2008012801071)
wp
# Out:
# (Counter({'Achmet': 3,
#           'Aksel': 4,
#           'Aldeles': 8,
#           'Amalie': 13,
#           'André': 3,
#           'Anita': 26,
#           'Annen': 4,
#           'Annie': 30,
#           'Antigoni': 4,
#           'Anton': 3,
#           'Arbo': 5,
#           'Arendal': 4,
#           'Arne': 31,
#           'Arthur': 36,
#           'Asovske': 14,
#           'Atter': 7,
#           'Augusts': 3,
#           'Averding': 63,
#           'Be': 5,
#           'Bibelen': 3,
#           'Birgit': 141,
#           'Birgits': 9,
#           'Blir': 4,
#           'Bosporus': 8,
#           'Brandt': 33,
#           'Bønn': 52,
#           'Carsten': 22,
#           'De': 560,
#           'Dem': 178,
#           'Dere': 19,
#           'Deres': 70,
#           'Di': 14,
#           'Drammensveien': 7,
#           'Eder': 10,
#           'Eders': 8,
#           'Eia': 5,
#           'Einar': 28,
#           'Elise': 4,
#           'England': 6,
#           'Enhver': 3,
#           'Enn': 13,
#           'Er': 73,
#           'Estrid': 21,
#           'Fadervår': 5,
#           'Falsen': 15,
#           'Fan': 4,
#           'Flemming': 242,
#           'Flemming.': 4,
#           'Flemmings': 19,
#           'Fra': 98,
#           'Fredrik': 24,
#           'Frelseren': 3,
#           'Fånar': 3,
#           'Første': 5,
#           'Galata': 4,
#           'Galatabroen': 3,
#           'Gamborg': 50,
#           'Gaustad': 8,
#           'Gerner': 170,
#           'Gerners': 7,
#           'Gid': 7,
#           'Gjør': 4,
#           'God': 27,
#           'Grønn': 9,
#           'Gud': 155,
#           'Gude': 6,
#           'Guds': 17,
#           'Gå': 19,
#           'Går': 5,
#           'Halvorsen': 3,
#           'Har': 42,
#           'Henny': 111,
#           'Hennys': 6,
#           'Herregud': 11,
#           'Herren': 9,
#           'Herrens': 5,
#           'Hold': 12,
#           'Holm': 69,
#           'Holms': 8,
#           'Hondurasfloden': 13,
#           'Hr.': 4,
#           'Husk': 10,
#           'Hva': 20,
#           'Hvem': 13,
#           'Hysj': 4,
#           'Hyss': 10,
#           'Hør': 8,
#           'Incognitogaten': 4,
#           'Ines': 539,
#           'Inger': 7,
#           'Ja': 403,
#           'Jamen': 7,
#           'Jean': 4,
#           'Jesu': 3,
#           'Jesus': 7,
#           'Jo': 70,
#           'Johan': 3,
#           'Johanne': 108,
#           'Johannes': 7,
#           'Jørgen': 56,
#           'Jørgens': 7,
#           'Karen': 55,
#           'Karl': 8,
#           'Knut': 299,
#           'Knuts': 8,
#           'Kom': 35,
#           'Kommer': 12,
#           'Konrad': 9,
#           'Konstantinopel': 15,
#           'Konstantinopels': 3,
#           'Kragerø': 4,
#           'Kristiania': 5,
#           'Kristus': 3,
#           'La': 33,
#           'Lina': 3,
#           'Lise': 37,
#           'Lises': 4,
#           'Lizzi': 4,
#           'London': 5,
#           'Lucie': 519,
#           'Luciebarne': 12,
#           'Lucies': 32,
#           'Lucy': 22,
#           'Lucys': 4,
#           'Lund': 7,
#           'Lussia': 7,
#           'Madame': 11,
#           'Magnus': 35,
#           'Maikaland': 25,
#           'Malmøen': 6,
#           'Mamma': 11,
#           'Maren': 33,
#           'Margrethe': 56,
#           'Martha': 7,
#           'Martine': 16,
#           'Mon': 3,
#           'Mot': 4,
#           'Mrs': 10,
#           'Mørk': 50,
#           'Mørks': 9,
#           'Narr': 3,
#           'Naturligvis': 11,
#           'Nei': 244,
#           'Nikola': 4,
#           'Nille': 11,
#           'Nilsa': 17,
#           'Nilsen': 80,
#           'Nilsens': 6,
#           'Noe': 9,
#           'Nå': 57,
#           'Nåda': 3,
#           'Ole': 53,
#           'Olsen': 60,
#           'Opover': 3,
#           'Pappa': 4,
#           'Paris': 6,
#           'Passasjerer': 3,
#           'Pera': 7,
#           'Peragaten': 4,
#           'Persia': 5,
#           'Pet': 4,
#           'Polly': 4,
#           'Prinkipo': 6,
#           'Prinseøene': 4,
#           'Proti': 4,
#           'Rangle': 48,
#           'Rangles': 8,
#           'Reinertson': 106,
#           'Reinertson,': 3,
#           'Reinertson.': 3,
#           'Reinertsons': 9,
#           'Reis': 5,
#           'Rett': 3,
#           'Ribbing': 66,
#           'Ribbings': 8,
#           'Riktig': 5,
#           'Ruder': 44,
#           'Ruders': 4,
#           'Sally': 11,
#           'Sam': 3,
#           'Se': 28,
#           'Severine': 3,
#           'Sigurd': 55,
#           'Sitt': 5,
#           'Skal': 37,
#           'Skram': 13,
#           'Skutari': 5,
#           'Smyrnagate': 5,
#           'Smyrnagaten': 3,
#           'Snakk': 4,
#           'St': 4,
#           'Stakkars': 10,
#           'Stemmen': 6,
#           'Stå': 4,
#           'Sultan': 3,
#           'Sverige': 3,
#           'Synes': 5,
#           'Sæby': 6,
#           'Søte': 6,
#           'Ta': 11,
#           'Takk': 21,
#           'Tal': 4,
#           'Tandberg': 147,
#           'Tandbergs': 3,
#           'Termopylai': 3,
#           'Theodor': 130,
#           'Theodors': 5,
#           'Therapia': 6,
#           'Thomsen': 14,
#           'Tivoli': 6,
#           'Uff': 18,
#           'Undskyld': 4,
#           'Vest': 11,
#           'Vet': 8,
#           'Vil': 39,
#           'Vilde': 7,
#           'Vis': 4,
#           'Vårherre': 14,
#           'Værsgo': 9,
#           'Øvre': 3}),
#  Counter({('Persia', 'Annen'): 1,
#           ('Knut', 'Tandberg'): 74,
#           ('Lucie', 'Nilsen'): 1,
#           ('Theodor', 'Gerner'): 5,
#           ('Lucie', 'Gerner'): 2,
#           ('Aksel', 'Mørks'): 1,
#           ('Theodor', 'Gerners'): 1,
#           ('Karl', 'Johan'): 3,
#           ('Amalie', 'Skram'): 13,
#           ('Lucie', 'Theodor'): 1,
#           ('Vil', 'De'): 13,
#           ('Severine', 'Nilsen'): 3,
#           ('Sitt', 'Di'): 1,
#           ('Hold', 'Dem'): 2,
#           ('Olsen', 'Lucie'): 1,
#           ('Hr.', 'Gerner'): 1,
#           ('Knut', 'Reinertson'): 3,
#           ('Har', 'De'): 7,
#           ('Henny', 'Brandt'): 1,
#           ('Er', 'Fredrik'): 1,
#           ('Er', 'De'): 5,
#           ('Reis', 'Dem'): 1,
#           ('Vet', 'De'): 3,
#           ('Vilde', 'De'): 2,
#           ('Lucie', 'Ja'): 1,
#           ('Stakkars', 'Lucie'): 2,
#           ('La', 'Mørk'): 1,
#           ('Gerner', 'Lucie'): 1,
#           ('Ole', 'Første'): 1,
#           ('Stakkars', 'Jørgen'): 1,
#           ('Opover', 'Hondurasfloden'): 1,
#           ('Rett', 'Dem'): 1,
#           ('Jesus', 'Kristus'): 1,
#           ('Maikaland', 'Anita'): 1,
#           ('Stakkars', 'Sigurd'): 2,
#           ('Holm', 'Magnus'): 1,
#           ('Eders', 'Gud'): 1,
#           ('De', 'Dem'): 5,
#           ('Margrethe', 'Falsen'): 11,
#           ('Hr.', 'Gamborg'): 1,
#           ('De', 'Fredrik'): 1,
#           ('Knut', 'Knut'): 1,
#           ('Tandberg', 'Gamborg'): 1,
#           ('Knut', 'Margrethe'): 2,
#           ('Synes', 'De'): 2,
#           ('Tandberg', 'Birgit'): 1,
#           ('Tandberg', 'Knut'): 1,
#           ('Fra', 'Margrethe'): 1,
#           ('Sultan', 'Achmet'): 3,
#           ('Enn', 'De'): 1,
#           ('Kommer', 'De'): 1,
#           ('Fra', 'Ines'): 90,
#           ('Gå', 'De'): 1,
#           ('Går', 'De'): 1,
#           ('Mot', 'Flemming'): 1,
#           ('Ines', 'Flemming'): 1,
#           ('Flemming.', 'Ines'): 1,
#           ('Kom', 'Averding'): 1,
#           ('Ines', 'Ruder'): 1}),
#  Counter({('Knut', 'Knut', 'Tandberg'): 1,
#           ('Knut', 'Tandberg', 'Gamborg'): 1,
#           ('Knut', 'Tandberg', 'Birgit'): 1,
#           ('Tandberg', 'Knut', 'Tandberg'): 1,
#           ('Fra', 'Ines', 'Flemming'): 1,
#           ('Fra', 'Ines', 'Ruder'): 1}),
#  Counter())

# %% [markdown]
# Tilbake til [DHLAB ved Nasjonalbiblioteket](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/DHLAB_ved_Nasjonalbiblioteket.ipynb)
