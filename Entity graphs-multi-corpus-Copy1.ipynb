# %% [markdown]
# ## Oppstart

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Note that the file `nbtext.py` will be overwritten in the code below
#
# This is probably ok, though. If not, change `update('nbtext', overwrite = True)` to `update('nbtext', overwrite = False)` and the file will stay unchanged.

# %%
update('graph_networkx_louvain', overwrite=True)
update('nbtext', overwrite = True)
update('token_map', overwrite = True)
import nbtext as nb
import token_map as tm
from nbtext import get_urn, make_graph, get_urn, relaterte_ord, navn, totals
import graph_networkx_louvain as gnl
import pandas as pd
# %matplotlib inline

plot = lambda x,  lw=3, alpha= 0.7: x.plot(figsize=(15,6), lw=lw, alpha=alpha)
# Out:
# Updated file `D:\Documents\GitHub\NER\graph_networkx_louvain.py`
# Updated file `D:\Documents\GitHub\NER\nbtext.py`
# Updated file `D:\Documents\GitHub\NER\token_map.py`

# %% [markdown]
# # Hjelpekommandoer
#
# `alle_korpusnavn` henter ut alle navn (eller forslag til) fra korpuset.
# `tell_navn` teller opp navnene på tvers av korpuset

# %%
import pandas as pd

def alle_korpusnavn(korpus):
    urner = list(korpus['urn'])
    alle_navn = tm.combine_names(tm.corpus_names(urner))
    return alle_navn

def tell_navn(korpus, token_map):
    res = dict()
    for urn in korpus['urn']:
        res[urn] = tm.count_name_strings(str(urn), token_map).to_dict()[0]
    return pd.DataFrame(pd.DataFrame(res).sum(axis=1).sort_values(ascending=False))

# %% [markdown]
# ## Navn i bøker
#
#
# Vi søker etter navn i en bok, og en serie av bøker.
#
# Kommandoene er:
# 1. `names` henter et sett med forslag til navn, fra nbtext
# 1. `show_names` gir en oversikt over funnene, fra token_map
# 1. `names_to_token_map_file` lagrer navneforslagene til en excelfil (eller csv) for redigering (token_map)
# 1. `read_token_map_file` henter redigert fil tilbake for analyse (token_map)
# 1. `character_network` lager graf for navnene (token_map)
# 1. `show_graph`  tegner grafen (fra graph_networkx_louvain)
# 1. `show_communities` viser clustre i grafen (graph_networkx_louvain)

# %% [markdown]
# # Eksempel
#
# Henter ut navn fra et korpus. Bøkene slås sammen.
#
# ## Korpus
#
# Bygg først et korpus, enten fra kommando `nb.book_corpus` eller `book_urn`, eller gjenskap fra fil.

# %%
korpus = nb.book_corpus(author='hamsun%')

# %%
#korpus = nb.restore_metadata_from_excel('metadatafil.xls')

# %% [markdown]
# ## Sjekk innholdet
#
# Gjør noen søk for å se at alt er ok. Konkordanser er fine til det. Her går urnene gjennom `nb.pure_urn` -  i fremtiden skal det ikke være nødvendig.

# %%
nb.urn_concordance(word = 'arbeid', urns = nb.pure_urn(korpus))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007061301045?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1956</a>
#                 </td>
#                 <td>åpne for vannet . Storartet</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>for Ingrid og Marta !</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007061301045?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1956</a>
#                 </td>
#                 <td>, men det var trutt</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>og god vilje i det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007061301045?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1956</a>
#                 </td>
#                 <td>så Ola fikk et interessant</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>med å finne ut nye</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021106080?searchText=arbeid' target='_blank' style='text-decoration:none'>Mørk himmel over Puerto Bravo, Hamsun, Tore, 1986</a>
#                 </td>
#                 <td>natten . Man snakket om</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>, og noe ble det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021106080?searchText=arbeid' target='_blank' style='text-decoration:none'>Mørk himmel over Puerto Bravo, Hamsun, Tore, 1986</a>
#                 </td>
#                 <td>Yolanda og de største barna</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>i berenjena-åkrene utenfor landsbyen. Det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021106080?searchText=arbeid' target='_blank' style='text-decoration:none'>Mørk himmel over Puerto Bravo, Hamsun, Tore, 1986</a>
#                 </td>
#                 <td>innblikk i det rent forberedende</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021106080?searchText=arbeid' target='_blank' style='text-decoration:none'>Mørk himmel over Puerto Bravo, Hamsun, Tore, 1986</a>
#                 </td>
#                 <td>mens bygging av barrikader og</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>med provisoriske bunkere og pansergraver</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021106080?searchText=arbeid' target='_blank' style='text-decoration:none'>Mørk himmel over Puerto Bravo, Hamsun, Tore, 1986</a>
#                 </td>
#                 <td>og vi så mennesker i</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>ute på markene . Her</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072400009?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1969</a>
#                 </td>
#                 <td>glatte saker som det intet</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>var med , nei også</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072400009?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1969</a>
#                 </td>
#                 <td>tid på en gård forefallende</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>. Svar pr. omgående .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072400009?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1969</a>
#                 </td>
#                 <td>V % mann til samme</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>? For til tross for</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072400009?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1969</a>
#                 </td>
#                 <td>neste dag var Henry i</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>sammen med Einar . Det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072400009?searchText=arbeid' target='_blank' style='text-decoration:none'>Bygdebarn, Hamsun, Marie, 1969</a>
#                 </td>
#                 <td>i sterkt</td>
#                 <td>arbeid</td>
#                 <td style='text-align:left'>med å renske ut røtter</td>
#             </tr>
# </table>

# %% [markdown]
# ## Navn
#
# Finn forslag til navn med `names`. Se på dem med `show_names`. Her er det muligheter til å skru litt på parametrene. Hvis ratioen skrus ned fjernes en del ord, og om cutoff settes høyere vil også enkelte navneforslag kunne forsvinne.

# %% [markdown]
# Velg hvilken bok som skal studeres (alle kan tas, men se under). Se på listen over korpus og sett den indeksen som passer. Her er det bare å føle seg frem.

# %%
korpus
# Out:
#               urn         author                          title  year
# 0   2011011005071   Hamsun, Knut                 Samlede Verker  1934
# 1   2014051508038   Hamsun, Knut                   Segelfoss by  1962
# 2   2011081905049   Hamsun, Knut                 Ringen sluttet  2004
# 3   2011050405030   Hamsun, Knut                         August  2001
# 4   2007061301045  Hamsun, Marie                      Bygdebarn  1956
# 5   2008102204060   Hamsun, Knut                 Samlede verker  2000
# 6   2014090908064   Hamsun, Knut                 Samlede verker  2007
# 7   2013013008314   Hamsun, Knut                Men livet lever  1968
# 8   2012092606124   Hamsun, Knut                 Samlede verker  1964
# 9   2014021106080   Hamsun, Tore  Mørk himmel over Puerto Bravo  1986
# 10  2006120600021   Hamsun, Knut                 Samlede Verker  1918
# 11  2011050904046   Hamsun, Tore                       Teresita  1959
# 12  2009061013011   Hamsun, Knut                        Bjørger  1878
# 13  2007072400009  Hamsun, Marie                      Bygdebarn  1969
# 14  2012021424027  Hamsun, Marie          Bygdebarn om vinteren  1926
# 15  2013011708144   Hamsun, Knut                 Samlede Verker  1934
# 16  2010112306003  Hamsun, Marie                      Bygdebarn  1932
# 17  2008121001008   Hamsun, Knut                  Markens grøde  2001
# 18  2013072508022   Hamsun, Knut                        Bjørger  1925
# 19  2013030608004   Hamsun, Knut                 Samlede verker  1992

# %% [markdown]
# Finn korpuset ved å sette inn en index tilsvarende den som står helt til venstre i listen over.

# %% [markdown]
# Hent ut navn fra boken

# %%
total_names = alle_korpusnavn(korpus)
# Out:
# Fikk ikke laget navn for: 2006120600021
# Fikk ikke laget navn for: 2012021424027

# %% [markdown]
# # Ta en titt på navneforslagene
#
# Men redigere dem i excel for å se. Navnene er hentet fra hele korpuset.

# %%
total_names
# Out:
# [Counter({'Aar': 197,
#           'Aaret': 13,
#           'Aksel': 588,
#           'Alvor': 26,
#           'Amerika': 236,
#           'Andresen': 95,
#           'Ansigt': 17,
#           'Ansigtet': 25,
#           'Arbeide': 138,
#           'Arbeiderne': 11,
#           'Arbeidet': 41,
#           'Armen': 33,
#           'Aronsen': 183,
#           'Barbro': 491,
#           'Barn': 85,
#           'Barnet': 96,
#           'Begyndelsen': 24,
#           'Bergen': 100,
#           'Bord': 29,
#           'Brede': 410,
#           'Breidablik': 99,
#           'Brev': 61,
#           'Brevet': 35,
#           'Bruk': 42,
#           'Brystet': 28,
#           'Bud': 15,
#           'Buskapen': 25,
#           'By': 26,
#           'Byen': 76,
#           'Bygden': 192,
#           'Bækken': 15,
#           'Bør': 12,
#           'Børn': 101,
#           'Børnene': 99,
#           'Dag': 231,
#           'Dagen': 72,
#           'Dagene': 44,
#           'Dager': 125,
#           'Daler': 84,
#           'Datter': 12,
#           'Direktøren': 16,
#           'Dokker': 931,
#           'Doktoren': 23,
#           'Dyr': 70,
#           'Dyrene': 45,
#           'Død': 12,
#           'Døden': 11,
#           'Dør': 12,
#           'Døren': 50,
#           'Dørhellen': 21,
#           'Eleseus': 614,
#           'Elven': 18,
#           'Familje': 12,
#           'Familjen': 22,
#           'Far': 85,
#           'Farn': 123,
#           'Farvel': 19,
#           'Favnved': 14,
#           'Fjæld': 21,
#           'Fjældet': 111,
#           'Fjøs': 28,
#           'Fjøset': 48,
#           'Foder': 11,
#           'Folk': 265,
#           'Fredrik': 86,
#           'Fremmede': 11,
#           'Fru': 14,
#           'Fruen': 24,
#           'Fuldmægtig': 32,
#           'Fuldmægtigen': 14,
#           'Gaa': 13,
#           'Gaard': 48,
#           'Gaarden': 108,
#           'Gamle': 39,
#           'Gammen': 45,
#           'Gang': 251,
#           'Ganger': 71,
#           'Geissler': 564,
#           'Geisslers': 32,
#           'Gjeiter': 17,
#           'Gjeiterne': 19,
#           'Grund': 30,
#           'Grunden': 45,
#           'Grøde': 328,
#           'Gud': 798,
#           'Guds': 121,
#           'Guldhorn': 41,
#           'Guldring': 41,
#           'Gulvet': 27,
#           'Gustaf': 72,
#           'Gut': 50,
#           'Gutten': 59,
#           'Gutterne': 34,
#           'Haand': 96,
#           'Haanden': 99,
#           'Halsen': 36,
#           'Hamsun': 129,
#           'Handel': 62,
#           'Handelen': 23,
#           'Handelsmand': 28,
#           'Handelsmanden': 27,
#           'Hare': 15,
#           'Herre': 12,
#           'Herregud': 36,
#           'Herrer': 11,
#           'Herrerne': 49,
#           'Hest': 70,
#           'Hesten': 40,
#           'Hester': 14,
#           'Heyerdahl': 41,
#           'Himlen': 28,
#           'Hjem': 44,
#           'Hjemveien': 13,
#           'Hjælp': 47,
#           'Hjærte': 25,
#           'Hode': 36,
#           'Hodet': 176,
#           'Hundrede': 57,
#           'Hus': 84,
#           'Husene': 52,
#           'Huset': 49,
#           'Hvem': 65,
#           'Hænder': 44,
#           'Hænderne': 54,
#           'Høi': 15,
#           'Høiet': 28,
#           'Høst': 16,
#           'Høsten': 20,
#           'Ingeniøren': 46,
#           'Inger': 1369,
#           'Ingers': 34,
#           'Isak': 1514,
#           'Isaks': 40,
#           'Ja': 793,
#           'Jensine': 64,
#           'Jord': 50,
#           'Jorden': 90,
#           'Jordet': 26,
#           'Kaffe': 81,
#           'Kammerset': 15,
#           'Kan': 60,
#           'Kanter': 11,
#           'Kar': 62,
#           'Kirken': 29,
#           'Kjyr': 38,
#           'Kjærre': 14,
#           'Kjærren': 22,
#           'Klokken': 46,
#           'Klær': 23,
#           'Kokka': 12,
#           'Kone': 105,
#           'Konen': 111,
#           'Korn': 15,
#           'Kornet': 16,
#           'Kramboden': 108,
#           'Kroner': 21,
#           'Kræfter': 11,
#           'Ku': 46,
#           'Kua': 27,
#           'Kvindfolk': 45,
#           'Kvindfolkhjælp': 11,
#           'Kvæld': 46,
#           'Kvælden': 20,
#           'Lagmanden': 12,
#           'Lagretten': 13,
#           'Lam': 15,
#           'Lensmand': 39,
#           'Lensmanden': 88,
#           'Lensmandsfruen': 29,
#           'Leopoldine': 94,
#           'Lien': 17,
#           'Linjen': 16,
#           'Liv': 99,
#           'Livet': 94,
#           'Lykke': 39,
#           'Lyst': 24,
#           'Løen': 13,
#           'Maal': 11,
#           'Maaneland': 33,
#           'Maate': 76,
#           'Magt': 13,
#           'Mand': 366,
#           'Manden': 152,
#           'Marken': 171,
#           'Markens': 341,
#           'Maskinen': 15,
#           'Mat': 115,
#           'Maten': 23,
#           'Mening': 48,
#           'Menneske': 75,
#           'Menneskene': 51,
#           'Mennesker': 54,
#           'Middel': 31,
#           'Mil': 11,
#           'Mor': 67,
#           'Morbror': 30,
#           'Morgen': 37,
#           'Morgningen': 54,
#           'Morn': 74,
#           'Mot': 13,
#           'Mund': 32,
#           'Munden': 53,
#           'Muren': 12,
#           'Myr': 13,
#           'Myren': 71,
#           'Myrene': 23,
#           'Mælk': 16,
#           'Mænd': 42,
#           'Naa': 200,
#           'Nat': 73,
#           'Natten': 70,
#           'Navn': 44,
#           'Nei': 420,
#           'Niste': 15,
#           'Nybygg': 19,
#           'Nybygget': 28,
#           'Nød': 13,
#           'Okse': 11,
#           'Oksen': 18,
#           'Oline': 369,
#           'Olsen': 116,
#           'Ord': 168,
#           'Os-Anders': 33,
#           'Papir': 31,
#           'Par': 149,
#           'Pengene': 70,
#           'Penger': 238,
#           'Pike': 60,
#           'Piken': 48,
#           'Piker': 29,
#           'Plass': 38,
#           'Pokker': 38,
#           'Post': 23,
#           'Potet': 14,
#           'Poteten': 33,
#           'Pris': 27,
#           'Raad': 90,
#           'Rebekka': 49,
#           'Regn': 20,
#           'Reise': 16,
#           'Reisen': 36,
#           'Ret': 47,
#           'Ringen': 41,
#           'Ro': 40,
#           'Ryggen': 22,
#           'Sagen': 21,
#           'Sak': 25,
#           'Saken': 64,
#           'Sau': 18,
#           'Sauen': 23,
#           'Sauer': 11,
#           'Sellanraa': 139,
#           'Side': 52,
#           'Siden': 58,
#           'Sind': 22,
#           'Sivert': 557,
#           'Sjøen': 51,
#           'Skjorte': 12,
#           'Skog': 15,
#           'Skogen': 77,
#           'Skogkanten': 11,
#           'Skyld': 73,
#           'Slaamaskine': 12,
#           'Slag': 54,
#           'Slags': 68,
#           'Smaa': 14,
#           'Smaagutterne': 29,
#           'Sne': 13,
#           'Sneen': 30,
#           'Solen': 16,
#           'Som': 24,
#           'Sommer': 125,
#           'Sommeren': 38,
#           'Spor': 25,
#           'Spøk': 32,
#           'Spørsmaal': 39,
#           'Staten': 16,
#           'Statsadvokaten': 14,
#           'Sted': 136,
#           'Steder': 63,
#           'Stedet': 88,
#           'Sten': 62,
#           'Stenen': 34,
#           'Stener': 25,
#           'Stok': 12,
#           'Storborg': 97,
#           'Straf': 15,
#           'Strøm': 76,
#           'Stue': 40,
#           'Stuen': 95,
#           'Stund': 151,
#           'Stykke': 30,
#           'Svar': 48,
#           'Sverige': 44,
#           'Synd': 38,
#           'Søn': 17,
#           'Søndag': 36,
#           'Sønnen': 14,
#           'Tak': 112,
#           'Tale': 36,
#           'Tanke': 33,
#           'Tanker': 31,
#           'Taus': 15,
#           'Telegrafen': 23,
#           'Tid': 277,
#           'Tiden': 128,
#           'Tilstand': 13,
#           'Timer': 32,
#           'Ting': 163,
#           'Tjenestepike': 11,
#           'Tobak': 11,
#           'Trondhjem': 147,
#           'Tunet': 16,
#           'Tur': 42,
#           'Turen': 28,
#           'Tusen': 53,
#           'Uker': 44,
#           'Under': 34,
#           'Vaar': 14,
#           'Vaaren': 28,
#           'Vand': 50,
#           'Varer': 142,
#           'Ved': 24,
#           'Vei': 103,
#           'Veien': 62,
#           'Verden': 105,
#           'Vet': 12,
#           'Vinter': 43,
#           'Vinteren': 51,
#           'Våndet': 21,
#           'Væggen': 11,
#           'Ærend': 35,
#           'Ødemarken': 15,
#           'Øieblik': 74,
#           'Øine': 73,
#           'Øinene': 69,
#           'Øksen': 17,
#           'Anton': 258,
#           'Aslak': 74,
#           'Bertel': 117,
#           'Bua': 394,
#           'Bårdsen': 489,
#           'Clara': 120,
#           'Coldevin': 101,
#           'Daverdana': 118,
#           'De': 2401,
#           'Dem': 973,
#           'Deres': 490,
#           'Didriksen': 108,
#           'Felix': 48,
#           'Flaghaugen': 32,
#           'Florina': 138,
#           'Gottfred': 156,
#           'Holmengrå': 774,
#           'Holmengrås': 115,
#           'Holmsen': 184,
#           'Irgens': 152,
#           'Jensen': 186,
#           'Johan': 151,
#           'Julius': 425,
#           'Konrad': 122,
#           'Kornelius': 48,
#           'Kristiania': 49,
#           'Landmarck': 80,
#           'Lars': 470,
#           'Larsens': 38,
#           'Lassen': 171,
#           'Lydia': 49,
#           'Manuelsen': 313,
#           'Mariane': 391,
#           'Martin': 115,
#           'Max': 54,
#           'Mexico': 36,
#           'Muus': 128,
#           'Nils': 262,
#           'Ole': 143,
#           'Pauline': 1277,
#           'Per': 276,
#           'Rasch': 334,
#           'Sagvika': 52,
#           'Segelfoss': 570,
#           'Sibylle': 52,
#           'Theodor': 1122,
#           'Theodors': 40,
#           'Tidende': 82,
#           'Tobias': 150,
#           'Ura': 39,
#           'Utvær': 33,
#           'Vælta': 33,
#           'Willatz': 915,
#           'Abel': 949,
#           'Abels': 26,
#           'Alex': 181,
#           'Angéle': 12,
#           'Bokklubben': 35,
#           'Brodersen': 102,
#           'Canada': 11,
#           'Carlsen': 53,
#           'Clemens': 159,
#           'Fredriksen': 129,
#           'Gregersen': 19,
#           'Gulliksen': 49,
#           'Kentucky': 23,
#           'Kjørboe': 16,
#           'Lawrence': 55,
#           'Lili': 168,
#           'Lolla': 399,
#           'Lovise': 269,
#           'Natal': 14,
#           'Olga': 229,
#           'Regina': 30,
#           'Rieber': 20,
#           'Robertsen': 90,
#           'Rolandsen': 88,
#           'Severin': 18,
#           'Sjømandshjemmet': 23,
#           'Spurven': 86,
#           'Tengvald': 22,
#           'Ulrik': 45,
#           'Westman': 15,
#           'Ane': 404,
#           'August': 4048,
#           'Augusts': 105,
#           'Bank': 22,
#           'Doppen': 144,
#           'Edevart': 2428,
#           'Edevarts': 58,
#           'Ester': 86,
#           'Ezra': 496,
#           'Fuglværø': 28,
#           'Gabrielsen': 99,
#           'Hosea': 141,
#           'Indrebygden': 103,
#           'Iversen': 44,
#           'Joakim': 833,
#           'Karolus': 556,
#           'Kristofer': 137,
#           'Lyder': 22,
#           'Magrete': 244,
#           'Maria': 397,
#           'Milde': 28,
#           'Nordbygden': 25,
#           'Norges': 26,
#           'Ottesen': 66,
#           'Paulines': 26,
#           'Polden': 630,
#           'Poldens': 62,
#           'Ragna': 298,
#           'Roderik': 100,
#           'Teodor': 441,
#           'Yterpolden': 73,
#           'Anna': 80,
#           'Berthe': 12,
#           'Bie': 47,
#           'Carr': 15,
#           'Einar': 370,
#           'Finn': 248,
#           'Finns': 14,
#           'Foss': 24,
#           'Henry': 249,
#           'Henrys': 24,
#           'Ingrid': 474,
#           'Jakob': 145,
#           'Jon': 24,
#           'Kattepatruljen': 19,
#           'Langerud': 87,
#           'Marta': 107,
#           'Miraklet': 18,
#           'Ola': 963,
#           'Olas': 24,
#           'Oppesen': 15,
#           'Oslo': 61,
#           'Percival': 119,
#           'Sonja': 95,
#           'Svartkonsta': 20,
#           'Tripp': 18,
#           'Adolf': 85,
#           'Berntsen': 70,
#           'Brygga': 47,
#           'Davidsen': 93,
#           'Fia': 141,
#           'Frank': 145,
#           'Gudskelov': 31,
#           'Heibergs': 11,
#           'Henriksen': 55,
#           'Johnsen': 213,
#           'Johnsens': 36,
#           'Jørgen': 105,
#           'Kasper': 16,
#           'Lillelydia': 77,
#           'Maren': 65,
#           'Matris': 24,
#           'Mattis': 145,
#           'Olaus': 85,
#           'Oliver': 735,
#           'Olivers': 34,
#           'Olsens': 18,
#           'Petra': 258,
#           'Reinert': 44,
#           'Salt': 32,
#           'Scheldrup': 116,
#           'Stortinget': 13,
#           'Tegnestiften': 16,
#           'Vangen': 29,
#           'Værftet': 23,
#           'Di': 12,
#           'Hans': 18,
#           'Jomfruen': 30,
#           'Karl': 11,
#           'Kommandøren': 14,
#           'Rådstuen': 11,
#           'Samlede': 14,
#           'Ylajali': 17,
#           'Alexander': 89,
#           'Altmulig': 169,
#           'Benjamin': 94,
#           'Boldemand': 25,
#           'Cornelia': 192,
#           'Dokkers': 14,
#           'England': 43,
#           'Francis': 21,
#           'Gina': 73,
#           'Gordon': 121,
#           'Hagen': 23,
#           'Hendrik': 109,
#           'Holm': 189,
#           'Julie': 101,
#           'Jørn': 55,
#           'Karel': 75,
#           'Lund': 37,
#           'Marna': 77,
#           'Mathildesen': 22,
#           'Nordgrænden': 37,
#           'Otto': 11,
#           'Pettersen': 41,
#           'Pipehodet': 20,
#           'Roten': 32,
#           'Segelfoss-bua': 17,
#           'Segelfossen': 17,
#           'Solmund': 25,
#           'Steffen': 33,
#           'Sørgrænden': 57,
#           'Tidemand': 84,
#           'Tidend': 17,
#           'Tykje': 25,
#           'Valborg': 36,
#           'Vendt': 60,
#           'Åse': 76,
#           'Albert': 379,
#           'Alberts': 42,
#           'Beck': 233,
#           'Becks': 29,
#           'Berlin': 32,
#           'Bravo': 53,
#           'Calle': 11,
#           'Civil': 24,
#           'Dolores': 29,
#           'Du': 126,
#           'Enriquez': 88,
#           'Guardia': 27,
#           'Har': 25,
#           'Herr': 11,
#           'Herrera': 19,
#           'Herreras': 15,
#           'Holzhauer': 13,
#           'Hør': 12,
#           'Jo': 11,
#           'Kaptein': 22,
#           'Karlsen': 53,
#           'Kris': 11,
#           'Kristin': 202,
#           'Kristins': 14,
#           'Las': 35,
#           'Madrid': 38,
#           'Manolo': 123,
#           'Manolos': 21,
#           'Mar': 17,
#           'Norge': 30,
#           'Orillas': 15,
#           'Palmas': 36,
#           'Patricia': 37,
#           'Puerto': 84,
#           'Rico': 21,
#           'Serrano': 58,
#           'Victor': 200,
#           'Victors': 37,
#           'Wilhelm': 262,
#           'Yolanda': 41,
#           'Vil': 22,
#           'Aa': 85,
#           'Bjørger': 253,
#           'Borken': 25,
#           'Er': 32,
#           'Erik': 187,
#           'Hvor': 22,
#           'Laura': 46,
#           'Nej': 14,
#           'Nu': 20,
#           'Thor': 88,
#           'Thora': 23,
#           'Vorherre': 30,
#           'Agnes': 28,
#           'Blakken': 22,
#           'Bygdebarn': 12,
#           'Fiffi': 30,
#           'Harald': 28,
#           'Hilde': 26,
#           'Lofoten': 65,
#           'Malene': 46,
#           'Minda': 30,
#           'Sjefen': 21,
#           'Anders': 24,
#           'Ansikt': 29,
#           'Ansiktet': 33,
#           'Armene': 16,
#           'Avsked': 11,
#           'Baat': 50,
#           'Baaten': 86,
#           'Baatene': 11,
#           'Bakeren': 13,
#           'Ben': 14,
#           'Beret': 14,
#           'Bergene': 34,
#           'Blik': 17,
#           'Blod': 19,
#           'Bod': 18,
#           'Boden': 17,
#           'Bodø': 11,
#           'Boken': 12,
#           'Bordet': 22,
#           'Bror': 26,
#           'Bryggen': 11,
#           'Brændevin': 11,
#           'Bødkeren': 16,
#           'Børnskap': 11,
#           'Chefen': 43,
#           'Dame': 15,
#           'Dans': 13,
#           'Disken': 12,
#           'Dram': 13,
#           'Dåmen': 22,
#           'Dækket': 25,
#           'Eksempel': 11,
#           'Ellingsen': 28,
#           'Enden': 15,
#           'Engelsk': 21,
#           'Fartøi': 11,
#           'Fartøier': 13,
#           'Farver': 11,
#           'Fisk': 30,
#           'Fiske': 11,
#           'Fisken': 41,
#           'Fisket': 14,
#           'Fjeldet': 13,
#           'Folkene': 17,
#           'Fortjeneste': 11,
#           'Fosenlandet': 21,
#           'Fossen': 35,
#           'Fred': 22,
#           'Fyr': 15,
#           'Færingen': 13,
#           'Førstesvend': 24,
#           'Galeasen': 17,
#           'Gangen': 20,
#           'Glæde': 15,
#           'Grænd': 11,
#           'Grænden': 38,
#           'Guid': 32,
#           'Gutter': 15,
#           'Haabjørg': 66,
#           'Haakon': 64,
#           'Handelsstedet': 16,
#           'Hat': 11,
#           'Hatten': 11,
#           'Hav': 14,
#           'Havet': 11,
#           'Hile': 11,
#           'Hjelp': 24,
#           'Hjerte': 19,
#           'Humør': 13,
#           'Husbond': 17,
#           'Hylderne': 11,
#           'Hyre': 24,
#           'Håar': 12,
#           'Indkjøp': 11,
#           'Jakt': 17,
#           'Jakten': 70,
#           'Jomfru': 30,
#           'Josefine': 28,
#           'Kai': 18,
#           'Kaien': 39,
#           'Kamerat': 35,
#           'Kameraten': 44,
#           'Kamerater': 13,
#           'Kameraterne': 19,
#           'Karer': 13,
#           'Kasse': 14,
#           'Kassen': 21,
#           'Kasser': 20,
#           'Kiær': 43,
#           'Kjæreste': 15,
#           'Kjæresten': 11,
#           'Kjærlighet': 11,
#           'Kjøkkenet': 21,
#           'Kleiva': 16,
#           'Klokke': 35,
#           'Klokker': 33,
#           'Klærne': 15,
#           'Knap': 13,
#           'Knoff': 160,
#           'Knoffs': 23,
#           'Kontoret': 12,
#           'Krambod': 34,
#           'Kramkar': 15,
#           'Kveld': 38,
#           'Kvelden': 38,
#           'Land': 81,
#           'Landet': 27,
#           'Landstrykare': 17,
#           'Landstrykere': 390,
#           'Last': 17,
#           'Lasten': 16,
#           'Levanger': 12,
#           'Liket': 24,
#           'Lommebok': 14,
#           'Lommen': 47,
#           'Lorensen': 35,
#           'Lys': 12,
#           'Løn': 18,
#           'Maaneder': 12,
#           'Maasen': 23,
#           'Maaten': 15,
#           'Magnus': 35,
#           'Maken': 21,
#           'Makt': 12,
#           'Mama': 15,
#           'Mark': 16,
#           'Marked': 13,
#           'Markedet': 20,
#           'Martinus': 22,
#           'Mattea': 78,
#           'Mel': 21,
#           'Middag': 13,
#           'Musikeren': 18,
#           'Mændene': 14,
#           'Mængde': 12,
#           'Norem': 41,
#           'Noten': 28,
#           'Næsen': 13,
#           'Ofotingen': 12,
#           'Opgjør': 14,
#           'Opgjøret': 15,
#           'Ordfører': 20,
#           'Ottring': 14,
#           'Ottringen': 11,
#           'Papst': 115,
#           'Pikerne': 14,
#           'Pipen': 12,
#           'Pokkers': 14,
#           'Prat': 25,
#           'Presten': 19,
#           'Resten': 11,
#           'Ring': 12,
#           'Ringer': 13,
#           'Romeo': 90,
#           'Rop': 21,
#           'Sikkerhet': 11,
#           'Sild': 22,
#           'Sjæl': 13,
#           'Skaaro': 66,
#           'Skaaros': 12,
#           'Skilling': 15,
#           'Skillinger': 13,
#           'Skind': 14,
#           'Skipper': 100,
#           'Skipperen': 70,
#           'Skipperne': 13,
#           'Skridt': 15,
#           'Smeden': 19,
#           'Snak': 14,
#           'Stas': 13,
#           'Stoppestedet': 21,
#           'Storebror': 11,
#           'Sæk': 18,
#           'Sækken': 16,
#           'Søstrene': 12,
#           'Tang': 13,
#           'Tider': 13,
#           'Tilfælde': 18,
#           'Time': 15,
#           'Tjeneste': 11,
#           'Tosk': 13,
#           'Trækspil': 17,
#           'Trøien': 13,
#           'Tvil': 12,
#           'Tænder': 11,
#           'Tøier': 12,
#           'Ungen': 11,
#           'Ur': 44,
#           'Uret': 28,
#           'Vaade': 23,
#           'Varerne': 19,
#           'Veir': 20,
#           'Ven': 12,
#           'Verdens': 11,
#           'Vik': 11,
#           'Vind': 16,
#           'Vinden': 11,
#           'Øie': 12,
#           'Øieblikket': 12,
#           'Martha': 48,
#           'Gå': 13,
#           'Måneland': 34,
#           'Nå': 200,
#           'Olme': 197,
#           'Sellanrå': 141,
#           'Eilef': 11,
#           'Moe': 11,
#           'Sulheim': 14,
#           'Adelheid': 90,
#           'Adelheids': 12,
#           'Hannover': 12,
#           'Harrow': 12,
#           'Holmsens': 11,
#           'Kristine': 15,
#           'Manuelsens': 15,
#           'Marcilie': 33,
#           'Moritz': 15,
#           'Nordland': 16,
#           'Raschs': 11,
#           'Salvesen': 66,
#           'Vel': 11}),
#  Counter({('Markens', 'Grøde'): 327,
#           ('Grøde', 'Dokker'): 1,
#           ('Sivert', 'Morbror'): 15,
#           ('Dyrene', 'Gammen'): 1,
#           ('Par', 'Aar'): 4,
#           ('Ja', 'Isak'): 2,
#           ('Hundrede', 'Ganger'): 3,
#           ('Grøde', 'Markens'): 1,
#           ('Inger', 'Isak'): 2,
#           ('Kua', 'Guldhorn'): 1,
#           ('Konen', 'Oline'): 2,
#           ('Par', 'Dager'): 12,
#           ('Ingers', 'Sauer'): 1,
#           ('Grøde', 'Hesten'): 1,
#           ('Hundrede', 'Aar'): 5,
#           ('Grøde', 'Inger'): 1,
#           ('Guds', 'Haand'): 2,
#           ('Par', 'Timer'): 7,
#           ('Guds', 'Hjælp'): 1,
#           ('Nei', 'Herregud'): 1,
#           ('Guds', 'Navn'): 3,
#           ('Grøde', 'Vinteren'): 1,
#           ('Inger', 'Ret'): 1,
#           ('Grøde', 'Ansigt'): 1,
#           ('Lensmand', 'Geissler'): 10,
#           ('Grøde', 'Lensmanden'): 1,
#           ('Hundrede', 'Daler'): 9,
#           ('Brede', 'Olsen'): 52,
#           ('Dag', 'Isak'): 1,
#           ('Saken', 'Sellanraa'): 2,
#           ('Geisslers', 'Haand'): 1,
#           ('Lensmand', 'Heyerdahl'): 11,
#           ('Mand', 'Geissler'): 1,
#           ('Grøde', 'Dagene'): 2,
#           ('Isak', 'Sten'): 1,
#           ('Ganger', 'Mor'): 2,
#           ('Isak', 'Kornet'): 2,
#           ('Kvæld', 'Isak'): 1,
#           ('Daler', 'Aaret'): 1,
#           ('Grøde', 'Favnved'): 1,
#           ('Nei', 'Lensmanden'): 1,
#           ('Grøde', 'Geissler'): 1,
#           ('Tilstand', 'Isak'): 1,
#           ('Gamle', 'Oline'): 2,
#           ('Ingers', 'Tid'): 1,
#           ('Nei', 'Gud'): 1,
#           ('Isaks', 'Gang'): 1,
#           ('Tid', 'Geissler'): 1,
#           ('Oline', 'Kaffe'): 1,
#           ('Par', 'Ganger'): 12,
#           ('Par', 'Ord'): 5,
#           ('Guds', 'Lykke'): 4,
#           ('Slags', 'Hus'): 1,
#           ('Isaks', 'Børn'): 1,
#           ('Grøde', 'Smaagutterne'): 1,
#           ('Inger', 'Sellanraa'): 3,
#           ('Ingers', 'Hjem'): 1,
#           ('Geisslers', 'Mund'): 1,
#           ('Isak', 'Sellanraa'): 2,
#           ('Par', 'Hundrede'): 3,
#           ('Tusen', 'Kræfter'): 1,
#           ('Gang', 'Isak'): 1,
#           ('Isak', 'Kjærren'): 1,
#           ('Isak', 'Mat'): 1,
#           ('Geisslers', 'Arbeide'): 1,
#           ('Siden', 'Oline'): 1,
#           ('Grøde', 'Menneske'): 1,
#           ('Piken', 'Barbro'): 9,
#           ('Ja', 'Mat'): 1,
#           ('Inger', 'Bud'): 1,
#           ('Ja', 'Hjælp'): 1,
#           ('Slags', 'Maal'): 1,
#           ('Sellanraa', 'Gaard'): 3,
#           ('Livet', 'Dag'): 1,
#           ('Grøde', 'Ved'): 1,
#           ('Inger', 'Ro'): 1,
#           ('Morbror', 'Sivert'): 8,
#           ('Aksel', 'Strøm'): 68,
#           ('Par', 'Dyr'): 1,
#           ('Isaks', 'Hænder'): 1,
#           ('Grøde', 'Dyrene'): 1,
#           ('Ja', 'Tak'): 2,
#           ('Nei', 'Tak'): 3,
#           ('Geissler', 'Ro'): 1,
#           ('Arbeide', 'Sivert'): 1,
#           ('Dokker', 'Morgningen'): 1,
#           ('Geissler', 'Gaarden'): 1,
#           ('Telegrafen', 'Brede'): 1,
#           ('Familjen', 'Brede'): 7,
#           ('Par', 'Uker'): 10,
#           ('Nei', 'Isak'): 1,
#           ('Ingers', 'Folk'): 1,
#           ('Bud', 'Oline'): 1,
#           ('Grøde', 'Hvem'): 1,
#           ('Farn', 'Sivert'): 1,
#           ('Geisslers', 'Ord'): 1,
#           ('Geissler', 'Isak'): 2,
#           ('Tusen', 'Kroner'): 4,
#           ('Fru', 'Geisslers'): 2,
#           ('Hundrede', 'Kroner'): 8,
#           ('Isaks', 'Fuldmægtig'): 1,
#           ('Sind', 'Markens'): 1,
#           ('Slags', 'Folk'): 3,
#           ('Tusen', 'Daler'): 9,
#           ('Ja', 'Sivert'): 2,
#           ('Grøde', 'Eleseus'): 1,
#           ('Grøde', 'Munden'): 1,
#           ('Fru', 'Heyerdahl'): 6,
#           ('Søndag', 'Morgen'): 3,
#           ('Mening', 'Markens'): 1,
#           ('Grøde', 'Farn'): 1,
#           ('Par', 'Steder'): 3,
#           ('Grøde', 'Aksel'): 1,
#           ('Aksel', 'Markens'): 1,
#           ('Smaa', 'Bud'): 1,
#           ('Grøde', 'Naa'): 1,
#           ('Ja', 'Oline'): 1,
#           ('Varer', 'Gaarden'): 1,
#           ('Gaarden', 'Sellanraa'): 1,
#           ('Siden', 'Barbro'): 1,
#           ('Guds', 'Sne'): 1,
#           ('Aksel', 'Tid'): 1,
#           ('Kvæld', 'Aksel'): 1,
#           ('Slags', 'Mand'): 2,
#           ('Grøde', 'Menneskene'): 1,
#           ('Dokker', 'Fjældet'): 1,
#           ('Grøde', 'Marken'): 2,
#           ('Ingers', 'Guldring'): 1,
#           ('Grøde', 'Sellanraa'): 1,
#           ('Par', 'Spørsmaal'): 2,
#           ('Herrerne', 'Markens'): 1,
#           ('Geisslers', 'Svar'): 1,
#           ('Geisslers', 'Side'): 1,
#           ('Geisslers', 'Folk'): 1,
#           ('Grøde', 'Sommeren'): 1,
#           ('Oline', 'Hænderne'): 1,
#           ('Ingers', 'Skyld'): 1,
#           ('Markens', 'Barn'): 1,
#           ('Ja', 'Penger'): 1,
#           ('Ja', 'Dokker'): 10,
#           ('Menneskene', 'Tid'): 1,
#           ('Sivert', 'Lyst'): 1,
#           ('Nei', 'Inger'): 2,
#           ('Fuldmægtig', 'Andresen'): 18,
#           ('Markens', 'Folk'): 3,
#           ('Nei', 'Barbro'): 1,
#           ('Fru', 'Lensmand'): 6,
#           ('Geisslers', 'Øine'): 1,
#           ('Par', 'Piker'): 1,
#           ('Nei', 'Statsadvokaten'): 1,
#           ('Som', 'Menneske'): 1,
#           ('Nei', 'Piken'): 1,
#           ('Aksel', 'Lensmanden'): 1,
#           ('Handelsmand', 'Aronsen'): 8,
#           ('Grøde', 'Hodet'): 1,
#           ('Slags', 'Varer'): 2,
#           ('Nei', 'Dokker'): 2,
#           ('Gang', 'Herre'): 1,
#           ('Nei', 'Lensmandsfruen'): 1,
#           ('Geisslers', 'Fjæld'): 1,
#           ('Nei', 'Arbeidet'): 1,
#           ('Grøde', 'Andresen'): 1,
#           ('Isaks', 'Side'): 1,
#           ('Grøde', 'Sten'): 1,
#           ('Slags', 'Pike'): 1,
#           ('Morgen', 'Klokken'): 2,
#           ('Naa', 'Herregud'): 1,
#           ('Ja', 'Barbro'): 2,
#           ('Grøde', 'Kvindfolkhjælp'): 1,
#           ('Markens', 'Mand'): 1,
#           ('Nei', 'Oline'): 1,
#           ('Oline', 'Hodet'): 1,
#           ('Nei', 'Aksel'): 1,
#           ('Leopoldine', 'Markens'): 1,
#           ('Datter', 'Barbro'): 1,
#           ('Grøde', 'Brede'): 1,
#           ('Nei', 'Eleseus'): 1,
#           ('Eleseus', 'Penger'): 1,
#           ('Storborg', 'Gaard'): 1,
#           ('Gaard', 'Potet'): 1,
#           ('Sivert', 'Hesten'): 1,
#           ('Fredrik', 'Strøm'): 8,
#           ('Gang', 'Sivert'): 1,
#           ('Bygden', 'Penger'): 1,
#           ('Dokker', 'Tobak'): 1,
#           ('Nei', 'Sivert'): 1,
#           ('Hamsun', 'Segelfoss'): 1,
#           ('Ole', 'Johan'): 135,
#           ('Lars', 'Manuelsen'): 293,
#           ('Willatz', 'Holmsen'): 134,
#           ('Julius', 'Larsens'): 2,
#           ('Segelfoss', 'Tidende'): 78,
#           ('Theodor', 'Jensen'): 30,
#           ('Dem', 'Segelfoss'): 2,
#           ('Anton', 'Coldevin'): 40,
#           ('De', 'Dem'): 6,
#           ('De', 'Willatz'): 2,
#           ('Lassen', 'De'): 4,
#           ('Dem', 'Theodor'): 2,
#           ('Segelfoss', 'De'): 2,
#           ('De', 'Deres'): 4,
#           ('Deres', 'Mariane'): 4,
#           ('Mariane', 'Holmengrå'): 4,
#           ('Abel', 'Brodersen'): 16,
#           ('Lovise', 'Rolandsen'): 11,
#           ('Rieber', 'Carlsen'): 19,
#           ('Ulrik', 'Fredriksen'): 12,
#           ('Olga', 'Clemens'): 1,
#           ('Deres', 'Alex'): 1,
#           ('Brodersen', 'Clemens'): 1,
#           ('Olga', 'Gulliksen'): 1,
#           ('Ane', 'Maria'): 395,
#           ('Lovise', 'Magrete'): 244,
#           ('Magrete', 'Doppen'): 9,
#           ('Lyder', 'Milde'): 22,
#           ('Norges', 'Bank'): 22,
#           ('Ola', 'Langerud'): 11,
#           ('Langerud', 'Oslo'): 1,
#           ('Percival', 'Carr'): 9,
#           ('Finn', 'Oppesen'): 13,
#           ('Scheldrup', 'Johnsen'): 28,
#           ('Fia', 'Johnsen'): 10,
#           ('Maren', 'Salt'): 32,
#           ('Dem', 'Mattis'): 1,
#           ('Fia', 'Johnsens'): 1,
#           ('Dem', 'Deres'): 1,
#           ('Karl', 'Johan'): 11,
#           ('Dem', 'Ylajali'): 1,
#           ('Hamsun', 'Samlede'): 4,
#           ('Gordon', 'Tidemand'): 84,
#           ('Otto', 'Alexander'): 5,
#           ('Segelfoss', 'Tidend'): 16,
#           ('Jørn', 'Mathildesen'): 22,
#           ('Puerto', 'Bravo'): 53,
#           ('Albert', 'Sommer'): 69,
#           ('Las', 'Palmas'): 35,
#           ('Herr', 'Holzhauer'): 3,
#           ('Puerto', 'Rico'): 21,
#           ('Guardia', 'Civil'): 24,
#           ('Patricia', 'Enriquez'): 9,
#           ('Wilhelm', 'Beck'): 218,
#           ('Wilhelm', 'Becks'): 28,
#           ('Kristin', 'Patricia'): 4,
#           ('Patricia', 'Karlsen'): 1,
#           ('Kristin', 'Karlsen'): 41,
#           ('Kris', 'Karlsen'): 1,
#           ('Herr', 'Beck'): 1,
#           ('Victor', 'Enriquez'): 58,
#           ('Du', 'Sommer'): 1,
#           ('Kaptein', 'Serrano'): 20,
#           ('Vil', 'Vil'): 1,
#           ('Nei', 'Borken'): 1,
#           ('Ja', 'Borken'): 2,
#           ('Er', 'Per'): 2,
#           ('Er', 'Thor'): 2,
#           ('Ingrid', 'Langerud'): 2,
#           ('Landstrykere', 'Stykke'): 1,
#           ('Musikeren', 'Landstrykere'): 1,
#           ('Hile', 'Piken'): 2,
#           ('Edevarts', 'Hode'): 2,
#           ('Edevarts', 'Liv'): 1,
#           ('Augusts', 'Tænder'): 1,
#           ('Kone', 'Ane'): 3,
#           ('Mand', 'Teodor'): 1,
#           ('Edevart', 'Kamerater'): 1,
#           ('August', 'Handelen'): 1,
#           ('Mængde', 'Skind'): 1,
#           ('Landstrykere', 'August'): 7,
#           ('Kamerater', 'August'): 1,
#           ('Edevarts', 'Ansikt'): 3,
#           ('Gamle', 'Papst'): 2,
#           ('Papst', 'Uret'): 1,
#           ('Verdens', 'Mat'): 1,
#           ('Landstrykere', 'Eksempel'): 1,
#           ('Landstrykere', 'Edevart'): 18,
#           ('Gang', 'Edevart'): 2,
#           ('Tusen', 'Fisk'): 1,
#           ('Skipper', 'Skaaro'): 37,
#           ('Maria', 'Landstrykere'): 1,
#           ('Landstrykere', 'Aar'): 1,
#           ('Dag', 'Fisken'): 2,
#           ('Landstrykere', 'Dokker'): 1,
#           ('Landstrykere', 'Verden'): 1,
#           ('Skipper', 'Skaaros'): 3,
#           ('Skipper', 'August'): 7,
#           ('Skaaros', 'Ur'): 3,
#           ('Landstrykere', 'Land'): 1,
#           ('Par', 'Børn'): 1,
#           ('Slags', 'Arbeide'): 1,
#           ('Tak', 'Sauen'): 1,
#           ('August', 'Papst'): 1,
#           ('Penger', 'Edevart'): 1,
#           ('Verdens', 'Handel'): 1,
#           ('Jomfruen', 'Edevart'): 1,
#           ('Verdens', 'Ting'): 4,
#           ('Morgen', 'Edevart'): 1,
#           ('Augusts', 'Øine'): 1,
#           ('Skaaros', 'Klokke'): 1,
#           ('Landstrykere', 'Edevarts'): 1,
#           ('Edevarts', 'Ur'): 2,
#           ('Piken', 'Øinene'): 1,
#           ('Haakon', 'Doppen'): 19,
#           ('Landstrykere', 'Lovise'): 3,
#           ('Tid', 'Lovise'): 1,
#           ('Børn', 'Romeo'): 1,
#           ('Kamerat', 'August'): 4,
#           ('Knoffs', 'Hode'): 1,
#           ('Knoffs', 'Øine'): 1,
#           ('Jomfru', 'Ellingsen'): 24,
#           ('Gutten', 'Romeo'): 3,
#           ('Edevarts', 'Øine'): 1,
#           ('Edevart', 'Knoff'): 1,
#           ('Knoffs', 'Penger'): 1,
#           ('Eksempel', 'Levanger'): 1,
#           ('Levanger', 'Marked'): 6,
#           ('Par', 'Kasser'): 1,
#           ('Hundrede', 'Kasser'): 1,
#           ('Tusen', 'Kasser'): 1,
#           ('Brev', 'Landstrykere'): 1,
#           ('Knoffs', 'Sted'): 3,
#           ('Mand', 'Knoff'): 1,
#           ('Levanger', 'Landstrykere'): 1,
#           ('Skaaros', 'Jakt'): 1,
#           ('Slags', 'Ur'): 1,
#           ('Par', 'Gutter'): 1,
#           ('Bror', 'Joakim'): 4,
#           ('Landstrykere', 'Knoff'): 1,
#           ('Magrete', 'Landstrykere'): 1,
#           ('Knoffs', 'Jakt'): 1,
#           ('Par', 'Maaneder'): 3,
#           ('Hus', 'Dagen'): 1,
#           ('Knoff', 'Tid'): 1,
#           ('Skipper', 'Norem'): 11,
#           ('Edevart', 'Penger'): 1,
#           ('Par', 'Daler'): 6,
#           ('Pokkers', 'Joakim'): 1,
#           ('Ordfører', 'Karolus'): 11,
#           ('Handelsmand', 'Gabrielsen'): 9,
#           ('Skilling', 'Natten'): 1,
#           ('Mængde', 'Varer'): 4,
#           ('Ungen', 'Joakim'): 2,
#           ('Guds', 'Hjelp'): 2,
#           ('Edevarts', 'Hænder'): 1,
#           ('Pokkers', 'Beret'): 1,
#           ('Skipper', 'Edevart'): 2,
#           ('Knoffs', 'Bord'): 1,
#           ('Guds', 'Skyld'): 3,
#           ('Mængde', 'Folk'): 1,
#           ('Slags', 'Kjæreste'): 1,
#           ('Førstesvend', 'Lorensen'): 14,
#           ('Kramboden', 'Lorensen'): 2,
#           ('Knoffs', 'Ansikt'): 1,
#           ('Norem', 'Liv'): 1,
#           ('Knoffs', 'Tjeneste'): 1,
#           ('Mand', 'Karolus'): 1,
#           ('Kone', 'Beret'): 1,
#           ('Landstrykere', 'Alvor'): 1,
#           ('Piken', 'Olga'): 1,
#           ('Karolus', 'Ordfører'): 1,
#           ('Landstrykere', 'Ragna'): 1,
#           ('Edevarts', 'Tjeneste'): 1,
#           ('Gamle', 'Mand'): 1,
#           ('Kamerat', 'Augusts'): 1,
#           ('Augusts', 'Kjæreste'): 1,
#           ('Tusen', 'Tanker'): 3,
#           ('Nils', 'Kramkar'): 6,
#           ('Hile', 'Gaard'): 1,
#           ('Bodø', 'By'): 1,
#           ('Augusts', 'Guldring'): 1,
#           ('Landstrykere', 'Spørsmaal'): 1,
#           ('Mark', 'Kaffe'): 6,
#           ('Ven', 'Bakeren'): 1,
#           ('Gamle', 'Knoff'): 3,
#           ('Knoffs', 'Hus'): 1,
#           ('Landstrykere', 'Manden'): 1,
#           ('Ved', 'Opgjøret'): 1,
#           ('Knoffs', 'Krambod'): 1,
#           ('Edevarts', 'Hjem'): 2,
#           ('Joakim', 'Bror'): 1,
#           ('Pokkers', 'August'): 2,
#           ('Landstrykere', 'Fjøset'): 1,
#           ('Fjøset', 'Ezra'): 1,
#           ('Tid', 'Folk'): 1,
#           ('Augusts', 'Raad'): 1,
#           ('Dagen', 'Skipper'): 1,
#           ('Time', 'Alvor'): 1,
#           ('Ved', 'Enden'): 1,
#           ('Hile', 'Ragna'): 1,
#           ('Landstrykere', 'Mark'): 1,
#           ('Edevarts', 'Krambod'): 1,
#           ('Pokkers', 'Fyr'): 1,
#           ('Hile', 'Haabjørg'): 2,
#           ('Landstrykere', 'Ezra'): 1,
#           ('Landstrykere', 'Gaarden'): 1,
#           ('Romeo', 'Knoff'): 2,
#           ('Knoffs', 'Kai'): 1,
#           ('Anders', 'Vaade'): 23,
#           ('Hundrede', 'Kjyr'): 1,
#           ('Landstrykere', 'Vand'): 1,
#           ('Landstrykare', 'Haanden'): 1,
#           ('Slags', 'Dyr'): 2,
#           ('Mama', 'Ringer'): 1,
#           ('Hile', 'Hode'): 1,
#           ('Stykke', 'Vei'): 1,
#           ('Par', 'Kjyr'): 1,
#           ('Edevarts', 'Mening'): 1,
#           ('Gabrielsen', 'Edevart'): 1,
#           ('Romeo', 'Fossen'): 1,
#           ('Landstrykere', 'Fossen'): 1,
#           ('Par', 'Ting'): 1,
#           ('Landstrykere', 'Pris'): 1,
#           ('Landstrykere', 'Kvelden'): 1,
#           ('Landstrykere', 'Slag'): 1,
#           ('Landstrykere', 'Vei'): 1,
#           ('Landstrykere', 'Fjeldet'): 1,
#           ('August', 'Edevart'): 1,
#           ('Landstrykere', 'Guldring'): 1,
#           ('Kjøkkenet', 'Landstrykere'): 1,
#           ('Gang', 'Anders'): 1,
#           ('Julie', 'Knoff'): 1,
#           ('Hile', 'Fjøs'): 1,
#           ('Bror', 'Boken'): 1,
#           ('Dag', 'Ofotingen'): 1,
#           ('Verdens', 'Varer'): 1,
#           ('Edevarts', 'Skyld'): 1,
#           ('Landstrykere', 'Anders'): 1,
#           ('Tid', 'Ezra'): 1,
#           ('Landstrykere', 'Penger'): 1,
#           ('Tider', 'Folk'): 1,
#           ('Tusen', 'Ganger'): 1,
#           ('Landstrykere', 'Halsen'): 1,
#           ('Far', 'Skipperen'): 1,
#           ('Edevarts', 'Side'): 1,
#           ('Landstrykere', 'Kameraterne'): 1,
#           ('Landstrykere', 'Romeo'): 1,
#           ('Presten', 'Haanden'): 1,
#           ('Krambod', 'Landstrykere'): 1,
#           ('Gamle', 'Skipper'): 1,
#           ('Skipper', 'Ofotingen'): 1,
#           ('Joakim', 'Brevet'): 1,
#           ('Landstrykere', 'Ane'): 1,
#           ('Haand', 'Joakim'): 1,
#           ('Pokkers', 'Kone'): 3,
#           ('Slags', 'Veir'): 1,
#           ('Inger', 'Sellanrå'): 3,
#           ('Isak', 'Sellanrå'): 2,
#           ('Ja', 'Olme'): 1,
#           ('Nå', 'Herregud'): 1,
#           ('Er', 'Eilef'): 1,
#           ('Nei', 'Per'): 1,
#           ('Nei', 'Eilef'): 1,
#           ('Borken', 'Eilef'): 1,
#           ('Erik', 'Sulheim'): 2,
#           ('Inger', 'Sulheim'): 1,
#           ('Bjørger', 'Sulheim'): 1,
#           ('Du', 'Gud'): 1,
#           ('Laura', 'Moe'): 1,
#           ('Willatz', 'Holmsens'): 4,
#           ('Holmsen', 'De'): 1,
#           ('Tobias', 'Holmengrå'): 5,
#           ('Kristine', 'Salvesen'): 3,
#           ('Lars', 'Manuelsens'): 15,
#           ('Fredrik', 'Coldevin'): 18,
#           ('Deres', 'Martin'): 1,
#           ('De', 'Martin'): 1}),
#  Counter({('Markens', 'Grøde', 'Dokker'): 1,
#           ('Markens', 'Grøde', 'Markens'): 1,
#           ('Grøde', 'Markens', 'Grøde'): 1,
#           ('Markens', 'Grøde', 'Hesten'): 1,
#           ('Markens', 'Grøde', 'Inger'): 1,
#           ('Markens', 'Grøde', 'Vinteren'): 1,
#           ('Markens', 'Grøde', 'Ansigt'): 1,
#           ('Markens', 'Grøde', 'Lensmanden'): 1,
#           ('Markens', 'Grøde', 'Dagene'): 2,
#           ('Markens', 'Grøde', 'Favnved'): 1,
#           ('Markens', 'Grøde', 'Geissler'): 1,
#           ('Markens', 'Grøde', 'Smaagutterne'): 1,
#           ('Par', 'Hundrede', 'Daler'): 1,
#           ('Markens', 'Grøde', 'Menneske'): 1,
#           ('Markens', 'Grøde', 'Ved'): 1,
#           ('Markens', 'Grøde', 'Dyrene'): 1,
#           ('Markens', 'Grøde', 'Hvem'): 1,
#           ('Sind', 'Markens', 'Grøde'): 1,
#           ('Markens', 'Grøde', 'Eleseus'): 1,
#           ('Markens', 'Grøde', 'Munden'): 1,
#           ('Mening', 'Markens', 'Grøde'): 1,
#           ('Markens', 'Grøde', 'Farn'): 1,
#           ('Markens', 'Grøde', 'Aksel'): 1,
#           ('Grøde', 'Aksel', 'Strøm'): 1,
#           ('Aksel', 'Markens', 'Grøde'): 1,
#           ('Markens', 'Grøde', 'Naa'): 1,
#           ('Varer', 'Gaarden', 'Sellanraa'): 1,
#           ('Markens', 'Grøde', 'Menneskene'): 1,
#           ('Markens', 'Grøde', 'Marken'): 2,
#           ('Markens', 'Grøde', 'Sellanraa'): 1,
#           ('Herrerne', 'Markens', 'Grøde'): 1,
#           ('Fru', 'Geisslers', 'Folk'): 1,
#           ('Markens', 'Grøde', 'Sommeren'): 1,
#           ('Fru', 'Lensmand', 'Heyerdahl'): 4,
#           ('Nei', 'Piken', 'Barbro'): 1,
#           ('Markens', 'Grøde', 'Hodet'): 1,
#           ('Markens', 'Grøde', 'Andresen'): 1,
#           ('Markens', 'Grøde', 'Sten'): 1,
#           ('Markens', 'Grøde', 'Kvindfolkhjælp'): 1,
#           ('Leopoldine', 'Markens', 'Grøde'): 1,
#           ('Markens', 'Grøde', 'Brede'): 1,
#           ('Storborg', 'Gaard', 'Potet'): 1,
#           ('Dem', 'Segelfoss', 'Tidende'): 2,
#           ('De', 'Willatz', 'Holmsen'): 2,
#           ('Deres', 'Mariane', 'Holmengrå'): 4,
#           ('Lovise', 'Magrete', 'Doppen'): 9,
#           ('Ola', 'Langerud', 'Oslo'): 1,
#           ('Kristin', 'Patricia', 'Karlsen'): 1,
#           ('Kone', 'Ane', 'Maria'): 3,
#           ('Ane', 'Maria', 'Landstrykere'): 1,
#           ('Skipper', 'August', 'Papst'): 1,
#           ('Skipper', 'Skaaros', 'Klokke'): 1,
#           ('Landstrykere', 'Edevarts', 'Ansikt'): 1,
#           ('Landstrykere', 'Lovise', 'Magrete'): 3,
#           ('Tid', 'Lovise', 'Magrete'): 1,
#           ('Eksempel', 'Levanger', 'Marked'): 1,
#           ('Lovise', 'Magrete', 'Landstrykere'): 1,
#           ('Dagen', 'Skipper', 'Skaaro'): 1,
#           ('Landstrykere', 'Mark', 'Kaffe'): 1,
#           ('Gang', 'Anders', 'Vaade'): 1,
#           ('Landstrykere', 'Anders', 'Vaade'): 1,
#           ('Gamle', 'Skipper', 'Ofotingen'): 1,
#           ('Landstrykere', 'Ane', 'Maria'): 1,
#           ('Willatz', 'Holmsen', 'De'): 1}),
#  Counter({('Markens', 'Grøde', 'Markens', 'Grøde'): 1,
#           ('Markens', 'Grøde', 'Aksel', 'Strøm'): 1,
#           ('Kone', 'Ane', 'Maria', 'Landstrykere'): 1})]

# %% [markdown]
# ### Lagring og redigering
#
# Rediger filen fra cellen med lagringskommando (`names_to_token_map_file(....)`)
# Listen trenger litt redigering, og sammenslåing. Lagre til Excel, og benytt `orient = column` for å ha navn i kolonnner, eller `orient = row` for å redigere radvis. Noen store filer med over 256 navn krever `row`. Kommandoen sjekker om filen allerede fins, og vil ikke skrive over. Følg med på output.

# %%
tm.names_to_token_map_file(total_names, filename = "korpus_test0.xls", orient = "row")
# Out:
# True

# %% [markdown]
# ### Redigeringsaktivitet
#
# Åpne i for eksempel i excel eller tilsvarende som for eksempel openoffice eller libreoffice. Etter redigering, kjøres cellen under. Husk bare å benytte riktig filnavn.
#
# Husk at verdien på orient må være lik mellom lagring og lesing av excelfil.

# %%
redigerte_navn = tm.read_token_map_file("korpus_test0.xls", orient = "row")

# %% [markdown]
# ## Tell opp navn med hensyn til det som står i `redigerte_navn`
#
# Bruker hjelpekommando `tell_navn`

# %%
opptelling = tell_navn(korpus, redigerte_navn)
opptelling
# Out:
#                                    0
# De_Willatz_Holmsen            7120.0
# Ja_Isak                       5757.0
# Skipper_August_Papst          4406.0
# Nei_Piken_Barbro              4232.0
# Edevart_Kamerater             2519.0
# Dem_Segelfoss_Tidende         2203.0
# Du_Sommer                     2092.0
# Deres_Mariane_Holmengrå       1979.0
# Theodor_Jensen                1724.0
# Nu                            1486.0
# Markens_Grøde_Inger           1476.0
# Ola_Langerud_Oslo             1451.0
# Kone_Ane_Maria_Landstrykere   1342.0
# Pauline                       1329.0
# Er_Per                        1107.0
# Nå_Herregud                   1080.0
# Abel_Brodersen                1077.0
# Markens_Grøde_Dokker          1047.0
# Nei_Gud                       1042.0
# Lars_Manuelsen                1037.0
# Jo                             977.0
# Bror_Joakim                    879.0
# Oliver                         769.0
# Fru_Geisslers_Folk             764.0
# Polden                         702.0
# Har                            674.0
# Markens_Grøde_Aksel_Strøm      672.0
# Hvor                           662.0
# Lovise_Magrete_Doppen          660.0
# Einar                          629.0
# ...                              ...
# Di                              14.0
# Fiske                           13.0
# Færingen                        13.0
# Mil                             13.0
# Hannover                        13.0
# Berthe                          13.0
# Tang                            13.0
# Skipperne                       13.0
# Ottringen                       12.0
# Harrow                          12.0
# Tøier                           12.0
# Brændevin                       12.0
# Grænd                           12.0
# Angéle                          12.0
# Markens_Grøde_Kvindfolkhjælp    12.0
# Slaamaskine                     12.0
# Skogkanten                      12.0
# Makt                            12.0
# Hylderne                        12.0
# Indkjøp                         12.0
# Rådstuen                        11.0
# Calle                           11.0
# Foder                           11.0
# Vik                             11.0
# Heibergs                        11.0
# Kris_Karlsen                    11.0
# Canada                          11.0
# Fartøi                          11.0
# Børnskap                        11.0
# Ungen_Joakim                    11.0
#
# [714 rows x 1 columns]

# %% [markdown]
# # Lag en graf for en bok
#
# Grafene kan legges sammen i etterkant om det ønskes en graf for hele korpuset.

# %%
# fyll inn en indeks fra korpuslisten 0 er første URN, 1 neste osv.

G = tm.character_network(str(korpus['urn'][2]), redigerte_navn)
gnl.show_graph(G)
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# Dernest kan den vises og analyseres med passende kommandoer
