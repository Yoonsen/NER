# %% [markdown]
# conda config --add channels conda-forge
#
# conda install qgrid

# %%
import pandas as pd
import qgrid as qg
import dhlab.nbtext as nb
import dhlab.token_map as tm
import ipywidgets as widgets
# %matplotlib inline

# %%
df = pd.read_excel("Hamsuns_data/Alt_Hamsunkorpus.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f33c866e54dd> in <module>
# ----> 1 df = pd.read_excel("Hamsuns_data/Alt_Hamsunkorpus.xls")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Hamsuns_data/Alt_Hamsunkorpus.xls'

# %%
df.drop(axis=1, index= df[df.urn.isna()].index, inplace=True)

# %%
df.columns
# Out:
# Index(['urn', 'forf', 'år', 'tittel', 'undertittel', 'forlag', 'sjanger',
#        'sesamid', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df = df[['urn', 'forf', 'år', 'tittel', 'undertittel', 'forlag', 'sjanger','sesamid']]

# %%
grid = qg.show_grid(df, show_toolbar=True)
grid
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
brev = grid.get_changed_df()
brev
# Out:
#              urn          forf      år             tittel undertittel  \
# 43  2.008091e+12  Hamsun, Knut  1997.0  Knut Hamsuns brev         NaN
# 44  2.010032e+12  Hamsun, Knut  1995.0  Knut Hamsuns brev         NaN
# 45  2.009032e+12  Hamsun, Knut  1999.0  Knut Hamsuns brev         NaN
# 46  2.008010e+12  Hamsun, Knut  1994.0  Knut Hamsuns brev         NaN
# 47  2.008113e+12  Hamsun, Knut  2000.0  Knut Hamsuns brev         NaN
# 48  2.008111e+12  Hamsun, Knut  2001.0  Knut Hamsuns brev         NaN
#
#                                    forlag  sjanger  \
# 43  Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 44  Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 45  Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 46  Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 47  Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 48  Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
#
#                              sesamid
# 43  016db7c52214bce8e3612c2608b4b61c
# 44  23df19922b203f588261e34304351de1
# 45  3be2e2a46b0a788081c6e72cbf24761f
# 46  131e85b5bbc3800dcb60bc9afd588459
# 47  8206fe4a8ec2fac45ac6f3d2a9c7639c
# 48  33b6512367fc496d55846e601217d98d

# %%
gyld = grid.get_changed_df()
gyld
# Out:
#              urn          forf      år                      tittel  \
# 10  2.009052e+12  Hamsun, Knut  1897.0                      Siesta
# 11  2.007061e+12  Hamsun, Knut  1898.0                   Aftenrøde
# 13  2.008123e+12  Hamsun, Knut  1902.0                Munken Vendt
# 14  2.016011e+12  Hamsun, Knut  1903.0             Dronning Tamara
# 15  2.008123e+12  Hamsun, Knut  1903.0                    Kratskog
# 16  2.008123e+12  Hamsun, Knut  1903.0               I Æventyrland
# 17  2.009052e+12  Hamsun, Knut  1904.0               Det vilde Kor
# 18  2.009051e+12  Hamsun, Knut  1904.0                    Sværmere
# 19  2.009052e+12  Hamsun, Knut  1905.0               Stridende Liv
# 20  2.008123e+12  Hamsun, Knut  1906.0          Under Høststjærnen
# 21  2.009061e+12  Hamsun, Knut  1908.0                        Rosa
# 22  2.013041e+12  Hamsun, Knut  1908.0                      Benoni
# 23  2.009062e+12  Hamsun, Knut  1909.0  Vandrer spiller med Sordin
# 24  2.008123e+12  Hamsun, Knut  1910.0                 Livet ivold
# 25  2.008092e+12  Hamsun, Knut  1912.0                sidste Glæde
# 26  2.008092e+12  Hamsun, Knut  1913.0               Børn av Tiden
# 36  2.008092e+12  Hamsun, Knut  1927.0                Landstrykere
# 42  2.008042e+12  Hamsun, Knut  1949.0        Paa gjengrodde stier
#
#                         undertittel     forlag  sjanger  \
# 10                          Skitser  Gyldendal  unknown
# 11                    Slutningsspil  Gyldendal  unknown
# 13             Brigantinens Saga, 1  Gyldendal  unknown
# 14             Skuespil i tre Akter  Gyldendal  unknown
# 15             Historier og Skitser  Gyldendal  unknown
# 16     oplevet og drømt i Kaukasien  Gyldendal  unknown
# 17                            Digte  Gyldendal  unknown
# 18                            Roman  Gyldendal    novel
# 19  Skildringer fra Vesten og Østen  Gyldendal  unknown
# 20           en Vandrers Fortælling  Gyldendal  unknown
# 21     af Student Parelius' Papirer  Gyldendal  unknown
# 22                            roman  Gyldendal  unknown
# 23                              NaN  Gyldendal  unknown
# 24            Skuespil i fire Akter  Gyldendal  unknown
# 25                      Skildringer  Gyldendal  unknown
# 26                            Roman  Gyldendal  unknown
# 36                            roman  Gyldendal    novel
# 42                              NaN  Gyldendal  unknown
#
#                              sesamid
# 10  e7e8524d734b0bab8c2219d349be3c6e
# 11  a36c73ddd25674f39f55c7e233dd0770
# 13  89ee1bececa7b691dafdf6f785b236b7
# 14  be5af477838b99c1ede33603bebc20c8
# 15  fc7c0e985dd11d120bebb9c3f15bffbc
# 16  2b981c264b0802a5fc53a8d432440e98
# 17  f7b71bb94d2eb6269ec46f7db668edc3
# 18  c6be34a1385f8e08463cedd6d8357210
# 19  5a7697d5ef98464f854bcd1ce7a0a66d
# 20  8444ebbd3ae76c073402385f4fb94eff
# 21  3217b178aebb23c537a7b079b6918c47
# 22  9d1f9278a5efbae4d4dd7974884f9b09
# 23  429be57bdf2c1e6fd7e93ff396bb0d93
# 24  e3c975a4d23b31c74aaf84b3dde8f6ac
# 25  ef5a096eec2b9dfd62804ca5206a0b86
# 26  3fc74605bf0797503d11e45bbe7ef46a
# 36  9c37b0255a568e33ba8881fb419a1ca9
# 42  a49e4e77ab01e0e04aff4e71de753dbe

# %%
df[df.forlag=='Gyldendal']
# Out:
#              urn          forf      år                      tittel  \
# 10  2.009052e+12  Hamsun, Knut  1897.0                      Siesta
# 11  2.007061e+12  Hamsun, Knut  1898.0                   Aftenrøde
# 13  2.008123e+12  Hamsun, Knut  1902.0                Munken Vendt
# 14  2.016011e+12  Hamsun, Knut  1903.0             Dronning Tamara
# 15  2.008123e+12  Hamsun, Knut  1903.0                    Kratskog
# 16  2.008123e+12  Hamsun, Knut  1903.0               I Æventyrland
# 17  2.009052e+12  Hamsun, Knut  1904.0               Det vilde Kor
# 18  2.009051e+12  Hamsun, Knut  1904.0                    Sværmere
# 19  2.009052e+12  Hamsun, Knut  1905.0               Stridende Liv
# 20  2.008123e+12  Hamsun, Knut  1906.0          Under Høststjærnen
# 21  2.009061e+12  Hamsun, Knut  1908.0                        Rosa
# 22  2.013041e+12  Hamsun, Knut  1908.0                      Benoni
# 23  2.009062e+12  Hamsun, Knut  1909.0  Vandrer spiller med Sordin
# 24  2.008123e+12  Hamsun, Knut  1910.0                 Livet ivold
# 25  2.008092e+12  Hamsun, Knut  1912.0                sidste Glæde
# 26  2.008092e+12  Hamsun, Knut  1913.0               Børn av Tiden
# 36  2.008092e+12  Hamsun, Knut  1927.0                Landstrykere
# 42  2.008042e+12  Hamsun, Knut  1949.0        Paa gjengrodde stier
#
#                         undertittel     forlag  sjanger  \
# 10                          Skitser  Gyldendal  unknown
# 11                    Slutningsspil  Gyldendal  unknown
# 13             Brigantinens Saga, 1  Gyldendal  unknown
# 14             Skuespil i tre Akter  Gyldendal  unknown
# 15             Historier og Skitser  Gyldendal  unknown
# 16     oplevet og drømt i Kaukasien  Gyldendal  unknown
# 17                            Digte  Gyldendal  unknown
# 18                            Roman  Gyldendal    novel
# 19  Skildringer fra Vesten og Østen  Gyldendal  unknown
# 20           en Vandrers Fortælling  Gyldendal  unknown
# 21     af Student Parelius' Papirer  Gyldendal  unknown
# 22                            roman  Gyldendal  unknown
# 23                              NaN  Gyldendal  unknown
# 24            Skuespil i fire Akter  Gyldendal  unknown
# 25                      Skildringer  Gyldendal  unknown
# 26                            Roman  Gyldendal  unknown
# 36                            roman  Gyldendal    novel
# 42                              NaN  Gyldendal  unknown
#
#                              sesamid
# 10  e7e8524d734b0bab8c2219d349be3c6e
# 11  a36c73ddd25674f39f55c7e233dd0770
# 13  89ee1bececa7b691dafdf6f785b236b7
# 14  be5af477838b99c1ede33603bebc20c8
# 15  fc7c0e985dd11d120bebb9c3f15bffbc
# 16  2b981c264b0802a5fc53a8d432440e98
# 17  f7b71bb94d2eb6269ec46f7db668edc3
# 18  c6be34a1385f8e08463cedd6d8357210
# 19  5a7697d5ef98464f854bcd1ce7a0a66d
# 20  8444ebbd3ae76c073402385f4fb94eff
# 21  3217b178aebb23c537a7b079b6918c47
# 22  9d1f9278a5efbae4d4dd7974884f9b09
# 23  429be57bdf2c1e6fd7e93ff396bb0d93
# 24  e3c975a4d23b31c74aaf84b3dde8f6ac
# 25  ef5a096eec2b9dfd62804ca5206a0b86
# 26  3fc74605bf0797503d11e45bbe7ef46a
# 36  9c37b0255a568e33ba8881fb419a1ca9
# 42  a49e4e77ab01e0e04aff4e71de753dbe
