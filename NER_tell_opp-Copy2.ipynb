# %% [markdown]
# ## Oppstart

# %%
from dhlab.module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Shippori+Mincho';
# 	font-size:1.1em;
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Note that the file `nbtext.py` will be overwritten in the code below
#
# This is probably ok, though. If not, change `update('nbtext', overwrite = True)` to `update('nbtext', overwrite = False)` and the file will stay unchanged.

# %%
import dhlab.nbtext as nb
import dhlab.token_map as tm
from dhlab.nbtext import get_urn, make_graph, get_urn, relaterte_ord, navn, totals
import dhlab.graph_networkx_louvain as gnl
import pandas as pd
# %matplotlib inline

plot = lambda x,  lw=3, alpha= 0.7: x.plot(figsize=(15,6), lw=lw, alpha=alpha)

# %% [markdown]
# # Hjelpekommandoer
#
# I den her notebooken er det satt opp kode for å telle opp navn i et korpus. Både listen med navn og korpuset må foreligge som excelfiler. Noen av kommandoene vil bli lagt til `token_map`-modulen
#
# * `tell_navn` teller opp navnene på tvers av korpuset
# * `korpus_oppføring` finner data i korpuset
# * `vis_bok` viser navn i en spesifikk bok (benytter oppførings-kommandoen)
# * `aggregate_pr_col` aggregerer navnedata over kolonner.

# %%
import pandas as pd
from nbtext import metadata

def alle_korpusnavn(korpus):
    urner = nb.pure_urn(korpus)
    alle_navn = tm.combine_names(tm.corpus_names(urner))
    return alle_navn

def tell_navn(korpus, token_map):
    res = dict()
    for urn in nb.pure_urn(korpus['urn']):
        try:
            res[urn] = tm.count_name_strings(str(urn), token_map)
            res[urn].columns = [str(urn)]
        except:
            print("Problemer med å telle fra: ", metadata(urn))
    return pd.concat([res[u] for u in res], axis=1)

def korpus_oppføring(df, text, column='tittel'):
    return nb.pure_urn(df[df[column].str.contains(text)]['urn'])

def add_metadata(korpus):
    korpus['metadata'] = ['_'.join([str(x) for x in z[2:4]]) for z in nb.metadata(korpus.urn)]
    return True

vis_bok = lambda x, column = 'metadata': nb.frame_sort(nb.frame(opptelling[korpus_oppføring(korpus, x, column)[0]].dropna(), nb.metadata(korpus_oppføring(korpus, x, column)[0])[0][3]))

# %% [markdown]
# ## Navn i bøker
#
#
# Vi søker etter navn i en bok, og en serie av bøker.
#
# Kommandoene er:
# 1. `names` henter et sett med forslag til navn, fra nbtext
# 1. `show_names` gir en oversikt over funnene, fra token_map
# 1. `names_to_token_map_file` lagrer navneforslagene til en excelfil (eller csv) for redigering (token_map)
# 1. `read_token_map_file` henter redigert fil tilbake for analyse (token_map)
# 1. `character_network` lager graf for navnene (token_map)
# 1. `show_graph`  tegner grafen (fra graph_networkx_louvain)
# 1. `show_communities` viser clustre i grafen (graph_networkx_louvain)

# %% [markdown]
# ## Korpus
#
# Hent korpus fra excelfil. Det er korpuset det skal telles opp fra. Husk at korpuset som genererer navn kan godt være forskjellig fra der det telles.

# %%
#korpus = nb.restore_metadata_from_excel('Hamsunkorpus, kronologisk.xls')
korpus = nb.book_corpus(author='hamsun%')

# %% [markdown]
# Neste linje fyller opp en kolonne med en kortversjon av metadata - til senere bruk. Linjen er viktig for å at vis_bok skal fungere (nesten).

# %% [markdown]
# ## Ta en titt på korpuset som tabell

# %%
korpus
# Out:
#               urn         author                       title  year
# 0   2010062306022   Hamsun, Knut              Samlede Verker  1936
# 1   2013012108010   Hamsun, Knut                    Victoria  1959
# 2   2012033008103   Hamsun, Knut                    Sværmere  1972
# 3   2016051148095   Hamsun, Knut  vandrer spiller med sordin  1921
# 4   2013010908035   Hamsun, Knut                Landstrykere  2002
# 5   2010080620015   Hamsun, Knut              Samlede verker  1997
# 6   2008112113001   Hamsun, Knut                  Gaadefulde  1877
# 7   2012012606034   Hamsun, Knut             Samlede romaner  1944
# 8   2007020201064  Hamsun, Arild        Askeladden i gresset  1941
# 9   2014061108229   Hamsun, Knut              Samlede verker  2008
# 10  2009051413002   Hamsun, Knut               Siste kapitel  1923
# 11  2014081908003   Hamsun, Knut              Samlede verker  2009
# 12  2009030300045   Hamsun, Knut                    Victoria  1998
# 13  2008031112002   Hamsun, Knut                       Nälkä  1919
# 14  2011110306011  Hamsun, Arild      Ung mann kommer og går  1939
# 15  2009030900157   Hamsun, Knut                    Victoria  1998
# 16  2013040824021   Hamsun, Knut                  wilde Chor  1926
# 17  2012010508105   Hamsun, Knut              Samlede verker  1954
# 18  2012091908134   Hamsun, Knut              Samlede verker  1963
# 19  2014110508116   Hamsun, Knut                         Pan  2002

# %% [markdown]
# ## Sjekk innholdet
#
# Gjør noen søk for å se at alt er ok. Konkordanser er fine til det.

# %%
nb.urn_concordance(word = 'Skogen', urns = korpus)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010062306022?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede Verker, Hamsun, Knut, 1936</a>
#                 </td>
#                 <td>før og faar ikke denne</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>paa Kredit — for at</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010062306022?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede Verker, Hamsun, Knut, 1936</a>
#                 </td>
#                 <td>Ledelsen at faa Kredit paa</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>i Pistleia . Nu kunde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013012108010?searchText=Skogen' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1959</a>
#                 </td>
#                 <td>kjender ikke alt igjen .</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>er hugget.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051148095?searchText=Skogen' target='_blank' style='text-decoration:none'>vandrer spiller med sordin, Hamsun, Knut, 1921</a>
#                 </td>
#                 <td>og tok den med. I</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>var Inez like i Hælene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051148095?searchText=Skogen' target='_blank' style='text-decoration:none'>vandrer spiller med sordin, Hamsun, Knut, 1921</a>
#                 </td>
#                 <td>Tid tar jeg ind i</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>og vandrer litt omkring derinde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051148095?searchText=Skogen' target='_blank' style='text-decoration:none'>vandrer spiller med sordin, Hamsun, Knut, 1921</a>
#                 </td>
#                 <td>nye Smaahuser høit oppe i</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>og skjønner at der er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051148095?searchText=Skogen' target='_blank' style='text-decoration:none'>vandrer spiller med sordin, Hamsun, Knut, 1921</a>
#                 </td>
#                 <td>. Det forundret mig at</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>var saa stærkt hugget .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016051148095?searchText=Skogen' target='_blank' style='text-decoration:none'>vandrer spiller med sordin, Hamsun, Knut, 1921</a>
#                 </td>
#                 <td>, Jordveien er vanbrukt og</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>har han drevet for stærkt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010080620015?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede verker, Hamsun, Knut, 1997</a>
#                 </td>
#                 <td>er et ondt mirakel .</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>farer ilde og må visst</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012012606034?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede romaner, Hamsun, Knut, 1944</a>
#                 </td>
#                 <td>uhjælpsom mot andre . Da</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>gik i Veiret og han</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012012606034?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede romaner, Hamsun, Knut, 1944</a>
#                 </td>
#                 <td>og Fiskere til Arbeide i</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>, sa han til sin</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012012606034?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede romaner, Hamsun, Knut, 1944</a>
#                 </td>
#                 <td>med at faa Arbeide i</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012012606034?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede romaner, Hamsun, Knut, 1944</a>
#                 </td>
#                 <td>den . Men Tømmeret og</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>det var en vældig Velsignelse</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012012606034?searchText=Skogen' target='_blank' style='text-decoration:none'>Samlede romaner, Hamsun, Knut, 1944</a>
#                 </td>
#                 <td>, de forsvandt tilslut opi</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051413002?searchText=Skogen' target='_blank' style='text-decoration:none'>Siste kapitel, Hamsun, Knut, 1923</a>
#                 </td>
#                 <td>omkring , at se paa</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>som vokste pent og Myrer</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051413002?searchText=Skogen' target='_blank' style='text-decoration:none'>Siste kapitel, Hamsun, Knut, 1923</a>
#                 </td>
#                 <td>var fuldt av Smaabækker i</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>som de hoppet over ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051413002?searchText=Skogen' target='_blank' style='text-decoration:none'>Siste kapitel, Hamsun, Knut, 1923</a>
#                 </td>
#                 <td>en Dame løpende hjem fra</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>, og Herren det var</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051413002?searchText=Skogen' target='_blank' style='text-decoration:none'>Siste kapitel, Hamsun, Knut, 1923</a>
#                 </td>
#                 <td>fast i noget Løy i</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>; men med Kindet ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051413002?searchText=Skogen' target='_blank' style='text-decoration:none'>Siste kapitel, Hamsun, Knut, 1923</a>
#                 </td>
#                 <td>, Marken dynges ned ,</td>
#                 <td>Skogen</td>
#                 <td style='text-align:left'>pudres over , et Fjeld</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009030900157?searchText=Skogen' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1998</a>

# %% [markdown]
# ### Hent redigert fil
#
# Husk at verdien på orient må være lik mellom lagring og lesing av excelfil. Typisk for den her type redigering er radorientering. Excel har en begrensning på 256 kolonner, som blir for smått for de fleste anvendelser. Det er tilnærmet ubegrenset kapasitet på antall rader.

# %%
#redigerte_navn = tm.read_token_map_file("ner-samledeverker.xls", orient = "row")

# %% [markdown]
# ## Tell opp navn med hensyn til det som står i `redigerte_navn`
#
# Bruker hjelpekommando `tell_navn`. Det kan ta litt tid, noen minutter å telle opp.

# %%
redigerte_navn = alle_korpusnavn(korpus)

# %%
redigerte_navn
# Out:
# [Counter({'Aar': 328,
#           'Abel': 936,
#           'Abels': 27,
#           'Aktier': 17,
#           'Aktierne': 27,
#           'Alex': 181,
#           'Alverden': 26,
#           'Amerika': 144,
#           'Angéle': 12,
#           'Ansikt': 39,
#           'Ansiktet': 44,
#           'Apotekeren': 25,
#           'Arbeide': 139,
#           'Arm': 22,
#           'Armbaand': 11,
#           'Armbaandet': 15,
#           'Armen': 29,
#           'Baaten': 63,
#           'Banken': 55,
#           'Barn': 50,
#           'Begyndelsen': 12,
#           'Benk': 12,
#           'Bilen': 11,
#           'Bord': 31,
#           'Bordet': 77,
#           'Brev': 96,
#           'Brevet': 56,
#           'Brodersen': 95,
#           'Broen': 34,
#           'Bror': 52,
#           'Bruket': 61,
#           'Bryggen': 55,
#           'Bud': 28,
#           'Byen': 142,
#           'Bøker': 63,
#           'Bøkerne': 36,
#           'Børn': 299,
#           'Børnene': 36,
#           'Canada': 11,
#           'Carlsen': 55,
#           'Clemens': 161,
#           'Dag': 352,
#           'Dagen': 108,
#           'Dager': 232,
#           'Dame': 82,
#           'Damen': 43,
#           'Damer': 40,
#           'Datter': 36,
#           'Dem': 2661,
#           'Deres': 862,
#           'Dækket': 26,
#           'Døren': 145,
#           'Erend': 13,
#           'Familje': 42,
#           'Familjen': 22,
#           'Fan': 29,
#           'Far': 317,
#           'Farmasøiten': 25,
#           'Farn': 133,
#           'Flaske': 12,
#           'Folk': 425,
#           'Fredriksen': 129,
#           'Fru': 353,
#           'Fruen': 472,
#           'Fyret': 42,
#           'Fører': 13,
#           'Gang': 453,
#           'Gangen': 55,
#           'Ganger': 99,
#           'Gartneriet': 11,
#           'Gaten': 22,
#           'Glas': 69,
#           'Gregersen': 18,
#           'Grund': 110,
#           'Grunden': 37,
#           'Gud': 995,
#           'Gulliksen': 49,
#           'Gut': 59,
#           'Gutten': 74,
#           'Haand': 122,
#           'Haanden': 127,
#           'Haaret': 11,
#           'Halsen': 18,
#           'Hamsun': 107,
#           'Hat': 36,
#           'Hatten': 39,
#           'Hjelp': 25,
#           'Hjem': 55,
#           'Hodet': 188,
#           'Hund': 12,
#           'Hus': 149,
#           'Huset': 114,
#           'Hænder': 87,
#           'Hænderne': 44,
#           'Indtryk': 64,
#           'Ingeniøren': 118,
#           'Kaffe': 52,
#           'Kaptein': 143,
#           'Kapteinen': 377,
#           'Kar': 53,
#           'Kasse': 23,
#           'Kassen': 12,
#           'Kentucky': 22,
#           'Kirken': 62,
#           'Kjole': 12,
#           'Kjøpmand': 23,
#           'Kjørboe': 17,
#           'Klokken': 47,
#           'Klær': 108,
#           'Klærne': 26,
#           'Kone': 108,
#           'Konen': 60,
#           'Kontoret': 26,
#           'Kroner': 76,
#           'Kua': 17,
#           'Kveld': 39,
#           'Kvelden': 20,
#           'Kystbaaten': 13,
#           'Laks': 15,
#           'Land': 83,
#           'Landstedet': 21,
#           'Lawrence': 54,
#           'Lili': 165,
#           'Liv': 122,
#           'Livet': 165,
#           'Lolla': 400,
#           'Lovise': 235,
#           'Luen': 20,
#           'Lugar': 17,
#           'Lys': 31,
#           'Maaned': 11,
#           'Maaneder': 32,
#           'Maate': 111,
#           'Maken': 40,
#           'Mand': 695,
#           'Manden': 238,
#           'Mandskapet': 16,
#           'Maskinen': 11,
#           'Mat': 88,
#           'Melkespand': 12,
#           'Mening': 73,
#           'Menneske': 83,
#           'Mennesker': 122,
#           'Mor': 159,
#           'Morn': 77,
#           'Munden': 68,
#           'Nat': 98,
#           'Natal': 14,
#           'Natten': 63,
#           'Navn': 63,
#           'Numer': 16,
#           'Olga': 272,
#           'Opdrift': 14,
#           'Ord': 266,
#           'Papir': 19,
#           'Par': 245,
#           'Parret': 12,
#           'Passagererne': 11,
#           'Pengene': 99,
#           'Penger': 252,
#           'Pike': 158,
#           'Piken': 97,
#           'Pikerne': 54,
#           'Plass': 62,
#           'Pokker': 45,
#           'Politiet': 17,
#           'Post': 13,
#           'Prat': 56,
#           'Raad': 143,
#           'Regina': 29,
#           'Ret': 87,
#           'Revolveren': 23,
#           'Rieber': 20,
#           'Ringen': 418,
#           'Robertsen': 136,
#           'Rolandsen': 292,
#           'Rum': 60,
#           'Sagbruket': 11,
#           'Sagen': 22,
#           'Sak': 73,
#           'Saken': 58,
#           'Saker': 27,
#           'Seng': 13,
#           'Sengen': 49,
#           'Severin': 18,
#           'Side': 78,
#           'Siden': 89,
#           'Sjaaen': 11,
#           'Sjøen': 43,
#           'Sjømandshjemmet': 24,
#           'Skam': 24,
#           'Skib': 33,
#           'Sko': 11,
#           'Skrædderen': 14,
#           'Skuret': 17,
#           'Skyld': 160,
#           'Slags': 80,
#           'Smaa': 11,
#           'Spurven': 85,
#           'Spørsmaal': 51,
#           'Sted': 131,
#           'Steder': 59,
#           'Stedmor': 11,
#           'Stilling': 13,
#           'Stok': 24,
#           'Stol': 30,
#           'Stolen': 24,
#           'Stoler': 12,
#           'Strandstuen': 15,
#           'Stuen': 76,
#           'Stund': 177,
#           'Styret': 15,
#           'Styrmand': 48,
#           'Styrmanden': 74,
#           'Svar': 68,
#           'Synd': 32,
#           'Søn': 118,
#           'Tak': 278,
#           'Tale': 88,
#           'Tengvald': 21,
#           'Tid': 376,
#           'Tiden': 382,
#           'Tilfælde': 58,
#           'Ting': 247,
#           'Tolder': 37,
#           'Trisa': 75,
#           'Tur': 63,
#           'Turen': 24,
#           'Tusen': 95,
#           'Tøv': 15,
#           'Uke': 32,
#           'Uker': 48,
#           'Ulrik': 56,
#           'Vaaren': 43,
#           'Vafler': 21,
#           'Vand': 25,
#           'Vei': 151,
#           'Veien': 160,
#           'Verden': 128,
#           'Vin': 56,
#           'Vinduet': 46,
#           'Vognen': 12,
#           'Westman': 15,
#           'Øieblik': 138,
#           'Øine': 165,
#           'Øinene': 95,
#           'Camilla': 115,
#           'De': 7363,
#           'Johannes': 511,
#           'Otto': 84,
#           'Richmond': 38,
#           'Slottet': 49,
#           'Slottets': 24,
#           'Victoria': 382,
#           'Elise': 35,
#           'Enok': 52,
#           'Fredrik': 88,
#           'Levion': 46,
#           'Loos': 34,
#           'Mack': 198,
#           'Macks': 43,
#           'Ove': 14,
#           'Rosengaard': 12,
#           'Bruk': 71,
#           'By': 322,
#           'Drageren': 18,
#           'Dreng': 89,
#           'Drengen': 75,
#           'Elisabet': 27,
#           'Elven': 114,
#           'Emma': 15,
#           'Falkenberg': 81,
#           'Fløterne': 16,
#           'Fossen': 11,
#           'Fruens': 36,
#           'Gaarden': 116,
#           'Grindhusen': 123,
#           'Herskapet': 24,
#           'Hestene': 31,
#           'Hester': 12,
#           'Hjælp': 41,
#           'Hovedbygningen': 15,
#           'Hugo': 21,
#           'Husene': 13,
#           'Håar': 40,
#           'Ingeniør': 23,
#           'Inspektøren': 59,
#           'Jorden': 70,
#           'Jordet': 20,
#           'Kapteinens': 14,
#           'Kiær': 13,
#           'Kjøkkenet': 21,
#           'Kvinden': 14,
#           'Kvæld': 119,
#           'Kvælden': 55,
#           'Lampen': 12,
#           'Lars': 370,
#           'Lassen': 124,
#           'Lysthuset': 19,
#           'Maling': 13,
#           'Malingen': 13,
#           'Morgningen': 40,
#           'Nils': 241,
#           'Oplag': 17,
#           'Ragnhild': 101,
#           'Regn': 13,
#           'Rydningen': 14,
#           'Skogen': 68,
#           'Skridt': 48,
#           'Sommer': 27,
#           'Sordin': 12,
#           'Stationen': 42,
#           'Stykke': 33,
#           'Syrinskogen': 17,
#           'Søndag': 11,
#           'Trappen': 19,
#           'Vandrer': 14,
#           'Værelse': 37,
#           'Øvrebø': 40,
#           'Anders': 24,
#           'Ane': 245,
#           'August': 2020,
#           'Augusts': 64,
#           'Beret': 14,
#           'Bergen': 38,
#           'Bodø': 11,
#           'Dokker': 331,
#           'Doppen': 131,
#           'Edevart': 1986,
#           'Edevarts': 46,
#           'Ellingsen': 184,
#           'Ezra': 321,
#           'Fosenlandet': 21,
#           'Gabrielsen': 70,
#           'Guds': 93,
#           'Hosea': 90,
#           'Håbjørg': 66,
#           'Håkon': 65,
#           'Joakim': 533,
#           'Josefine': 28,
#           'Julie': 38,
#           'Karel': 24,
#           'Karolus': 353,
#           'Kleiva': 16,
#           'Knoff': 161,
#           'Knoffs': 23,
#           'Landstrykere': 13,
#           'Levanger': 12,
#           'Lofoten': 54,
#           'Lorensen': 37,
#           'Magnus': 60,
#           'Magrete': 201,
#           'Maria': 241,
#           'Martinus': 22,
#           'Mattea': 77,
#           'Måsen': 24,
#           'Norem': 42,
#           'Papst': 115,
#           'Pauline': 680,
#           'Polden': 349,
#           'Ragna': 196,
#           'Romeo': 91,
#           'Skåro': 66,
#           'Skåros': 12,
#           'Teodor': 302,
#           'Trondhjem': 89,
#           'Tykje': 12,
#           'Våde': 23,
#           'Ytrepolden': 45,
#           'Alexander': 59,
#           'Allah': 20,
#           'Alle': 39,
#           'Alvilde': 15,
#           'Argentina': 16,
#           'Begge': 17,
#           'Boy': 24,
#           'Bridget': 19,
#           'Fanny': 25,
#           'Gihle': 110,
#           'Gior': 15,
#           'Giorgi': 362,
#           'Grimstad': 14,
#           'Juanata': 16,
#           'Juliane': 59,
#           'Kars': 25,
#           'Kleist': 11,
#           'Lynum': 19,
#           'Martin': 88,
#           'Mecedu': 22,
#           'Norge': 28,
#           'Norman': 20,
#           'Oslo': 13,
#           'Pat': 50,
#           'Psykiatrisk': 11,
#           'Rusudan': 19,
#           'Sofiat': 17,
#           'Sorosi': 12,
#           'Tamara': 18,
#           'To': 14,
#           'Tovin': 24,
#           'Ture': 25,
#           'Tåras': 23,
#           'Aa': 15,
#           'Aabakken': 20,
#           'Aae': 24,
#           'Du': 76,
#           'Fader': 19,
#           'Ia': 13,
#           'Ole': 107,
#           'Rolf': 73,
#           'Ronnaug': 85,
#           'Aarene': 23,
#           'Adelheid': 92,
#           'Adelheids': 12,
#           'Alvor': 11,
#           'Ansigt': 46,
#           'Ansigtet': 28,
#           'Anton': 178,
#           'Arbeidere': 32,
#           'Arbeiderne': 29,
#           'Arbeidet': 20,
#           'Aslak': 37,
#           'Baardsen': 257,
#           'Baat': 14,
#           'Barnet': 16,
#           'Ben': 11,
#           'Berlin': 29,
#           'Bertel': 64,
#           'Besked': 24,
#           'Besøk': 12,
#           'Betjent': 22,
#           'Billetter': 13,
#           'Blad': 11,
#           'Bladet': 28,
#           'Blik': 28,
#           'Blod': 11,
#           'Blomster': 13,
#           'Bok': 15,
#           'Brever': 17,
#           'Brillerne': 12,
#           'Brorn': 18,
#           'Brukseieren': 65,
#           'Bryggechefen': 29,
#           'Brynene': 13,
#           'Brystet': 11,
#           'Bua': 310,
#           'Byer': 12,
#           'Bygden': 34,
#           'Cello': 18,
#           'Chefen': 20,
#           'Clara': 60,
#           'Coldevin': 77,
#           'Dagene': 19,
#           'Damerne': 34,
#           'Dansen': 11,
#           'Daverdana': 88,
#           'Del': 17,
#           'Didriksen': 54,
#           'Disken': 12,
#           'Distriktslæge': 19,
#           'Doktor': 100,
#           'Doktoren': 195,
#           'Dunvær': 12,
#           'Dåmen': 17,
#           'Død': 17,
#           'Døden': 17,
#           'Dør': 21,
#           'Døtre': 13,
#           'Eiendom': 12,
#           'Eksempel': 30,
#           'Ende': 24,
#           'England': 32,
#           'Fare': 11,
#           'Farns': 17,
#           'Fars': 20,
#           'Farvel': 24,
#           'Felix': 33,
#           'Fest': 40,
#           'Festen': 19,
#           'Firma': 13,
#           'Fisk': 13,
#           'Flag': 19,
#           'Flaghaugen': 16,
#           'Florina': 71,
#           'Flyglet': 11,
#           'Folkene': 11,
#           'Folket': 12,
#           'Fornøielse': 13,
#           'Forretning': 30,
#           'Forretningen': 11,
#           'Forældre': 20,
#           'Fred': 21,
#           'Fremmede': 37,
#           'Frue': 63,
#           'Frøken': 417,
#           'Fyrstikker': 16,
#           'Følge': 11,
#           'Føtter': 11,
#           'Føtterne': 11,
#           'Gaard': 45,
#           'Gamle': 21,
#           'Gjæster': 12,
#           'Glæde': 32,
#           'Goddag': 21,
#           'Gods': 22,
#           'Godset': 35,
#           'Gottfred': 118,
#           'Graat': 11,
#           'Granden': 22,
#           'Grunde': 12,
#           'Gudskelov': 31,
#           'Guld': 31,
#           'Gulvet': 34,
#           'Haap': 16,
#           'Handel': 35,
#           'Handelen': 22,
#           'Handelsmand': 12,
#           'Handelsreisende': 18,
#           'Hannover': 12,
#           'Harrow': 12,
#           'Haven': 15,
#           'Held': 11,
#           'Helse': 11,
#           'Herre': 57,
#           'Herren': 50,
#           'Herrer': 23,
#           'Herrerne': 61,
#           'Hest': 47,
#           'Hesten': 27,
#           'Himlen': 14,
#           'Hjærte': 18,
#           'Hode': 50,
#           'Hohnengraa': 16,
#           'Holmen': 12,
#           'Holmengraa': 518,
#           'Holmengraas': 70,
#           'Holmsen': 113,
#           'Holmsens': 11,
#           'Hotel': 28,
#           'Hotellet': 34,
#           'Hr.': 774,
#           'Hundrede': 37,
#           'Huser': 11,
#           'Husjomfru': 12,
#           'Husjomfruen': 18,
#           'Høflighet': 13,
#           'Høst': 11,
#           'Høsten': 17,
#           'Ingenting': 17,
#           'Irgens': 86,
#           'Jensen': 56,
#           'Johan': 101,
#           'Jomfru': 71,
#           'Jomfruen': 35,
#           'Jord': 19,
#           'Julius': 295,
#           'Kaape': 11,
#           'Kaffen': 16,
#           'Kaien': 61,
#           'Kald': 11,
#           'Kamerater': 11,
#           'Kanter': 11,
#           'Kasser': 23,
#           'Kirke': 21,
#           'Kjælderen': 18,
#           'Kjæresten': 12,
#           'Kjærlighet': 11,
#           'Kniv': 13,
#           'Kniven': 22,
#           'Kong': 11,
#           'Konge': 28,
#           'Kongen': 22,
#           'Konrad': 61,
#           'Konsul': 56,
#           'Konsulen': 71,
#           'Kontor': 14,
#           'Kornelius': 24,
#           'Kors': 15,
#           'Kort': 16,
#           'Krambod': 18,
#           'Kramboden': 21,
#           'Krig': 11,
#           'Kristiania': 106,
#           'Kristine': 16,
#           'Krop': 11,
#           'Kultur': 12,
#           'Kunst': 13,
#           'Kunstner': 20,
#           'Kvældene': 12,
#           'Landet': 22,
#           'Landmarck': 39,
#           'Larsens': 19,
#           'Latter': 15,
#           'Leilighet': 15,
#           'Lensmand': 22,
#           'Lensmanden': 111,
#           'Lommen': 22,
#           'Lommetørklæde': 14,
#           'Lov': 20,
#           'Luften': 13,
#           'Lydia': 36,
#           'Lykke': 17,
#           'Lyst': 17,
#           'Løitnant': 20,
#           'Løitnanten': 502,
#           'Løitnantens': 43,
#           'Løn': 13,
#           'Maaten': 17,
#           'Magt': 23,
#           'Mands': 19,
#           'Manuelsen': 171,
#           'Manuelsens': 14,
#           'Marcilie': 33,
#           'Mariane': 214,
#           'Marken': 32,
#           'Maskinisten': 14,
#           'Maten': 12,
#           'Max': 27,
#           'Mel': 21,
#           'Meningen': 14,
#           'Menneskene': 42,
#           'Mester': 16,
#           'Mexico': 25,
#           'Middag': 14,
#           'Mine': 19,
#           'Mistanke': 12,
#           'Moritz': 15,
#           'Mund': 65,
#           'Musik': 37,
#           'Muus': 80,
#           'Mænd': 11,
#           'Mændene': 18,
#           'Mærke': 16,
#           'Møllen': 20,
#           'Nakken': 12,
#           'Naustet': 20,
#           'Nordland': 14,
#           'Nytte': 15,
#           'Nætterne': 12,
#           'Nøklen': 13,
#           'Opmærksomhet': 13,
#           'Orden': 23,
#           'Ordre': 17,
#           'Paafund': 14,
#           'Papa': 19,
#           'Per': 134,
#           'Piano': 12,
#           'Piker': 33,
#           'Plan': 13,
#           'Postskibet': 12,
#           'Primadonna': 21,
#           'Pris': 16,
#           'Præst': 35,
#           'Præsten': 160,
#           'Rasch': 176,
#           'Raschs': 11,
#           'Redaktøren': 15,
#           'Reiret': 14,
#           'Reise': 21,
#           'Reisende': 13,
#           'Respekt': 18,
#           'Rikdom': 21,
#           'Ring': 22,
#           'Ro': 14,
#           'Røst': 38,
#           'Sagvika': 30,
#           'Sakfører': 161,
#           'Sakføreren': 253,
#           'Sakførerens': 11,
#           'Salvesen': 63,
#           'Sang': 21,
#           'Seddel': 13,
#           'Sedler': 12,
#           'Segelfoss': 574,
#           'Selskap': 30,
#           'Sibylle': 24,
#           'Sind': 16,
#           'Sjura': 54,
#           'Sjæl': 19,
#           'Skade': 13,
#           'Skibet': 27,
#           'Skillinger': 12,
#           'Skjæbne': 38,
#           'Skog': 37,
#           'Skole': 17,
#           'Skomaker': 79,
#           'Skomakeren': 13,
#           'Skudd': 15,
#           'Slag': 39,
#           'Slægt': 17,
#           'Smak': 12,
#           'Smil': 18,
#           'Sommeren': 14,
#           'Spil': 19,
#           'Spor': 26,
#           'Sprog': 46,
#           'Spøk': 29,
#           'Stas': 20,
#           'Stedet': 85,
#           'Sten': 38,
#           'Stue': 51,
#           'Stuer': 24,
#           'Stuerne': 19,
#           'Stykket': 13,
#           'Støvler': 16,
#           'Sum': 20,
#           'Sving': 15,
#           'Sækker': 12,
#           'Sølv': 18,
#           'Sønnen': 55,
#           'Søster': 13,
#           'Søstre': 15,
#           'Tanker': 15,
#           'Tap': 15,
#           'Taushet': 12,
#           'Teater': 30,
#           'Teatret': 27,
#           'Teglværket': 37,
#           'Telegrafbestyrer': 13,
#           'Telegrafbestyreren': 17,
#           'Telegrafist': 24,
#           'Telegrafisten': 32,
#           'Telegram': 25,
#           'Theodor': 532,
#           'Theodors': 20,
#           'Tidende': 42,
#           'Tider': 19,
#           'Time': 13,
#           'Timer': 17,
#           'Tjener': 15,
#           'Tjeneste': 29,
#           'Tobak': 11,
#           'Tobias': 31,
#           'Tokrone': 11,
#           'Tomt': 12,
#           'Tomten': 14,
#           'Tone': 16,
#           'Truppen': 18,
#           'Træk': 19,
#           'Trøie': 12,
#           'Tvil': 28,
#           'Tøi': 14,
#           'Tømmer': 25,
#           'Ung': 96,
#           'Ungdommen': 13,
#           'Ura': 22,
#           'Utvær': 18,
#           'Vaar': 15,
#           'Varer': 25,
#           'Veiene': 15,
#           'Veiret': 20,
#           'Vel': 15,
#           'Velsignelse': 11,
#           'Ven': 41,
#           'Venner': 21,
#           'Vilje': 24,
#           'Vinduer': 11,
#           'Vinduerne': 15,
#           'Vinter': 13,
#           'Vinteren': 22,
#           'Virksomhet': 20,
#           'Visit': 13,
#           'Væg': 15,
#           'Væggen': 15,
#           'Vælta': 17,
#           'Vært': 11,
#           'Værten': 20,
#           'Willatz': 608,
#           'Ære': 15,
#           'Ærend': 34,
#           'Æventyret': 12,
#           'Øie': 11,
#           'Ønske': 13,
#           'Øre': 12,
#           'Jeg': 27,
#           'Adolf': 27,
#           'Andersen': 12,
#           'Berntsen': 70,
#           'Davidsen': 31,
#           'Fia': 143,
#           'Frank': 144,
#           'Gryn-Olsen': 16,
#           'Gryn-Olsens': 20,
#           'Heia': 15,
#           'Heibergs': 11,
#           'Henriksen': 51,
#           'Johnsen': 193,
#           'Johnsens': 38,
#           'Jørgen': 103,
#           'Kasper': 16,
#           'Konene': 11,
#           'Lillelydia': 81,
#           'Maren': 65,
#           'Mattis': 143,
#           'Olaus': 86,
#           'Oliver': 793,
#           'Olivers': 34,
#           'Olsen': 66,
#           'Olsens': 17,
#           'Petra': 257,
#           'Reinert': 57,
#           'Salt': 32,
#           'Scheldrup': 113,
#           'Stortinget': 14,
#           'Tegnestiften': 18,
#           'Vangen': 27,
#           'Berget': 13,
#           'Bertelsen': 298,
#           'Bladene': 24,
#           'Bryst': 11,
#           'Daniel': 518,
#           'Daniels': 44,
#           'Dyret': 12,
#           'Espard': 407,
#           'Eyde': 33,
#           'Fleming': 331,
#           'Flemings': 37,
#           'Fransk': 21,
#           'Frøkenen': 113,
#           'Gj': 18,
#           'Gjester': 37,
#           'Greve': 13,
#           'Greven': 17,
#           'Helena': 56,
#           'Kamerat': 12,
#           'Kameraten': 11,
#           'Kapitel': 17,
#           'Lensmandsbetj': 11,
#           'Moss': 335,
#           'Mylady': 36,
#           'Oksen': 51,
#           'Oldfruen': 22,
#           'Pokkers': 11,
#           'Postbudet': 24,
#           'Regning': 11,
#           'Rektor': 77,
#           'Ruben': 134,
#           'Saar': 15,
#           'Sanatoriet': 57,
#           'Sanatoriets': 13,
#           'Sanatorium': 19,
#           'Selskapet': 19,
#           'Selvmorderen': 166,
#           'Siste': 17,
#           'Sveitseren': 38,
#           'Sæter': 22,
#           'Torahus': 130,
#           'Bank': 11,
#           'Ester': 21,
#           'Fuglværø': 13,
#           'Indrebygden': 44,
#           'Iversen': 34,
#           'Kristofer': 66,
#           'Lyder': 11,
#           'Milde': 14,
#           'Ottesen': 33,
#           'Paulines': 13,
#           'Poldens': 32,
#           'Roderik': 50,
#           'Sparebank': 12,
#           'Abend': 17,
#           'Arbeit': 12,
#           'Auge': 11,
#           'Augen': 37,
#           'Augenblick': 23,
#           'Bewegung': 12,
#           'Blumen': 11,
#           'Boot': 18,
#           'Brief': 19,
#           'Buch': 16,
#           'CamiUa': 11,
#           'Erde': 24,
#           'Fenster': 33,
#           'Frau': 46,
#           'Freude': 16,
#           'Fråulein': 15,
#           'Garten': 25,
#           'Gesicht': 34,
#           'Gliick': 11,
#           'Gott': 49,
#           'Hand': 60,
#           'Haus': 21,
#           'Hause': 57,
#           'Hauslehrer': 16,
#           'Heber': 11,
#           'Herr': 20,
#           'Herz': 20,
#           'Heß': 11,
#           'Hut': 12,
#           'Hånde': 19,
#           'Ihnen': 87,
#           'Ihr': 18,
#           'Ihre': 22,
#           'Jahre': 25,
#           'Kammerherrn': 12,
#           'Kleid': 16,
#           'Kopf': 33,
#           'Leben': 33,
#           'Leutnant': 19,
#           'Liebe': 30,
#           'Mama': 14,
#           'Mann': 72,
#           'Menschen': 23,
#           'Miihle': 19,
#           'Mliller': 22,
#           'Mlitze': 14,
#           'Mutter': 11,
#           'Mådchen': 24,
#           'Nacht': 39,
#           'Nåmen': 17,
#           'Platz': 14,
#           'Rede': 12,
#           'Rose': 11,
#           'Ruhe': 12,
#           'Schiff': 16,
#           'Schloß': 25,
#           'Schloßherr': 18,
#           'Schloßherrin': 15,
#           'Seite': 16,
#           'Sic': 601,
#           'Sie': 57,
#           'Sonne': 15,
#           'Stadt': 27,
#           'Stein': 15,
#           'Stimme': 17,
#           'Straße': 27,
#           'Stuhl': 13,
#           'Stunde': 18,
#           'Tag': 36,
#           'Tlir': 18,
#           'Tod': 11,
#           'Tågen': 12,
#           'Uer': 11,
#           'Uhr': 15,
#           'Vater': 13,
#           'Wagen': 19,
#           'Wald': 23,
#           'Wasser': 13,
#           'Weg': 42,
#           'Weit': 17,
#           'Worte': 19,
#           'Zeit': 22,
#           'Zimmer': 19,
#           'Ei': 120,
#           'Hans': 12,
#           'Jumala': 34,
#           'Jumalan': 17,
#           'Kyllå': 27,
#           'Minå': 11,
#           'No': 51,
#           'Ooh': 14,
#           'Alfred': 11,
#           'Arild': 11,
#           'Frankrike': 18,
#           'Friedel': 13,
#           'Hanne': 21,
#           'Hvad': 39,
#           'Hvor': 16,
#           'Ja': 44,
#           'Jo': 14,
#           'Koln': 11,
#           'Krause': 13,
#           'Mario': 16,
#           'Miiller': 20,
#           'Nanna': 28,
#           'Naper': 11,
#           'Nei': 47,
#           'Olaf': 52,
#           'Paris': 50,
#           'Ursula': 13,
#           'Vika': 16,
#           'Ank': 24,
#           'Ano': 58,
#           'Dann': 17,
#           'Das': 35,
#           'Den': 17,
#           'Der': 56,
#           'Die': 70,
#           'Doch': 19,
#           'Es': 12,
#           'Gin': 18,
#           'Hein': 11,
#           'Himmel': 13,
#           'Kas': 11,
#           'Ken': 15,
#           'Ker': 16,
#           'Kie': 11,
#           'Ku': 20,
#           'Lon': 17,
#           'Mein': 14,
#           'Mit': 22,
#           'Os': 44,
#           'Sin': 17,
#           'So': 17,
#           'Sott': 13,
#           'Vom': 11,
#           'Von': 11,
#           'Waloe': 11,
#           'Welt': 15,
#           'Wie': 57,
#           ...}),
#  Counter({('Kaptein', 'Brodersen'): 12,
#           ('Tolder', 'Robertsen'): 30,
#           ('Lovise', 'Rolandsen'): 11,
#           ('Abels', 'Mor'): 2,
#           ('Abels', 'Haand'): 2,
#           ('Rieber', 'Carlsen'): 17,
#           ('Par', 'Ganger'): 16,
#           ('Gutten', 'Abel'): 1,
#           ('Abels', 'Tid'): 1,
#           ('Par', 'Stoler'): 1,
#           ('Familjen', 'Robertsen'): 3,
#           ('Styrmand', 'Robertsen'): 1,
#           ('Rieber', 'Ringen'): 1,
#           ('Mand', 'Ringen'): 1,
#           ('Parret', 'Clemens'): 2,
#           ('Kaptein', 'Kjørboe'): 1,
#           ('Hodet', 'Robertsen'): 1,
#           ('Tusen', 'Kroner'): 30,
#           ('Abel', 'Pengene'): 1,
#           ('Abel', 'Brodersen'): 12,
#           ('Abels', 'Far'): 1,
#           ('Slags', 'Folk'): 5,
#           ('Fru', 'Olga'): 2,
#           ('Flaske', 'Vin'): 1,
#           ('Lolla', 'Vin'): 1,
#           ('Fru', 'Clemens'): 5,
#           ('Glas', 'Vin'): 7,
#           ('Kjøpmand', 'Gulliksen'): 5,
#           ('Fru', 'Fredriksen'): 8,
#           ('Par', 'Spørsmaal'): 3,
#           ('Par', 'Maaneder'): 3,
#           ('Navn', 'Abel'): 1,
#           ('Parret', 'Robertsen'): 1,
#           ('Ulrik', 'Fredriksen'): 12,
#           ('Tusen', 'Tak'): 7,
#           ('Abels', 'Ansikt'): 2,
#           ('Kaptein', 'Ulrik'): 22,
#           ('Revolveren', 'Angéle'): 1,
#           ('Far', 'Aktierne'): 1,
#           ('Olga', 'Clemens'): 1,
#           ('Stedmor', 'Lolla'): 1,
#           ('Rolandsen', 'Børn'): 1,
#           ('Par', 'Kroner'): 3,
#           ('Benk', 'Ringen'): 1,
#           ('Gangen', 'Olga'): 1,
#           ('Abel', 'Bordet'): 1,
#           ('Slags', 'Stilling'): 1,
#           ('Par', 'Tusen'): 1,
#           ('Mand', 'Hodet'): 1,
#           ('Far', 'Deres'): 1,
#           ('Deres', 'Søn'): 3,
#           ('Kaptein', 'Fredriksen'): 6,
#           ('Deres', 'Alex'): 1,
#           ('Par', 'Sko'): 1,
#           ('Farmasøiten', 'Damen'): 1,
#           ('Fru', 'Brodersen'): 4,
#           ('Parret', 'Farmasøiten'): 1,
#           ('Par', 'Dager'): 15,
#           ('Alex', 'Lili'): 1,
#           ('Lugar', 'Numer'): 2,
#           ('Fru', 'Gulliksen'): 5,
#           ('Fru', 'Robertsen'): 1,
#           ('Trisa', 'Deres'): 1,
#           ('Kaptein', 'Abel'): 3,
#           ('Gud', 'Ringen'): 1,
#           ('Byen', 'Natal'): 2,
#           ('Brodersen', 'Clemens'): 1,
#           ('Abels', 'Navn'): 1,
#           ('Slags', 'Mand'): 1,
#           ('Mand', 'Lawrence'): 1,
#           ('Styrmand', 'Gregersen'): 6,
#           ('Gregersen', 'Fører'): 1,
#           ('Styrmand', 'Alex'): 2,
#           ('Halsen', 'Deres'): 2,
#           ('Deres', 'Aktier'): 1,
#           ('Fru', 'Ingeniøren'): 1,
#           ('Par', 'Aktier'): 1,
#           ('Manden', 'Deres'): 1,
#           ('Kar', 'Gulliksen'): 1,
#           ('Hatten', 'Deres'): 2,
#           ('Fru', 'Tolder'): 1,
#           ('Menneske', 'Regina'): 1,
#           ('Kone', 'Olga'): 2,
#           ('Olga', 'Gulliksen'): 1,
#           ('Par', 'Uker'): 8,
#           ('Dem', 'Folk'): 1,
#           ('Bror', 'Ulrik'): 1,
#           ('Dem', 'Kveld'): 1,
#           ('Par', 'Mand'): 1,
#           ('Deres', 'Vei'): 4,
#           ('Menneske', 'Olga'): 1,
#           ('Baaten', 'Deres'): 2,
#           ('Dem', 'De'): 2,
#           ('Johannes', 'Johannes'): 1,
#           ('De', 'Otto'): 2,
#           ('De', 'Victoria'): 2,
#           ('Gud', 'De'): 2,
#           ('Ove', 'Rolandsen'): 6,
#           ('Fredrik', 'Mack'): 5,
#           ('Elise', 'Mack'): 10,
#           ('Fredrik', 'Macks'): 1,
#           ('De', 'Olga'): 1,
#           ('Olga', 'Rolandsen'): 1,
#           ('Dem', 'Deres'): 2,
#           ('De', 'Dem'): 24,
#           ('Mack', 'Fredrik'): 1,
#           ('Par', 'Ord'): 17,
#           ('Fru', 'Lovise'): 1,
#           ('Gang', 'Hestene'): 1,
#           ('Lars', 'Falkenberg'): 24,
#           ('Piken', 'Emma'): 1,
#           ('Par', 'Børn'): 3,
#           ('Kaptein', 'Falkenberg'): 17,
#           ('Fru', 'Falkenberg'): 37,
#           ('Kaptein', 'Bror'): 9,
#           ('Fru', 'Elisabet'): 1,
#           ('Ingeniør', 'Lassen'): 17,
#           ('Gaarden', 'Nils'): 1,
#           ('Fruens', 'Værelse'): 8,
#           ('Fruen', 'Brevet'): 1,
#           ('Gang', 'Fruen'): 1,
#           ('Menneske', 'Tiden'): 1,
#           ('Nils', 'Dreng'): 32,
#           ('Elven', 'Morgningen'): 1,
#           ('Par', 'Øine'): 2,
#           ('Hugo', 'Lassen'): 1,
#           ('Par', 'Mennesker'): 1,
#           ('Kapteinens', 'Brev'): 1,
#           ('Slags', 'Maling'): 1,
#           ('Kapteinen', 'Tid'): 1,
#           ('Kapteinen', 'Hodet'): 1,
#           ('Fruens', 'Brev'): 1,
#           ('Fruens', 'Øine'): 1,
#           ('Slags', 'Ord'): 1,
#           ('Slags', 'Øine'): 1,
#           ('Kapteinens', 'Øine'): 1,
#           ('Dager', 'Drengen'): 1,
#           ('Par', 'Skridt'): 3,
#           ('Kapteinen', 'Klokken'): 1,
#           ('Par', 'Ting'): 2,
#           ('Mand', 'Folk'): 1,
#           ('Ane', 'Maria'): 239,
#           ('Lovise', 'Magrete'): 201,
#           ('Magrete', 'Doppen'): 7,
#           ('Håkon', 'Doppen'): 20,
#           ('Romeo', 'Knoff'): 2,
#           ('Anders', 'Våde'): 23,
#           ('Julie', 'Knoff'): 1,
#           ('Hosea', 'Ezra'): 1,
#           ('Giorgi', 'Giorgi'): 3,
#           ('Juliane', 'Gihle'): 1,
#           ('Fanny', 'Norman'): 1,
#           ('De', 'Deres'): 7,
#           ('Ole', 'Aae'): 11,
#           ('Ronnaug', 'Aae'): 3,
#           ('Far', 'Aae'): 1,
#           ('Ia', 'Du'): 1,
#           ('Ole', 'Aa'): 2,
#           ('Fader', 'Aae'): 1,
#           ('Gaarden', 'Segelfoss'): 1,
#           ('Hr.', 'Willatz'): 19,
#           ('Willatz', 'Holmsen'): 82,
#           ('Tiden', 'Skridt'): 1,
#           ('Husjomfruen', 'Jomfru'): 2,
#           ('Jomfru', 'Salvesen'): 57,
#           ('Slags', 'Smak'): 1,
#           ('Deres', 'Far'): 14,
#           ('Far', 'Ret'): 1,
#           ('Fru', 'Adelheid'): 41,
#           ('Løitnantens', 'Ansigt'): 2,
#           ('Godset', 'Segelfoss'): 3,
#           ('Ole', 'Johan'): 75,
#           ('Deres', 'Sang'): 2,
#           ('Deres', 'Røst'): 2,
#           ('Deres', 'Stol'): 1,
#           ('Fruens', 'Stuer'): 1,
#           ('Tiden', 'Kirken'): 1,
#           ('Deres', 'Dager'): 1,
#           ('Tid', 'Barnet'): 1,
#           ('Dreng', 'Martin'): 2,
#           ('Gaarden', 'Ura'): 1,
#           ('Fruens', 'Leilighet'): 1,
#           ('Guds', 'Hjælp'): 5,
#           ('Distriktslæge', 'Ole'): 1,
#           ('Løitnant', 'Willatz'): 4,
#           ('Willatz', 'Holmsens'): 4,
#           ('Fru', 'Holmsens'): 1,
#           ('By', 'Hannover'): 1,
#           ('Lars', 'Manuelsen'): 162,
#           ('Gutten', 'Lars'): 10,
#           ('Daverdana', 'Løitnanten'): 1,
#           ('Søn', 'Willatz'): 1,
#           ('Holmsen', 'De'): 1,
#           ('Fruen', 'Moritz'): 1,
#           ('Piken', 'Marcilie'): 7,
#           ('Spor', 'Tid'): 1,
#           ('Hr.', 'Holmsen'): 9,
#           ('Hr.', 'Holmengraa'): 360,
#           ('Tobias', 'Holmengraa'): 5,
#           ('Løitnantens', 'Stuer'): 3,
#           ('Deres', 'Helse'): 3,
#           ('Holmengraa', 'Øie'): 1,
#           ('Kong', 'Tobias'): 8,
#           ('Fruens', 'Far'): 2,
#           ('Mands', 'Svar'): 1,
#           ('Hr.', 'Holmengraas'): 50,
#           ('Hr.', 'Løitnanten'): 10,
#           ('Deres', 'Mening'): 4,
#           ('Løitnantens', 'Stue'): 2,
#           ('Jomfru', 'Kristine'): 2,
#           ('Kristine', 'Salvesen'): 3,
#           ('Hr.', 'Løitnant'): 7,
#           ('Doktor', 'De'): 1,
#           ('Deres', 'Doktor'): 1,
#           ('Lars', 'Manuelsens'): 14,
#           ('Søn', 'Fredrik'): 1,
#           ('Tiden', 'Julius'): 2,
#           ('Fare', 'Børn'): 1,
#           ('Selskap', 'Julius'): 1,
#           ('Fredrik', 'Coldevin'): 19,
#           ('Fru', 'Holmsen'): 3,
#           ('Piken', 'Daverdana'): 6,
#           ('Gamle', 'Fru'): 2,
#           ('Fru', 'Coldevin'): 4,
#           ('Gamle', 'Coldevin'): 1,
#           ('Hr.', 'Konsul'): 6,
#           ('Mands', 'Sted'): 1,
#           ('Konsul', 'Fredrik'): 24,
#           ('Søn', 'Anton'): 1,
#           ('Ven', 'Løitnanten'): 2,
#           ('Hr.', 'Hohnengraa'): 13,
#           ('Konsulen', 'Fru'): 2,
#           ('Coldevin', 'Besked'): 1,
#           ('Løitnantens', 'Arm'): 1,
#           ('Konsul', 'Coldevin'): 5,
#           ('Tak', 'Elven'): 1,
#           ('Slags', 'Handel'): 1,
#           ('Tiden', 'Børn'): 2,
#           ('Mand', 'Tobias'): 1,
#           ('Deres', 'Arbeidere'): 2,
#           ('Hr.', 'Coldevin'): 3,
#           ('Ven', 'Konsulen'): 1,
#           ('Deres', 'Hjærte'): 1,
#           ('Deres', 'Haand'): 5,
#           ('Kjæresten', 'Deres'): 1,
#           ('Løitnanten', 'Piken'): 1,
#           ('Fruens', 'Ansigt'): 1,
#           ('Deres', 'Reise'): 2,
#           ('Deres', 'Piker'): 1,
#           ('Holmengraas', 'Arbeidere'): 2,
#           ('Deres', 'Dør'): 1,
#           ('Adelheids', 'Vinduer'): 1,
#           ('Mand', 'Willatz'): 1,
#           ('Fru', 'Adelheids'): 3,
#           ('Manuelsens', 'Hus'): 1,
#           ('Gamle', 'Lars'): 2,
#           ('Segelfoss', 'Gaard'): 8,
#           ('Deres', 'Sted'): 1,
#           ('Deres', 'Eiendom'): 1,
#           ('Løitnanten', 'Holmengraa'): 1,
#           ('Stund', 'Adelheid'): 1,
#           ('Farns', 'Glæde'): 1,
#           ('Tusen', 'Ord'): 2,
#           ('Mine', 'Børn'): 1,
#           ('Par', 'Timer'): 4,
#           ('Frue', 'Løitnanten'): 1,
#           ('Deres', 'Folk'): 3,
#           ('Deres', 'Børn'): 3,
#           ('Par', 'Bruk'): 1,
#           ('Holmengraas', 'Selskap'): 1,
#           ('Tid', 'Fru'): 1,
#           ('Glas', 'Vand'): 1,
#           ('Siden', 'Willatz'): 1,
#           ('Tiden', 'Løitnanten'): 1,
#           ('Deres', 'Hode'): 2,
#           ('Tiden', 'De'): 1,
#           ('Segelfoss', 'Gods'): 14,
#           ('Tobias', 'Konge'): 2,
#           ('Hr.', 'Løitnantens'): 1,
#           ('Deres', 'Pris'): 1,
#           ('Holmengraas', 'Børn'): 2,
#           ('Gutten', 'Felix'): 1,
#           ('Fru', 'Irgens'): 80,
#           ('Søn', 'Lars'): 1,
#           ('Ung', 'Willatz'): 91,
#           ('Pikerne', 'Hænderne'): 1,
#           ('Martin', 'Dreng'): 49,
#           ('Willatz', 'Vand'): 1,
#           ('Willatz', 'Kniven'): 1,
#           ('Gottfred', 'Haanden'): 1,
#           ('Segelfoss', 'Grund'): 2,
#           ('Manuelsens', 'Stue'): 2,
#           ('Doktor', 'Muus'): 51,
#           ('Hr.', 'Doktor'): 3,
#           ('Holmengraas', 'Virksomhet'): 3,
#           ('Deres', 'Bruk'): 1,
#           ('Tiden', 'Willatz'): 1,
#           ('Deres', 'Martin'): 1,
#           ('Gang', 'De'): 4,
#           ('De', 'Martin'): 1,
#           ('Hr.', 'Muus'): 6,
#           ('Tobias', 'Doktoren'): 1,
#           ('Holmengraas', 'Magt'): 1,
#           ('Hr.', 'Holmen'): 2,
#           ('Holmengraas', 'Øine'): 1,
#           ('Deres', 'Ønske'): 2,
#           ('Sønnen', 'Lars'): 1,
#           ('Kald', 'Julius'): 1,
#           ('Løitnanten', 'Raad'): 1,
#           ('Ganger', 'Haanden'): 1,
#           ('Fru', 'Fredrik'): 1,
#           ('Manuelsens', 'Søn'): 2,
#           ('Fars', 'Lars'): 1,
#           ('Hundrede', 'Tusen'): 1,
#           ('Hr.', 'Rasch'): 4,
#           ('Holmengraas', 'Ønske'): 1,
#           ('Tiden', 'Hr.'): 1,
#           ('Løitnantens', 'Skog'): 1,
#           ('Frue', 'Fru'): 1,
#           ('Holmengraas', 'Hat'): 1,
#           ('Fars', 'Tid'): 2,
#           ('Hænderne', 'Børn'): 1,
#           ('Par', 'Aar'): 5,
#           ('Fruens', 'Tjener'): 1,
#           ('Gutten', 'Gottfred'): 1,
#           ('De', 'Bruk'): 1,
#           ('Holmengraas', 'Hus'): 14,
#           ('Gud', 'Børn'): 1,
#           ('Anton', 'Coldevin'): 22,
#           ('Ung', 'Anton'): 1,
#           ('Farns', 'Forretning'): 1,
#           ('Gottfred', 'Børn'): 1,
#           ('Guds', 'Navn'): 3,
#           ('Farns', 'Tale'): 1,
#           ('Tusen', 'Aar'): 1,
#           ('Distriktslæge', 'Muus'): 18,
#           ('Adelheids', 'Haand'): 1,
#           ('Holmengraas', 'Ansigt'): 4,
#           ('Par', 'Grunde'): 1,
#           ('Spørsmaal', 'Hr.'): 1,
#           ('Deres', 'Frue'): 1,
#           ('Tiden', 'Fru'): 1,
#           ('Fars', 'Dager'): 2,
#           ('Søster', 'Pauline'): 1,
#           ('Husjomfru', 'Salvesen'): 2,
#           ('Deres', 'Mund'): 2,
#           ('Segelfoss', 'Kirke'): 1,
#           ('Hr.', 'Lassen'): 8,
#           ('Tak', 'Vinduerne'): 1,
#           ('Guds', 'Ord'): 1,
#           ('Husjomfru', 'Jomfru'): 4,
#           ('Præsten', 'Lassen'): 34,
#           ('Fruens', 'Ven'): 1,
#           ('Hundrede', 'Aar'): 4,
#           ('Adelheids', 'Død'): 1,
#           ('Fruens', 'Død'): 1,
#           ('Tid', 'Løitnanten'): 1,
#           ('Sakfører', 'Rasch'): 107,
#           ('Deres', 'Indtryk'): 1,
#           ('Løitnantens', 'Gaard'): 1,
#           ('Dreng', 'Ordre'): 1,
#           ('Løitnantens', 'Ønske'): 1,
#           ('Holmengraas', 'Folk'): 1,
#           ('Løitnantens', 'Røst'): 2,
#           ('Øieblik', 'Præsten'): 1,
#           ('Fredrik', 'Haanden'): 1,
#           ('Par', 'Brever'): 1,
#           ('Piken', 'Haanden'): 1,
#           ('Farns', 'Stue'): 1,
#           ('Adelheids', 'Navn'): 1,
#           ('Telegrafist', 'Baardsen'): 19,
#           ('Nils', 'Skomaker'): 76,
#           ('Arm', 'Børn'): 1,
#           ('Haanden', 'Deres'): 1,
#           ('Par', 'Stuer'): 1,
#           ('Adelheids', 'Tjeneste'): 1,
#           ('Hundrede', 'Ganger'): 2,
#           ('Stykke', 'Jord'): 1,
#           ('Hr.', 'Børn'): 1,
#           ('Far', 'Lars'): 1,
#           ('Tiden', 'Jord'): 1,
#           ('Holmengraas', 'Ærend'): 1,
#           ('Løitnanten', 'Grunden'): 1,
#           ('Dag', 'Brev'): 1,
#           ('Eksempel', 'Hr.'): 1,
#           ('Sakfører', 'Raschs'): 8,
#           ('Del', 'Kunst'): 1,
#           ('Løitnantens', 'Vilje'): 1,
#           ('De', 'Tid'): 1,
#           ('Mands', 'Selskap'): 1,
#           ('Fru', 'Rasch'): 50,
#           ('Salvesen', 'Børn'): 1,
#           ('Løitnanten', 'Bruk'): 1,
#           ('Segelfoss', 'By'): 281,
#           ('Larsens', 'Hotel'): 19,
#           ('Manuelsens', 'Familje'): 1,
#           ('Mands', 'Far'): 5,
#           ('Mand', 'Hr.'): 2,
#           ('Frøken', 'Mariane'): 51,
#           ('Løitnantens', 'Dager'): 2,
#           ('Fru', 'Sakfører'): 11,
#           ('De', 'Dager'): 1,
#           ('Sønnen', 'Theodor'): 1,
#           ('Folk', 'Ung'): 1,
#           ('Julius', 'Larsens'): 1,
#           ('Huset', 'Holmsen'): 1,
#           ('Tjener', 'Aslak'): 1,
#           ('Løitnant', 'Holmsen'): 1,
#           ('Segelfoss', 'Bruk'): 1,
#           ('Segelfoss', 'Tidende'): 42,
#           ('Gutten', 'Theodor'): 8,
#           ('Gamle', 'Per'): 2,
#           ('Theodor', 'Jensen'): 16,
#           ('Navn', 'Mat'): 1,
#           ('Fars', 'Stuer'): 1,
#           ('Piker', 'Del'): 1,
#           ('Tusen', 'Ting'): 1,
#           ('Florina', 'Pike'): 22,
#           ('Pikerne', 'Turen'): 1,
#           ('Kornelius', 'Betjent'): 10,
#           ('Kornelius', 'Segelfoss'): 1,
#           ('Hr.', 'Didriksen'): 33,
#           ('Theodors', 'Ordre'): 1,
#           ('De', 'Ret'): 5,
#           ('Søn', 'Ung'): 1,
#           ('Hr.', 'Jensen'): 8,
#           ('Hr.', 'Baardsen'): 10,
#           ('Dunvær', 'De'): 1,
#           ('Hr.', 'Theodor'): 9,
#           ('Kjøpmand', 'Theodor'): 1,
#           ('Musik', 'Huset'): 1,
#           ('Deres', 'Musik'): 1,
#           ('Slag', 'Kort'): 2,
#           ('Par', 'Sedler'): 1,
#           ('Handelsmand', 'Penger'): 1,
#           ('Hundrede', 'Kroner'): 8,
#           ('Telegrafbestyrer', 'Baardsen'): 12,
#           ('Deres', 'Held'): 1,
#           ('Deres', 'Plass'): 1,
#           ('Dem', 'Ret'): 1,
#           ('Hr.', 'Holmsens'): 3,
#           ('By', 'De'): 2,
#           ('Bror', 'Felix'): 1,
#           ('Holmengraa', 'Lensmanden'): 1,
#           ('Fru', 'Landmarck'): 21,
#           ('Præsten', 'Landmarck'): 9,
#           ('Aar', 'Gudskelov'): 1,
#           ('By', 'Kroner'): 1,
#           ('Deres', 'Skyld'): 1,
#           ('Fru', 'Segelfoss'): 1,
#           ('Spøk', 'Frøken'): 1,
#           ('Holmengraas', 'Liv'): 1,
#           ('Raschs', 'Tur'): 1,
#           ('Glæde', 'Segelfoss'): 1,
#           ('Theodors', 'Mor'): 1,
#           ('Deres', 'Grund'): 2,
#           ('Sønnen', 'Felix'): 1,
#           ('Tid', 'Farn'): 1,
#           ('Fars', 'Børn'): 1,
#           ('Manuelsens', 'Kone'): 1,
#           ('Del', 'Aar'): 1,
#           ('Byen', 'Segelfoss'): 2,
#           ('Hr.', 'Lensmanden'): 1,
#           ('De', 'Teater'): 1,
#           ('Dem', 'Segelfoss'): 1,
#           ('Handelsreisende', 'Didriksen'): 2,
#           ('Dokker', 'Folk'): 1,
#           ('By', 'Julius'): 1,
#           ('De', 'Hundrede'): 1,
#           ('Holmengraas', 'Blik'): 1,
#           ('Slags', 'Ring'): 2,
#           ('Manuelsens', 'Ærend'): 1,
#           ('By', 'Vinter'): 1,
#           ('Manuelsens', 'Børn'): 1,
#           ('Bror', 'Lassen'): 1,
#           ('De', 'Reisende'): 1,
#           ('Julius', 'Raad'): 1,
#           ('Par', 'Hundrede'): 4,
#           ('Goddag', 'Julius'): 1,
#           ('Fru', 'Kristine'): 3,
#           ('Holmsens', 'Bord'): 1,
#           ('By', 'Fru'): 2,
#           ('Willatz', 'De'): 1,
#           ('Deres', 'Fars'): 3,
#           ('Handel', 'Segelfoss'): 1,
#           ('Deres', 'Datter'): 1,
#           ('Deres', 'Kunst'): 1,
#           ('Deres', 'Cello'): 1,
#           ('Deres', 'Mor'): 1,
#           ('By', 'Øinene'): 1,
#           ('Mand', 'Bertel'): 1,
#           ('Marcilie', 'Pike'): 4,
#           ('Pauline', 'Nytte'): 1,
#           ('Sakføreren', 'Ret'): 1,
#           ('Frøken', 'Sibylle'): 19,
#           ('Fru', 'Lydia'): 8,
#           ('Theodors', 'Arm'): 1,
#           ('Deres', 'Arm'): 1,
#           ('Dåmen', 'Sibylle'): 1,
#           ('Deres', 'Stykke'): 1,
#           ('De', 'Stykket'): 1,
#           ('Kunstner', 'Max'): 16,
#           ('Frøken', 'Clara'): 45,
#           ('Mariane', 'Holmengraa'): 3,
#           ('Frøken', 'Holmengraa'): 14,
#           ('Deres', 'Ærend'): 1,
#           ('Deres', 'Teater'): 1,
#           ('Dåmen', 'Clara'): 2,
#           ('Sprog', 'Telegrafbestyreren'): 1,
#           ('Deres', 'Sprog'): 1,
#           ('Slags', 'Spil'): 1,
#           ('Deres', 'Kald'): 1,
#           ('De', 'Willatz'): 1,
#           ('Prat', 'De'): 1,
#           ('Par', 'Blomster'): 1,
#           ('Par', 'Reisende'): 1,
#           ('Deres', 'Frøken'): 1,
#           ('Frøken', 'Datter'): 1,
#           ('Holmengraas', 'Ring'): 1,
#           ('Hr.', 'Sakfører'): 3,
#           ('Mand', 'Raad'): 1,
#           ('Frøken', 'Døtre'): 1,
#           ('Arbeide', 'De'): 1,
#           ('Lassen', 'De'): 1,
#           ('Deres', 'Mand'): 1,
#           ('Dem', 'Theodor'): 1,
#           ('Far', 'Konsulen'): 1,
#           ('Willatz', 'Ansigt'): 1,
#           ('Mands', 'Tale'): 1,
#           ('Far', 'Løitnanten'): 1,
#           ('Deres', 'Støvler'): 1,
#           ('Deres', 'Arbeide'): 1,
#           ('Kort', 'Taushet'): 1,
#           ('By', 'Ansigtet'): 1,
#           ('Holmengraa', 'Konge'): 1,
#           ('Far', 'Løitnantens'): 1,
#           ('Primadonna', 'Lydia'): 2,
#           ('Fru', 'Per'): 8,
#           ('Slags', 'Nytte'): 1,
#           ('Theodor', 'Tid'): 1,
#           ('Farns', 'Øine'): 1,
#           ('Theodors', 'Opmærksomhet'): 1,
#           ('Farns', 'Mund'): 1,
#           ('Par', 'Herrer'): 1,
#           ('Øre', 'Dagen'): 1,
#           ('By', 'Theodor'): 3,
#           ('Vært', 'Natten'): 1,
#           ('Slags', 'Maate'): 1,
#           ('Deres', 'Søstre'): 5,
#           ('Deres', 'Forældre'): 2,
#           ('Øieblik', 'Pokker'): 1,
#           ('Fars', 'Forretning'): 1,
#           ('Theodors', 'Skyld'): 1,
#           ('Deres', 'Søster'): 1,
#           ('Kjøpmand', 'Jensen'): 2,
#           ('Theodor', 'Mistanke'): 1,
#           ('Deres', 'Tilfælde'): 1,
#           ('Anton', 'Fredrik'): 1,
#           ('Slags', 'Varer'): 1,
#           ('Deres', 'Skog'): 1,
#           ('Øieblik', 'Anton'): 1,
#           ('Brukseieren', 'Ret'): 1,
#           ('Holmsens', 'Skog'): 1,
#           ('Datter', 'Segelfoss'): 1,
#           ('Theodors', 'Teater'): 2,
#           ('Deres', 'Telegram'): 1,
#           ('Deres', 'Svar'): 1,
#           ('Raschs', 'Hus'): 2,
#           ('Sakførerens', 'Tur'): 1,
#           ('Sakførerens', 'Stue'): 1,
#           ('Raschs', 'Slægt'): 1,
#           ('Damerne', 'Landmarck'): 1,
#           ('Damer', 'Landmarck'): 1,
#           ('Frøken', 'Landmarck'): 6,
#           ('Hr.', 'Sakføreren'): 1,
#           ('By', 'Kvældene'): 1,
#           ('Sakførerens', 'Fest'): 1,
#           ('Mand', 'Anton'): 1,
#           ('Par', 'Støvler'): 1,
#           ('Mine', 'Søstre'): 2,
#           ('Raschs', 'Fest'): 1,
#           ('Deres', 'Føtter'): 1,
#           ('De', 'Kniv'): 1,
#           ('Deres', 'Lommetørklæde'): 1,
#           ('Del', 'Mening'): 1,
#           ('By', 'Anton'): 1,
#           ('Sakførerens', 'Krambod'): 1,
#           ('Segelfoss', 'Piker'): 1,
#           ('De', 'Lensmand'): 1,
#           ('Farn', 'Bud'): 1,
#           ('By', 'Bua'): 1,
#           ('Dem', 'Farvel'): 1,
#           ('Farvel', 'Lensmand'): 1,
#           ('Bua', 'Væg'): 2,
#           ('By', 'Baardsen'): 1,
#           ('Huset', 'Baardsen'): 1,
#           ('Mand', 'Theodor'): 1,
#           ('Hr.', 'Max'): 1,
#           ('By', 'Dag'): 2,
#           ('Damerne', 'Lydia'): 1,
#           ('Clara', 'Kaape'): 1,
#           ('Goddag', 'Mor'): 1,
#           ('Guds', 'Fred'): 1,
#           ('By', 'Maten'): 1,
#           ('Lassen', 'Visit'): 1,
#           ('Mand', 'Lassen'): 1,
#           ('Siden', 'Distriktslæge'): 1,
#           ('By', 'Far'): 2,
#           ('Guds', 'Røst'): 1,
#           ('Par', 'Bøker'): 1,
#           ('Huset', 'Holmengraa'): 1,
#           ('Ven', 'Lensmanden'): 1,
#           ('Holmengraas', 'Skjæbne'): 1,
#           ('Deres', 'Mariane'): 2,
#           ('Folket', 'Mel'): 1,
#           ('By', 'Lensmand'): 1,
#           ('Ven', 'Papa'): 1,
#           ('Ung', 'Felix'): 1,
#           ('Siden', 'Præsten'): 1,
#           ('Holmengraas', 'Svar'): 1,
#           ('Theodors', 'Hode'): 1,
#           ('Farns', 'Død'): 1,
#           ('Folk', 'Bua'): 1,
#           ('By', 'Lars'): 1,
#           ('By', 'Kaffe'): 1,
#           ('Theodors', 'Kontor'): 1,
#           ('Ven', 'Didriksen'): 1,
#           ('Gang', 'Paafund'): 1,
#           ('Holmsens', 'Vilje'): 1,
#           ('Fars', 'Skyld'): 1,
#           ('Sum', 'Penger'): 1,
#           ('Scheldrup', 'Johnsen'): 27,
#           ('Oliver', 'Andersen'): 12,
#           ('Fia', 'Johnsen'): 10,
#           ('Maren', 'Salt'): 32,
#           ('Dem', 'Mattis'): 1,
#           ('Fia', 'Johnsens'): 1,
#           ('Siste', 'Kapitel'): 17,
#           ('Bruk', 'Herrerne'): 1,
#           ('Bygden', 'Gang'): 1,
#           ('Torahus', 'Sanatorium'): 13,
#           ('Eksempel', 'Fru'): 1,
#           ('Fru', 'Ruben'): 42,
#           ('Sakfører', 'Robertsen'): 22,
#           ('Hr.', 'Bertelsen'): 19,
#           ('Damen', 'Frøken'): 1,
#           ('Frøken', 'Ellingsen'): 51,
#           ('Pokkers', 'Pike'): 4,
#           ('Hr.', 'Fleming'): 123,
#           ('Torahus', 'Sæter'): 4,
#           ('Siden', 'De'): 2,
#           ('Hr.', 'Flemings'): 15,
#           ('Flemings', 'Øine'): 1,
#           ('Hr.', 'Eyde'): 4,
#           ('Anton', 'Moss'): 41,
#           ('Daniels', 'Sæter'): 7,
#           ('Øinene', 'Liv'): 1,
#           ('Kamerat', 'Anton'): 4,
#           ('Sakføreren', 'Frøken'): 1,
#           ('Gang', 'Hr.'): 1,
#           ('Pokkers', 'Sakfører'): 1,
#           ('De', 'Fransk'): 1,
#           ('Konsul', 'Ruben'): 6,
#           ('Gang', 'Damen'): 1,
#           ('Menneske', 'Fru'): 1,
#           ('Deres', 'Rum'): 1,
#           ('Rektor', 'Oliver'): 16,
#           ('Øieblik', 'Oksen'): 1,
#           ('Hr.', 'Rektor'): 2,
#           ('De', 'Bladene'): 1,
#           ('Slags', 'Sprog'): 1,
#           ('Flemings', 'Ansikt'): 2,
#           ('Oliver', 'Selskapet'): 1,
#           ('Flemings', 'Værelse'): 2,
#           ('Sanatoriets', 'Grund'): 1,
#           ('Daniels', 'Side'): 1,
#           ('Daniels', 'Øine'): 1,
#           ('De', 'Fru'): 1,
#           ('Greven', 'Deres'): 1,
#           ('Slags', 'Selskap'): 1,
#           ('Siden', 'Moss'): 1,
#           ('Sanatoriets', 'Bøker'): 1,
#           ('Spørsmaal', 'Frøken'): 1,
#           ('Kone', 'Helena'): 1,
#           ('Kamerat', 'Selvmorderen'): 1,
#           ('Maate', 'Moss'): 1,
#           ('Ting', 'De'): 1,
#           ('Saar', 'De'): 1,
#           ('Slags', 'Plass'): 1,
#           ('Dem', 'Menneske'): 1,
#           ('Gang', 'Daniel'): 1,
#           ('Penger', 'Dag'): 1,
#           ('Gang', 'Frøken'): 1,
#           ('Poldens', 'Sparebank'): 12,
#           ('Lyder', 'Milde'): 11,
#           ('Auge', 'Johannes'): 1,
#           ('Mliller', 'Heß'): 1,
#           ('Ihre', 'Hand'): 3,
#           ('Hause', 'Ihr'): 1,
#           ('Fråulein', 'Victoria'): 8,
#           ('Ihnen', 'Blumen'): 1,
#           ('Herr', 'Johannes'): 1,
#           ('Ihr', 'Mund'): 2,
#           ('Ihr', 'Gesicht'): 2,
#           ('Sic', 'Sic'): 1,
#           ('Frau', 'Victoria'): 1,
#           ('Wagen', 'Platz'): 1,
#           ('Sic', 'Otto'): 1,
#           ('Ihr', 'Platz'): 1,
#           ('Sie', 'Victoria'): 1,
#           ('Schloßherrin', 'Victoria'): 1,
#           ('Heß', 'CamiUa'): 1,
#           ('Ihre', 'Stimme'): 3,
#           ('Ihr', 'Auge'): 1,
#           ('Johannes', 'Heß'): 1,
#           ('Gott', 'Sic'): 1,
#           ('Leben', 'Sic'): 2,
#           ('Leben', 'Sie'): 1,
#           ('Ihr', 'Leben'): 1,
#           ('Ihre', 'Victoria'): 1,
#           ('Nåmen', 'Victoria'): 1,
#           ('De', 'Nanna'): 1,
#           ('Du', 'Nanna'): 1,
#           ('Arild', 'Hamsun'): 11,
#           ('Olaf', 'Naper'): 2,
#           ('Deres', 'Victoria'): 1,
#           ('Doch', 'Ku'): 1,
#           ('Die', 'Welt'): 4,
#           ('Ture', 'Ture'): 6,
#           ('Zur', 'Os'): 1,
#           ('Sin', 'Der'): 1,
#           ('Ker', 'Den'): 1,
#           ('Waloe', 'Vom'): 1,
#           ('Zum', 'Himmel'): 1,
#           ('Sott', 'Du'): 1,
#           ('Zu', 'Das'): 1,
#           ('Doch', 'Himmel'): 1,
#           ('Ank', 'Ku'): 1,
#           ('Ku', 'Ku'): 1,
#           ('Wie', 'Die'): 1,
#           ('Kie', 'Welt'): 1,
#           ('Den', 'Ker'): 1,
#           ('Ken', 'Ku'): 1,
#           ('Zum', 'Os'): 1,
#           ('Zu', 'Mit'): 1,
#           ('Zu', 'Ker'): 1,
#           ('Wie', 'Kie'): 1,
#           ('Himmel', 'Wie'): 1,
#           ('Der', 'Himmel'): 2,
#           ('Waloe', 'Sin'): 1,
#           ('Os', 'Lon'): 1,
#           ('Ku', 'Kas'): 1,
#           ('Ano', 'Wie'): 1,
#           ('Ano', 'Zu'): 1,
#           ('Karl', 'Johan'): 11,
#           ('Dem', 'Ylajali'): 1,
#           ('Johan', 'Nagel'): 9,
#           ('Dagny', 'Kielland'): 10,
#           ('Dagny', 'Kiellands'): 5,
#           ('Martha', 'Gude'): 11,
#           ('Minutten', 'De'): 1,
#           ('Dem', 'Minutten'): 1,
#           ('Dem', 'Simonsen'): 1,
#           ('Minutten', 'Johannes'): 1,
#           ('Deres', 'Dem'): 1,
#           ('Gude', 'De'): 1,
#           ('Dem', 'Johannes'): 1,
#           ('Selmer', 'Eyde'): 9,
#           ('De', 'Edvarda'): 1}),
#  Counter({('Navn', 'Abel', 'Brodersen'): 1,
#           ('Lovise', 'Rolandsen', 'Børn'): 1,
#           ('Kaptein', 'Ulrik', 'Fredriksen'): 1,
#           ('Kaptein', 'Brodersen', 'Clemens'): 1,
#           ('Kaptein', 'Abel', 'Brodersen'): 1,
#           ('Slags', 'Mand', 'Lawrence'): 1,
#           ('Fru', 'Tolder', 'Robertsen'): 1,
#           ('Lovise', 'Magrete', 'Doppen'): 7,
#           ('Giorgi', 'Giorgi', 'Giorgi'): 2,
#           ('Hr.', 'Willatz', 'Holmsen'): 16,
#           ('Husjomfruen', 'Jomfru', 'Salvesen'): 2,
#           ('Løitnant', 'Willatz', 'Holmsens'): 1,
#           ('Søn', 'Willatz', 'Holmsen'): 1,
#           ('Willatz', 'Holmsen', 'De'): 1,
#           ('Hr.', 'Holmengraa', 'Øie'): 1,
#           ('Løitnant', 'Willatz', 'Holmsen'): 3,
#           ('Jomfru', 'Kristine', 'Salvesen'): 2,
#           ('Gamle', 'Fru', 'Coldevin'): 2,
#           ('Konsulen', 'Fru', 'Adelheid'): 2,
#           ('Mand', 'Tobias', 'Holmengraa'): 1,
#           ('Løitnanten', 'Piken', 'Daverdana'): 1,
#           ('Mand', 'Willatz', 'Holmsen'): 1,
#           ('Lars', 'Manuelsens', 'Hus'): 1,
#           ('Gamle', 'Lars', 'Manuelsen'): 2,
#           ('Hr.', 'Holmengraas', 'Selskap'): 1,
#           ('Tid', 'Fru', 'Adelheid'): 1,
#           ('Lars', 'Manuelsens', 'Stue'): 2,
#           ('Hr.', 'Holmengraas', 'Virksomhet'): 3,
#           ('Deres', 'Martin', 'Dreng'): 1,
#           ('De', 'Martin', 'Dreng'): 1,
#           ('Kong', 'Tobias', 'Doktoren'): 1,
#           ('Hr.', 'Holmengraas', 'Magt'): 1,
#           ('Par', 'Ganger', 'Haanden'): 1,
#           ('Lars', 'Manuelsens', 'Søn'): 2,
#           ('Hr.', 'Holmengraas', 'Børn'): 1,
#           ('Fars', 'Lars', 'Manuelsens'): 1,
#           ('Hr.', 'Holmengraas', 'Ønske'): 1,
#           ('Tiden', 'Hr.', 'Holmengraa'): 1,
#           ('Frue', 'Fru', 'Adelheid'): 1,
#           ('Hr.', 'Holmengraas', 'Hat'): 1,
#           ('Fru', 'Adelheids', 'Haand'): 1,
#           ('Hr.', 'Holmengraas', 'Ansigt'): 4,
#           ('Spørsmaal', 'Hr.', 'Holmengraa'): 1,
#           ('Tiden', 'Fru', 'Adelheid'): 1,
#           ('Husjomfru', 'Jomfru', 'Salvesen'): 4,
#           ('Martin', 'Dreng', 'Ordre'): 1,
#           ('Øieblik', 'Præsten', 'Lassen'): 1,
#           ('Konsul', 'Fredrik', 'Haanden'): 1,
#           ('Far', 'Lars', 'Manuelsen'): 1,
#           ('Hr.', 'Holmengraas', 'Ærend'): 1,
#           ('Eksempel', 'Hr.', 'Holmengraa'): 1,
#           ('Jomfru', 'Salvesen', 'Børn'): 1,
#           ('Lars', 'Manuelsens', 'Familje'): 1,
#           ('Mand', 'Hr.', 'Holmengraa'): 1,
#           ('Fru', 'Sakfører', 'Rasch'): 10,
#           ('Folk', 'Ung', 'Willatz'): 1,
#           ('Julius', 'Larsens', 'Hotel'): 1,
#           ('Fru', 'Sakfører', 'Raschs'): 1,
#           ('Kornelius', 'Segelfoss', 'By'): 1,
#           ('Søn', 'Ung', 'Willatz'): 1,
#           ('Hr.', 'Holmengraas', 'Hus'): 10,
#           ('Segelfoss', 'By', 'De'): 2,
#           ('Hr.', 'Holmengraa', 'Lensmanden'): 1,
#           ('Segelfoss', 'By', 'Kroner'): 1,
#           ('Fru', 'Segelfoss', 'By'): 1,
#           ('Spøk', 'Frøken', 'Mariane'): 1,
#           ('Hr.', 'Holmengraas', 'Liv'): 1,
#           ('Sakfører', 'Raschs', 'Tur'): 1,
#           ('Glæde', 'Segelfoss', 'By'): 1,
#           ('Lars', 'Manuelsens', 'Kone'): 1,
#           ('Dem', 'Segelfoss', 'Tidende'): 1,
#           ('Hr.', 'Theodor', 'Jensen'): 5,
#           ('Segelfoss', 'By', 'Julius'): 1,
#           ('Hr.', 'Holmengraas', 'Blik'): 1,
#           ('Lars', 'Manuelsens', 'Ærend'): 1,
#           ('Segelfoss', 'By', 'Vinter'): 1,
#           ('Lars', 'Manuelsens', 'Børn'): 1,
#           ('Par', 'Hundrede', 'Kroner'): 3,
#           ('Hr.', 'Holmsens', 'Bord'): 1,
#           ('Segelfoss', 'By', 'Fru'): 2,
#           ('By', 'Fru', 'Irgens'): 1,
#           ('Ung', 'Willatz', 'De'): 1,
#           ('Deres', 'Fars', 'Tid'): 1,
#           ('Handel', 'Segelfoss', 'By'): 1,
#           ('Segelfoss', 'By', 'Øinene'): 1,
#           ('Frøken', 'Mariane', 'Holmengraa'): 1,
#           ('De', 'Willatz', 'Holmsen'): 1,
#           ('Deres', 'Frøken', 'Datter'): 1,
#           ('Hr.', 'Holmengraas', 'Ring'): 1,
#           ('Segelfoss', 'By', 'Ansigtet'): 1,
#           ('Hr.', 'Holmengraa', 'Konge'): 1,
#           ('Deres', 'Fars', 'Dager'): 1,
#           ('Far', 'Løitnantens', 'Røst'): 1,
#           ('Segelfoss', 'By', 'Theodor'): 3,
#           ('Anton', 'Fredrik', 'Coldevin'): 1,
#           ('Willatz', 'Holmsens', 'Skog'): 1,
#           ('Datter', 'Segelfoss', 'By'): 1,
#           ('Sakfører', 'Raschs', 'Hus'): 1,
#           ('By', 'Fru', 'Landmarck'): 1,
#           ('Hr.', 'Sakfører', 'Rasch'): 1,
#           ('Mand', 'Anton', 'Coldevin'): 1,
#           ('Sakfører', 'Raschs', 'Fest'): 1,
#           ('Segelfoss', 'By', 'Anton'): 1,
#           ('Segelfoss', 'By', 'Bua'): 1,
#           ('Segelfoss', 'By', 'Baardsen'): 1,
#           ('Segelfoss', 'By', 'Dag'): 2,
#           ('Frøken', 'Clara', 'Kaape'): 1,
#           ('Segelfoss', 'By', 'Maten'): 1,
#           ('Præsten', 'Lassen', 'Visit'): 1,
#           ('Siden', 'Distriktslæge', 'Muus'): 1,
#           ('Segelfoss', 'By', 'Far'): 2,
#           ('Hr.', 'Holmengraas', 'Skjæbne'): 1,
#           ('Deres', 'Mariane', 'Holmengraa'): 2,
#           ('Segelfoss', 'By', 'Lensmand'): 1,
#           ('Siden', 'Præsten', 'Lassen'): 1,
#           ('Hr.', 'Holmengraas', 'Arbeidere'): 1,
#           ('Hr.', 'Holmengraas', 'Svar'): 1,
#           ('Segelfoss', 'By', 'Lars'): 1,
#           ('By', 'Lars', 'Manuelsen'): 1,
#           ('Segelfoss', 'By', 'Kaffe'): 1,
#           ('Willatz', 'Holmsens', 'Vilje'): 1,
#           ('Eksempel', 'Fru', 'Ruben'): 1,
#           ('Damen', 'Frøken', 'Ellingsen'): 1,
#           ('Hr.', 'Flemings', 'Øine'): 1,
#           ('Kamerat', 'Anton', 'Moss'): 4,
#           ('Sakføreren', 'Frøken', 'Ellingsen'): 1,
#           ('Gang', 'Hr.', 'Bertelsen'): 1,
#           ('Menneske', 'Fru', 'Ruben'): 1,
#           ('Hr.', 'Flemings', 'Ansikt'): 2,
#           ('Rektor', 'Oliver', 'Selskapet'): 1,
#           ('Hr.', 'Flemings', 'Værelse'): 2,
#           ('De', 'Fru', 'Ruben'): 1,
#           ('Mand', 'Hr.', 'Fleming'): 1,
#           ('Ank', 'Ku', 'Ku'): 1}),
#  Counter({('Giorgi', 'Giorgi', 'Giorgi', 'Giorgi'): 1,
#           ('Søn', 'Willatz', 'Holmsen', 'De'): 1,
#           ('Segelfoss', 'By', 'Fru', 'Irgens'): 1,
#           ('Segelfoss', 'By', 'Fru', 'Landmarck'): 1,
#           ('Segelfoss', 'By', 'Lars', 'Manuelsen'): 1})]

# %%
nb.pure_urn(nb.frame(korpus, 'urn')['urn'])
# Out:
# ['2010062306022',
#  '2013012108010',
#  '2012033008103',
#  '2016051148095',
#  '2013010908035',
#  '2010080620015',
#  '2008112113001',
#  '2012012606034',
#  '2007020201064',
#  '2014061108229',
#  '2009051413002',
#  '2014081908003',
#  '2009030300045',
#  '2008031112002',
#  '2011110306011',
#  '2009030900157',
#  '2013040824021',
#  '2012010508105',
#  '2012091908134',
#  '2014110508116']

# %%
opptelling = tell_navn(, redigerte_navn)
# Out:
# Problemer med å telle fra:  [[2010062306022, 'Hamsun, Knut', 1936, 'Samlede Verker', '', 'Gyldendal;Oslo : Gyldendal, 1934-1936', 'unknown', '09c3732a97d3bc764f403c603d8365aa', 'nob', '']]
# Problemer med å telle fra:  [[2013012108010, 'Hamsun, Knut', 1959, 'Victoria', 'en kjærligheds historie', 'Gyldendal', 'fiction', '3bea4f928c40841d04b1574d4bf4f7e9', 'nob', '']]
# Problemer med å telle fra:  [[2012033008103, 'Hamsun, Knut', 1972, 'Sværmere', '', 'Gyldendal', 'fiction', 'c615d91acf40c6953503a163fe6eb1a4', 'nob', '']]
# Problemer med å telle fra:  [[2016051148095, 'Hamsun, Knut', 1921, 'vandrer spiller med sordin', '', 'Gyldendal', 'fiction', 'ec8f0c30ca42fbfc5a674a3fbc2189f6', 'nob', '']]
# Problemer med å telle fra:  [[2013010908035, 'Hamsun, Knut', 2002, 'Landstrykere', '', 'Gyldendal', 'fiction', 'f9196f9e3da5d3c9fe4d11dc49f0176e', 'nob', '']]
# Problemer med å telle fra:  [[2010080620015, 'Hamsun, Knut', 1997, 'Samlede verker', '', 'Gyldendal;[Oslo] : Gyldendal, 1997', 'fiction', '0b9d24253a11ecb2ca94589e4b9edb3b', 'nob', '']]
# Problemer med å telle fra:  [[2008112113001, 'Hamsun, Knut', 1877, 'Gaadefulde', 'en Kjærlighedshistorie fra Nordland', 'Urdal', 'unknown', '05b5fb8e2ffab70be305373f9857ee85', 'nob', '']]
# Problemer med å telle fra:  [[2012012606034, 'Hamsun, Knut', 1944, 'Samlede romaner', '', 'Gyldendal;Oslo : Gyldendal, 1944', 'unknown', '10be221ae24a25b2ce3e9a9a5866415c', 'und', '']]
# Problemer med å telle fra:  [[2007020201064, 'Hamsun, Arild', 1941, 'Askeladden i gresset', '', 'Gyldendal', 'unknown', '5c605841211c83b024fbba1877def456', 'nob', '']]
# Problemer med å telle fra:  [[2014061108229, 'Hamsun, Knut', 2008, 'Samlede verker', '', 'Gyldendal;[Oslo] : Gyldendal, 2007-2009', 'novel', 'ce797ce5f92be1fd9eb875bbfcb05979', 'nob', '']]
# Problemer med å telle fra:  [[2009051413002, 'Hamsun, Knut', 1923, 'Siste kapitel', 'roman', 'Gyldendal;Kristiania : Gyldendal, 1923', 'unknown', '6b165f349c6d1ad8b10b12767d05af99', 'nob', '']]
# Problemer med å telle fra:  [[2014081908003, 'Hamsun, Knut', 2009, 'Samlede verker', '', 'Gyldendal;[Oslo] : Gyldendal, 2007-2009', 'novel', '4aab87864719168a337d233260022918', 'nob', '']]
# Problemer med å telle fra:  [[2009030300045, 'Hamsun, Knut', 1998, 'Victoria', 'eine Liebesgeschichte', 'Stenersens forl.', 'fiction', '25a1752fbf6e1aa5fc401d543ccde5a3', 'ger', 'nob']]
# Problemer med å telle fra:  [[2008031112002, 'Hamsun, Knut', 1919, 'Nälkä', '', 'Kustannusosakeyhtiö kirja', 'unknown', 'db5ffcd4287ff89bf614040598c1c186', 'fin', '']]
# Problemer med å telle fra:  [[2011110306011, 'Hamsun, Arild', 1939, 'Ung mann kommer og går', '', 'Gyldendal', 'unknown', '802bfe29ca2f0f77768b9f24135716fa', 'nob', '']]
# Problemer med å telle fra:  [[2009030900157, 'Hamsun, Knut', 1998, 'Victoria', 'en kjærligheds historie', 'Stenersens forl.', 'fiction', 'd328ac19d672aad2be7949b53e83bc9f', 'nob', '']]
# Problemer med å telle fra:  [[2013040824021, 'Hamsun, Knut', 1926, 'wilde Chor', '', 'Spaeth', 'unknown', 'e20d12f309709ffe6af0e8890b427106', 'ger', 'nob']]
# Problemer med å telle fra:  [[2012010508105, 'Hamsun, Knut', 1954, 'Samlede verker', '', 'Gyldendal;Oslo : Gyldendal, 1954-56', 'unknown', 'd8ce287ea38d7da1156c9098604b04ce', 'nob', '']]
# Problemer med å telle fra:  [[2012091908134, 'Hamsun, Knut', 1963, 'Samlede verker', '', 'Gyldendal;Oslo : Gyldendal, 1963-1964', 'novel', 'ef2bb48090baf9f71427c58f38084615', 'nob', '']]
# Problemer med å telle fra:  [[2014110508116, 'Hamsun, Knut', 2002, 'Pan', 'av løitnant Thomas Glahns papirer', 'Gyldendal', 'fiction', 'a1e64642d7a63c4a8e00dec6f30995c0', 'nob', '']]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-665fad315e07> in <module>
# ----> 1 opptelling = tell_navn(nb.frame(korpus, 'urn'), redigerte_navn)
#
# <ipython-input-5-2b66edebe788> in tell_navn(korpus, token_map)
#      15         except:
#      16             print("Problemer med å telle fra: ", metadata(urn))
# ---> 17     return pd.concat([res[u] for u in res], axis=1)
#      18
#      19 def korpus_oppføring(df, text, column='tittel'):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate

# %% [markdown]
# Sånn ser opptellingen ut, en kolonne pr. bok. Nedenfor ser vi på det samlede resultatet, og hver bok.

# %%
opptelling
# Out:
#                  2008112113001  2009061013011  2009061013012  2009061012004  \
# Aabakken                  20.0            NaN            NaN            NaN
# Amerika                    NaN            NaN            NaN          305.0
# Amerikas_Vesten            1.0            NaN            NaN            3.0
# Baku                       NaN            NaN            NaN            NaN
# Bergen                     NaN            NaN            NaN            NaN
# Berlin                     NaN            NaN            NaN            NaN
# Bjærget                    NaN            NaN            NaN            NaN
# Bjørger_Sulheim            NaN          127.0            NaN            NaN
# Bodø                       NaN            NaN            1.0            NaN
# Bokhara                    NaN            NaN            NaN            NaN
# Boston                     NaN            NaN            NaN           14.0
# Breidablik                 NaN            NaN            NaN            NaN
# Canada                     NaN            NaN            NaN            NaN
# Chicago                    NaN            NaN            NaN           10.0
# Danmark                    NaN            NaN            NaN            NaN
# Doppen                     NaN            NaN            NaN            NaN
# Drammen                    NaN            NaN            NaN            NaN
# Europa                     NaN            1.0            NaN           33.0
# Finland                    NaN            NaN            NaN            NaN
# Fosenlandet                NaN            NaN            NaN            NaN
# Frankrike                  NaN            NaN            NaN            NaN
# Fuglværø                   NaN            NaN            NaN            NaN
# Gaden                      NaN            NaN            NaN           14.0
# Grimstad                   NaN            NaN            NaN            NaN
# Grønland                   NaN            NaN            NaN            NaN
# Hannover                   NaN            NaN            NaN            1.0
# Harrow                     NaN            NaN            NaN            NaN
# Havet                      NaN            NaN            NaN            NaN
# Heia                       NaN            NaN            NaN            NaN
# Himlen                     1.0            NaN            NaN            3.0
# ...                        ...            ...            ...            ...
# Polden                     NaN            NaN            NaN            NaN
# Russland                   NaN            NaN            NaN            NaN
# Sagvika                    NaN            NaN            NaN            NaN
# Segelfoss                  NaN            NaN            NaN            NaN
# Segelfossen                NaN            NaN            NaN            NaN
# Sellanraa                  NaN            NaN            NaN            NaN
# Sirilund                   NaN            NaN            NaN            NaN
# Skogen                     NaN            1.0            NaN            4.0
# Stavanger                  NaN            NaN            NaN            NaN
# Storborg                   NaN            NaN            NaN            NaN
# Stordalen                  NaN            NaN            NaN            NaN
# Stortinget                 NaN            NaN            NaN            NaN
# Sveits                     NaN            NaN            NaN            NaN
# Sverige                    NaN            NaN            NaN            1.0
# Syden                      NaN            NaN            NaN            3.0
# Tiflis                     NaN            NaN            NaN            NaN
# Torahus                    NaN            NaN            NaN            NaN
# Toretind                   NaN            NaN            NaN            NaN
# Torpelviken                NaN            NaN            NaN            NaN
# Tromsø                     NaN            NaN            NaN            NaN
# Trondhjem                  NaN            NaN            NaN            NaN
# Tyskland                   NaN            NaN            NaN            5.0
# Ura                        NaN            NaN            NaN            NaN
# Utvær                      NaN            NaN            NaN            NaN
# Vangen                     NaN            NaN            NaN            NaN
# Verden                     1.0            NaN            NaN           46.0
# Vladikaukas                NaN            NaN            NaN            NaN
# Vælta                      NaN            NaN            NaN            NaN
# Washington                 NaN            NaN            NaN           17.0
# Ytrepolden                 NaN            NaN            NaN            NaN
#
#                  2009042313001  2015051929001  2008123012002  2008123012003  \
# Aabakken                   NaN            NaN            NaN            NaN
# Amerika                    4.0            NaN            2.0            9.0
# Amerikas_Vesten            1.0            4.0            5.0            NaN
# Baku                       NaN            NaN            NaN            NaN
# Bergen                     NaN            NaN            NaN            NaN
# Berlin                     NaN            NaN            NaN            NaN
# Bjærget                    NaN            NaN            1.0            NaN
# Bjørger_Sulheim            NaN            NaN            NaN            NaN
# Bodø                       NaN            NaN            NaN            NaN
# Bokhara                    NaN            NaN            NaN            NaN
# Boston                     NaN            NaN            NaN            NaN
# Breidablik                 NaN            NaN            NaN            NaN
# Canada                     NaN            NaN            NaN            NaN
# Chicago                    2.0            NaN            NaN            NaN
# Danmark                    NaN            NaN            NaN            NaN
# Doppen                     NaN            NaN            NaN            NaN
# Drammen                    NaN            NaN            NaN            1.0
# Europa                     NaN            NaN            1.0            2.0
# Finland                    NaN            NaN            1.0            NaN
# Fosenlandet                2.0            NaN            NaN            NaN
# Frankrike                  NaN            NaN            NaN            NaN
# Fuglværø                   NaN            NaN            NaN            NaN
# Gaden                      NaN           64.0           38.0           38.0
# Grimstad                   NaN            NaN            NaN            NaN
# Grønland                   NaN            1.0            NaN            NaN
# Hannover                   NaN            1.0            1.0            1.0
# Harrow                     NaN            NaN            NaN            NaN
# Havet                      NaN            3.0            5.0            1.0
# Heia                       NaN            NaN            NaN            NaN
# Himlen                     7.0           13.0           17.0            2.0
# ...                        ...            ...            ...            ...
# Polden                     NaN            NaN            NaN            NaN
# Russland                   NaN            NaN            NaN            NaN
# Sagvika                    NaN            NaN            NaN            NaN
# Segelfoss                  NaN            NaN            NaN            NaN
# Segelfossen                NaN            NaN            NaN            NaN
# Sellanraa                  NaN            NaN            NaN            NaN
# Sirilund                   NaN            NaN            NaN            NaN
# Skogen                     NaN            3.0           68.0            1.0
# Stavanger                  9.0            NaN            NaN            NaN
# Storborg                   NaN            NaN            NaN            NaN
# Stordalen                  NaN            NaN            NaN            NaN
# Stortinget                 NaN            1.0            NaN           10.0
# Sveits                     NaN            NaN            NaN            NaN
# Sverige                    NaN            NaN            2.0            1.0
# Syden                      NaN            NaN            NaN            NaN
# Tiflis                     NaN            NaN            NaN            NaN
# Torahus                    NaN            NaN            NaN            NaN
# Toretind                   NaN            NaN            NaN            NaN
# Torpelviken                NaN            NaN            NaN            NaN
# Tromsø                     NaN            NaN            NaN            NaN
# Trondhjem                  NaN            NaN            NaN            1.0
# Tyskland                   1.0            NaN            NaN            NaN
# Ura                        NaN            NaN            NaN            NaN
# Utvær                      NaN            NaN            NaN            NaN
# Vangen                     NaN            NaN            NaN            NaN
# Verden                     6.0            8.0           51.0           10.0
# Vladikaukas                NaN            NaN            NaN            NaN
# Vælta                      NaN            NaN            NaN            NaN
# Washington                 NaN            NaN            NaN            NaN
# Ytrepolden                 NaN            NaN            NaN            NaN
#
#                  2008123010002  2008082710002  ...  2009051413002  \
# Aabakken                   NaN            NaN  ...            NaN
# Amerika                    5.0            NaN  ...            NaN
# Amerikas_Vesten            1.0            NaN  ...            1.0
# Baku                       NaN            NaN  ...            NaN
# Bergen                     NaN            NaN  ...            NaN
# Berlin                     NaN            NaN  ...            NaN
# Bjærget                    NaN            2.0  ...            NaN
# Bjørger_Sulheim            NaN            NaN  ...            NaN
# Bodø                       NaN            NaN  ...            NaN
# Bokhara                    NaN            NaN  ...            NaN
# Boston                     NaN            NaN  ...            NaN
# Breidablik                 NaN            NaN  ...            NaN
# Canada                     NaN            NaN  ...            NaN
# Chicago                    NaN            NaN  ...            NaN
# Danmark                    NaN            NaN  ...            NaN
# Doppen                     NaN            NaN  ...            NaN
# Drammen                    NaN            NaN  ...            NaN
# Europa                     1.0            NaN  ...            NaN
# Finland                    1.0            NaN  ...            5.0
# Fosenlandet                NaN            NaN  ...            NaN
# Frankrike                  NaN            NaN  ...            2.0
# Fuglværø                   NaN            NaN  ...            NaN
# Gaden                     60.0            3.0  ...            NaN
# Grimstad                   NaN            NaN  ...            NaN
# Grønland                   NaN            NaN  ...            NaN
# Hannover                   1.0            1.0  ...            NaN
# Harrow                     NaN            NaN  ...            NaN
# Havet                      1.0            3.0  ...            NaN
# Heia                       NaN            NaN  ...            NaN
# Himlen                    15.0           14.0  ...            2.0
# ...                        ...            ...  ...            ...
# Polden                     NaN            NaN  ...            NaN
# Russland                   NaN            NaN  ...            NaN
# Sagvika                    NaN            NaN  ...            NaN
# Segelfoss                  NaN            NaN  ...            1.0
# Segelfossen                NaN            NaN  ...            NaN
# Sellanraa                  NaN            NaN  ...            NaN
# Sirilund                   NaN           14.0  ...            NaN
# Skogen                     9.0           59.0  ...           20.0
# Stavanger                  NaN            NaN  ...            NaN
# Storborg                   NaN            NaN  ...            NaN
# Stordalen                  NaN            NaN  ...            NaN
# Stortinget                20.0            NaN  ...            NaN
# Sveits                     NaN            NaN  ...            1.0
# Sverige                    4.0            NaN  ...            1.0
# Syden                      NaN            NaN  ...            NaN
# Tiflis                     NaN            NaN  ...            NaN
# Torahus                    NaN            NaN  ...           53.0
# Toretind                   NaN            NaN  ...            NaN
# Torpelviken                NaN            NaN  ...            NaN
# Tromsø                     NaN            NaN  ...            NaN
# Trondhjem                  NaN            NaN  ...            NaN
# Tyskland                   1.0            NaN  ...            NaN
# Ura                        NaN            NaN  ...            NaN
# Utvær                      NaN            NaN  ...            NaN
# Vangen                     NaN            NaN  ...            NaN
# Verden                     9.0            9.0  ...           16.0
# Vladikaukas                NaN            NaN  ...            NaN
# Vælta                      NaN            NaN  ...            NaN
# Washington                 NaN            NaN  ...            NaN
# Ytrepolden                 NaN            NaN  ...            NaN
#
#                  2014021807090  2014120206051  2008091603021  2008091603020  \
# Aabakken                   NaN            NaN            NaN            NaN
# Amerika                    2.0           49.0           69.0           47.0
# Amerikas_Vesten            2.0            2.0            6.0            NaN
# Baku                       NaN            NaN            NaN            NaN
# Bergen                     NaN            2.0           27.0            NaN
# Berlin                     NaN            NaN            NaN            NaN
# Bjærget                    NaN            NaN            NaN            NaN
# Bjørger_Sulheim            NaN            NaN            NaN            NaN
# Bodø                       NaN            9.0           11.0            6.0
# Bokhara                    NaN            NaN            NaN            NaN
# Boston                     NaN            NaN            NaN            NaN
# Breidablik                 NaN            NaN            NaN            NaN
# Canada                     NaN            NaN            NaN            NaN
# Chicago                    NaN            NaN            NaN            NaN
# Danmark                    NaN            NaN            1.0            NaN
# Doppen                     NaN           77.0          119.0           13.0
# Drammen                    NaN            NaN            NaN            NaN
# Europa                     NaN            NaN            NaN            NaN
# Finland                    3.0            NaN            NaN            NaN
# Fosenlandet                NaN           12.0           24.0            2.0
# Frankrike                  1.0            1.0            2.0            NaN
# Fuglværø                   NaN            NaN            NaN           14.0
# Gaden                      NaN            NaN            NaN            NaN
# Grimstad                   NaN            NaN            NaN            NaN
# Grønland                   NaN            NaN            NaN            1.0
# Hannover                   NaN            NaN            NaN            NaN
# Harrow                     NaN            NaN            NaN            NaN
# Havet                      1.0            5.0           15.0            3.0
# Heia                       NaN            NaN            NaN            NaN
# Himlen                     4.0            4.0           12.0            7.0
# ...                        ...            ...            ...            ...
# Polden                     NaN           68.0          146.0          245.0
# Russland                   NaN            1.0            2.0            NaN
# Sagvika                    NaN            NaN            NaN            NaN
# Segelfoss                  NaN            NaN            NaN            NaN
# Segelfossen                NaN            NaN            NaN            NaN
# Sellanraa                  NaN            NaN            NaN            NaN
# Sirilund                   NaN            NaN            NaN            NaN
# Skogen                    39.0            6.0           13.0            7.0
# Stavanger                  NaN            NaN            NaN            NaN
# Storborg                   NaN            NaN            NaN            NaN
# Stordalen                  NaN            NaN            NaN            NaN
# Stortinget                 NaN            NaN            NaN            2.0
# Sveits                     NaN            NaN            NaN            NaN
# Sverige                    1.0            1.0            2.0            NaN
# Syden                      NaN            NaN            NaN            NaN
# Tiflis                     NaN            NaN            NaN            NaN
# Torahus                   27.0            NaN            NaN            NaN
# Toretind                   NaN            NaN            NaN            NaN
# Torpelviken                NaN            NaN            NaN            NaN
# Tromsø                     NaN            3.0            3.0            3.0
# Trondhjem                  NaN           17.0           56.0           17.0
# Tyskland                   NaN            2.0            3.0            NaN
# Ura                        NaN            NaN            NaN            NaN
# Utvær                      NaN            NaN            NaN            NaN
# Vangen                     NaN            NaN            NaN            NaN
# Verden                    14.0           31.0           65.0           65.0
# Vladikaukas                NaN            NaN            NaN            NaN
# Vælta                      NaN            NaN            NaN            NaN
# Washington                 NaN            NaN            NaN            NaN
# Ytrepolden                 NaN            7.0           10.0            NaN
#
#                  2009061010002  2009061013010  2014080408001  2012041208040  \
# Aabakken                   NaN            NaN            NaN            NaN
# Amerika                    1.0            NaN            3.0           10.0
# Amerikas_Vesten            NaN            2.0            1.0            1.0
# Baku                       NaN            NaN            NaN            NaN
# Bergen                     3.0            NaN            NaN            NaN
# Berlin                     NaN            1.0            NaN            NaN
# Bjærget                    NaN            NaN            NaN            NaN
# Bjørger_Sulheim            NaN            NaN            NaN            NaN
# Bodø                       4.0            6.0            NaN            NaN
# Bokhara                    NaN            NaN            NaN            NaN
# Boston                     NaN            NaN            NaN            NaN
# Breidablik                 NaN            NaN            NaN            NaN
# Canada                     NaN            NaN            5.0            6.0
# Chicago                    NaN            NaN            NaN            NaN
# Danmark                    NaN            NaN            NaN            NaN
# Doppen                     NaN            NaN            NaN            NaN
# Drammen                    NaN            NaN            NaN            NaN
# Europa                     1.0            NaN            NaN            NaN
# Finland                    NaN            NaN            NaN            NaN
# Fosenlandet                NaN            NaN            NaN            NaN
# Frankrike                  NaN            2.0            NaN            NaN
# Fuglværø                   NaN            NaN            NaN            NaN
# Gaden                      NaN            NaN            NaN            NaN
# Grimstad                   NaN            NaN            NaN            NaN
# Grønland                   NaN            NaN            NaN            NaN
# Hannover                   NaN            1.0            NaN            NaN
# Harrow                     NaN            NaN            NaN            NaN
# Havet                      1.0            1.0            3.0            NaN
# Heia                       NaN            NaN            NaN            NaN
# Himlen                     5.0            4.0            1.0            2.0
# ...                        ...            ...            ...            ...
# Polden                    22.0           38.0            NaN            NaN
# Russland                   NaN            NaN            NaN            NaN
# Sagvika                    NaN            NaN            NaN            NaN
# Segelfoss                 33.0           57.0            NaN            NaN
# Segelfossen                6.0           11.0            NaN            NaN
# Sellanraa                  NaN            NaN            NaN            NaN
# Sirilund                   NaN            NaN            NaN            NaN
# Skogen                     NaN            6.0            2.0            3.0
# Stavanger                  NaN            NaN            NaN            NaN
# Storborg                   NaN            NaN            NaN            NaN
# Stordalen                  NaN            NaN            NaN            NaN
# Stortinget                 NaN            NaN            NaN            NaN
# Sveits                     NaN            NaN            NaN            NaN
# Sverige                    1.0            NaN            NaN            NaN
# Syden                      NaN            NaN            NaN            NaN
# Tiflis                     NaN            NaN            NaN            NaN
# Torahus                    NaN            NaN            NaN            NaN
# Toretind                   NaN            NaN            NaN            NaN
# Torpelviken                NaN            NaN            NaN            NaN
# Tromsø                     NaN            5.0            NaN            NaN
# Trondhjem                  1.0            6.0            NaN            NaN
# Tyskland                   NaN            3.0            NaN            1.0
# Ura                        NaN            NaN            NaN            NaN
# Utvær                      NaN            NaN            NaN            NaN
# Vangen                     NaN            NaN            NaN            NaN
# Verden                    19.0           23.0           20.0           25.0
# Vladikaukas                NaN            NaN            NaN            NaN
# Vælta                      NaN            NaN            NaN            NaN
# Washington                 NaN            NaN            NaN            NaN
# Ytrepolden                 NaN            NaN            NaN            NaN
#
#                  2008042201022
# Aabakken                   NaN
# Amerika                    7.0
# Amerikas_Vesten            1.0
# Baku                       NaN
# Bergen                     1.0
# Berlin                     NaN
# Bjærget                    NaN
# Bjørger_Sulheim            NaN
# Bodø                       1.0
# Bokhara                    NaN
# Boston                     NaN
# Breidablik                 NaN
# Canada                     NaN
# Chicago                    3.0
# Danmark                    1.0
# Doppen                     NaN
# Drammen                    NaN
# Europa                     5.0
# Finland                    3.0
# Fosenlandet                NaN
# Frankrike                  NaN
# Fuglværø                   NaN
# Gaden                      NaN
# Grimstad                  14.0
# Grønland                   NaN
# Hannover                   NaN
# Harrow                     NaN
# Havet                      NaN
# Heia                       8.0
# Himlen                     9.0
# ...                        ...
# Polden                     NaN
# Russland                   NaN
# Sagvika                    NaN
# Segelfoss                  NaN
# Segelfossen                NaN
# Sellanraa                  NaN
# Sirilund                   NaN
# Skogen                    11.0
# Stavanger                  NaN
# Storborg                   NaN
# Stordalen                  NaN
# Stortinget                 NaN
# Sveits                     NaN
# Sverige                    3.0
# Syden                      NaN
# Tiflis                     NaN
# Torahus                    NaN
# Toretind                   NaN
# Torpelviken                NaN
# Tromsø                     1.0
# Trondhjem                  NaN
# Tyskland                   2.0
# Ura                        NaN
# Utvær                      NaN
# Vangen                     NaN
# Verden                    20.0
# Vladikaukas                NaN
# Vælta                      NaN
# Washington                 NaN
# Ytrepolden                 NaN
#
# [88 rows x 46 columns]

# %% [markdown]
# En aggregering over hele korpuset

# %%
nb.frame_sort(nb.frame(opptelling.sum(axis=1)))
# Out:
#                      0
# Verden           838.0
# Skogen           718.0
# Jorden           598.0
# Amerika          579.0
# Norges_Land      561.0
# Polden           523.0
# Segelfoss        401.0
# Marken           384.0
# Gaden            335.0
# Jær              276.0
# Himlen           273.0
# Doppen           209.0
# Sirilund         204.0
# Norge            174.0
# Lofoten          149.0
# Sellanraa        137.0
# Myren            134.0
# Trondhjem        133.0
# Bergen           128.0
# Bjørger_Sulheim  127.0
# New_England      112.0
# New_York         112.0
# Havet             86.0
# Torahus           80.0
# Europa            73.0
# Indrebygden       62.0
# Amerikas_Vesten   59.0
# Tiflis            54.0
# Sverige           52.0
# Nordland          50.0
# ...                ...
# Aabakken          20.0
# Oslo              20.0
# Chicago           20.0
# Berlin            18.0
# Ytrepolden        17.0
# Jerusalem         17.0
# Segelfossen       17.0
# Washington        17.0
# Vælta             17.0
# Hopan             16.0
# København         16.0
# Bokhara           15.0
# Boston            15.0
# Levanger          15.0
# Nuten             15.0
# Moritz            14.0
# Natal             14.0
# Grimstad          14.0
# Fuglværø          14.0
# Stordalen         13.0
# Harrow            12.0
# Canada            11.0
# Drammen            9.0
# Frankrike          9.0
# Stavanger          9.0
# Minneapolis        9.0
# Syden              6.0
# Danmark            4.0
# Russland           3.0
# Grønland           2.0
#
# [88 rows x 1 columns]

# %% [markdown]
# ## Kommando `vis_bok`
#
# Med den kommandoen benyttes deler av metadata for å finne boken. Skriv en bit av metadata, årstall og tittel. Bokens tittel står over kolonnen.

# %%
vis_bok('Marken')
# Out:
#              Markens Grøde
# Marken                80.0
# Skogen                61.0
# Sellanraa             49.0
# Jorden                33.0
# Breidablik            30.0
# Verden                18.0
# Trondhjem             15.0
# Bergen                14.0
# Himlen                12.0
# Sverige               10.0
# Norges_Land            6.0
# Myren                  5.0
# Maaneland              4.0
# Amerika                1.0
# Finland                1.0
# Norge                  1.0

# %% [markdown]
# # Lag en graf for en bok
#
# Grafene kan legges sammen i etterkant om det ønskes en graf for hele korpuset.

# %%
# fyll inn en indeks fra korpuslisten 0 er første URN, 1 neste osv. eller benytt korpus_oppføring

G = tm.character_network(korpus_oppføring(korpus, 'Mark'), redigerte_navn)
gnl.show_graph(G)

# %%
nb.metadata(korpus['urn'][3])
# Out:
# [[2009061012004,
#   'Hamsun, Knut',
#   1889,
#   'Fra det moderne Amerikas Aandsliv',
#   '',
#   'Philipsen',
#   'unknown',
#   '949c8474bef0068c4d97f02c2f646284',
#   'nob',
#   '']]

# %% [markdown]
# Dernest kan den vises og analyseres med passende kommandoer

# %%
korpus.urn[3]
# Out:
# '2009061012004'
