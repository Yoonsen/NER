# %% [markdown]
# ## Oppstart

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import dhlab.nbtext as nb
import dhlab.token_map as tm
from dhlab.nbtext import get_urn, make_graph, get_urn, relaterte_ord, navn, totals
import dhlab.graph_networkx_louvain as gnl
import pandas as pd
import networkx as nx

# %matplotlib inline

plot = lambda x,  lw=3, alpha= 0.7: x.plot(figsize=(15,6), lw=lw, alpha=alpha)

# %%
from dhlab.module_update import update, css
css()

import dhlab.graph_networkx_louvain as gnl
import dhlab.nbtext as nb
import networkx as nx
# %matplotlib inline
import dhlab.module_update as mu
import warnings
warnings.filterwarnings('ignore')
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # Hjelpekommandoer
#
# I den her notebooken er det satt opp kode for å telle opp navn i et korpus. Både listen med navn og korpuset må foreligge som excelfiler. Noen av kommandoene vil bli lagt til `token_map`-modulen
#
# * `tell_navn` teller opp navnene på tvers av korpuset
# * `korpus_oppføring` finner data i korpuset
# * `vis_bok` viser navn i en spesifikk bok (benytter oppførings-kommandoen)
# * `aggregate_pr_col` aggregerer navnedata over kolonner.

# %%
import pandas as pd
from nbtext import metadata

def alle_korpusnavn(korpus):
    urner = nb.pure_urn(korpus)
    alle_navn = tm.combine_names(tm.corpus_names(urner))
    return alle_navn

def tell_navn(korpus, token_map):
    res = dict()
    for urn in nb.pure_urn(korpus['urn']):
        try:
            res[urn] = tm.count_name_strings(str(urn), token_map)
            res[urn].columns = [str(urn)]
        except:
            print("Problemer med å telle fra: ", urn)
    return pd.concat([res[u] for u in res], axis=1)

def korpus_oppføring(df, text, column='tittel'):
    return nb.pure_urn(df[df[column].str.contains(text)]['urn'])

def add_metadata(korpus, how='inner'):
    f = nb.frame([(z[0], '_'.join([str(x) for x in z[2:4]])) for z in nb.metadata(korpus['urn'])], 'urn metadata'.split())
    f = f.astype({'urn':'str'})
    return korpus.merge(f, on = 'urn', how = how)
    
vis_bok = lambda x, column = 'tittel': nb.frame_sort(nb.frame(opptelling[korpus_oppføring(korpus, x, column)[0]].dropna(), nb.metadata(korpus_oppføring(korpus, x, column)[0])[0][3]))

   
def bygg_allgraf(korpus):
    graphs = dict()
    for u in korpus.urn:
        graphs[u] = tm.character_network(u, redigerte_navn)
    df_graphs = [nx.to_pandas_adjacency(graphs[x]) for x in graphs]
    g = df_graphs[0]
    for z in df_graphs[1:]:
        g = g.add(z, fill_value=0).fillna(0)

    total_graph = nx.from_pandas_adjacency(g)
    return total_graph

# %% [markdown]
# ## Navn i bøker
#
#
# Vi søker etter navn i en bok, og en serie av bøker.
#
# Kommandoene er:
# 1. `names` henter et sett med forslag til navn, fra nbtext
# 1. `show_names` gir en oversikt over funnene, fra token_map
# 1. `names_to_token_map_file` lagrer navneforslagene til en excelfil (eller csv) for redigering (token_map)
# 1. `read_token_map_file` henter redigert fil tilbake for analyse (token_map)
# 1. `character_network` lager graf for navnene (token_map)
# 1. `show_graph`  tegner grafen (fra graph_networkx_louvain)
# 1. `show_communities` viser clustre i grafen (graph_networkx_louvain)

# %% [markdown]
# ## Korpus
#
# Hent korpus fra excelfil. Det er korpuset det skal telles opp fra. Korpuset som genererer navn kan godt være forskjellig fra der det telles.

# %%
korpus = nb.restore_metadata_from_excel('Hamsuns_data/Alt_Hamsunkorpus.xls')
korpus
# Out:
#               urn          forf    år                             tittel  \
# 0   2008112113001  Hamsun, Knut  1877                     Den Gaadefulde
# 1   2009061013011  Hamsun, Knut  1878                            Bjørger
# 2   2009061013012  Hamsun, Knut  1878                         Et gjensyn
# 3   2015051929001  Hamsun, Knut  1890                               Sult
# 4   2008123012002  Hamsun, Knut  1892                          Mysterier
# 5   2008123012003  Hamsun, Knut  1893                     Redaktør Lynge
# 6   2008123010002  Hamsun, Knut  1893                            Ny Jord
# 7   2008082710002  Hamsun, Knut  1894                                Pan
# 8   2008123010003  Hamsun, Knut  1895                    Ved Rigets Port
# 9   2009010210001  Hamsun, Knut  1896                        Livets Spil
# 10  2009051513003  Hamsun, Knut  1897                             Siesta
# 11  2007060512003  Hamsun, Knut  1898                          Aftenrøde
# 12  2009050610002  Hamsun, Knut  1898                           Victoria
# 13  2008122912002  Hamsun, Knut  1902                       Munken Vendt
# 14  2016011129002  Hamsun, Knut  1903                    Dronning Tamara
# 15  2008122910001  Hamsun, Knut  1903                           Kratskog
# 16  2008122912001  Hamsun, Knut  1903                      I Æventyrland
# 17  2009051813001  Hamsun, Knut  1904                      Det vilde Kor
# 18  2009050810001  Hamsun, Knut  1904                           Sværmere
# 19  2009051813003  Hamsun, Knut  1905                      Stridende Liv
# 20  2008122910003  Hamsun, Knut  1906                 Under Høststjærnen
# 21  2009060913006  Hamsun, Knut  1908                               Rosa
# 22  2013040824080  Hamsun, Knut  1908                             Benoni
# 23  2009061903032  Hamsun, Knut  1909         Vandrer spiller med Sordin
# 24  2008123010001  Hamsun, Knut  1910                        Livet ivold
# 25  2008091603019  Hamsun, Knut  1912                       sidste Glæde
# 26  2008091603009  Hamsun, Knut  1913                      Børn av Tiden
# 27  2013040824053  Hamsun, Knut  1915                       Segelfoss By
# 28  2013040824060  Hamsun, Knut  1915                       Segelfoss By
# 29  2010061108018  Hamsun, Knut  1917                      Markens Grøde
# 30  2014031208133  Hamsun, Knut  1917                      Markens Grøde
# 31  2008091603017  Hamsun, Knut  1920             Konerne ved Vandposten
# 32  2008091603013  Hamsun, Knut  1920             Konerne ved Vandposten
# 33  2009051413002  Hamsun, Knut  1923                      Siste kapitel
# 34  2014021807090  Hamsun, Knut  1923                      Siste kapitel
# 35  2014120206051  Hamsun, Knut  1927                       Landstrykere
# 36  2008091603021  Hamsun, Knut  1927                       Landstrykere
# 37  2008091603020  Hamsun, Knut  1930                             August
# 38  2009061010002  Hamsun, Knut  1933                    Men Livet lever
# 39  2009061013010  Hamsun, Knut  1933                    Men Livet lever
# 40  2014080408001  Hamsun, Knut  1936                     Ringen sluttet
# 41  2012041208040  Hamsun, Knut  1936                     Ringen sluttet
# 42  2008042201022  Hamsun, Knut  1949               Paa gjengrodde stier
# 43  2008091204050  Hamsun, Knut  1997                  Knut Hamsuns brev
# 44  2010031603013  Hamsun, Knut  1995                  Knut Hamsuns brev
# 45  2009032400042  Hamsun, Knut  1999                  Knut Hamsuns brev
# 46  2008010400002  Hamsun, Knut  1994                  Knut Hamsuns brev
# 47  2008112804029  Hamsun, Knut  2000                  Knut Hamsuns brev
# 48  2008110500029  Hamsun, Knut  2001                  Knut Hamsuns brev
# 49  2015090706177  Hamsun, Knut  2009                                 26
# 50  2014090308131  Hamsun, Knut  2009                                 27
# 51  2009061012004  Hamsun, Knut  1889  Fra det moderne Amerikas Aandsliv
# 52  2009042313001  Hamsun, Knut  1889                       Lars Oftedal
#
#                             undertittel  \
# 0   en Kjærlighedshistorie fra Nordland
# 1                            fortælling
# 2                                   NaN
# 3                                   NaN
# 4                                 Roman
# 5                                 Roman
# 6                                 Roman
# 7     af Løjtnant Thomas Glahns Papirer
# 8                               Forspil
# 9                                   NaN
# 10                              Skitser
# 11                        Slutningsspil
# 12               en Kærligheds Historie
# 13                 Brigantinens Saga, 1
# 14                 Skuespil i tre Akter
# 15                 Historier og Skitser
# 16         oplevet og drømt i Kaukasien
# 17                                Digte
# 18                                Roman
# 19      Skildringer fra Vesten og Østen
# 20               en Vandrers Fortælling
# 21         af Student Parelius' Papirer
# 22                                roman
# 23                                  NaN
# 24                Skuespil i fire Akter
# 25                          Skildringer
# 26                                Roman
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                  NaN
# 31                                roman
# 32                                roman
# 33                                roman
# 34                                roman
# 35                                roman
# 36                                roman
# 37                                roman
# 38                                Roman
# 39                                Roman
# 40                                roman
# 41                                roman
# 42                                  NaN
# 43                                  NaN
# 44                                  NaN
# 45                                  NaN
# 46                                  NaN
# 47                                  NaN
# 48                                  NaN
# 49                                    1
# 50                                    2
# 51                                  NaN
# 52                               Udkast
#
#                                                forlag  sjanger  \
# 0                                               Urdal  unknown
# 1                        [K. Hamsund];Alb.Fr. Knudsen  unknown
# 2                             [s.n.];Alb. Fr. Knudsen  unknown
# 3                                           Philipsen    novel
# 4                                           Philipsen  unknown
# 5                                           Philipsen  fiction
# 6                                           Philipsen  unknown
# 7                                           Philipsen  unknown
# 8                                           Philipsen  unknown
# 9                                 Det Nordiske Forlag  unknown
# 10                                          Gyldendal  unknown
# 11                                          Gyldendal  unknown
# 12                                        Cammermeyer  unknown
# 13                                          Gyldendal  unknown
# 14                                          Gyldendal  unknown
# 15                                          Gyldendal  unknown
# 16                                          Gyldendal  unknown
# 17                                          Gyldendal  unknown
# 18                                          Gyldendal    novel
# 19                                          Gyldendal  unknown
# 20                                          Gyldendal  unknown
# 21                                          Gyldendal  unknown
# 22                                          Gyldendal  unknown
# 23                                          Gyldendal  unknown
# 24                                          Gyldendal  unknown
# 25                                          Gyldendal  unknown
# 26                                          Gyldendal  unknown
# 27  Gyldendalske Boghandel, Nordisk Forl.;Kristian...  unknown
# 28  Gyldendalske Boghandel, Nordisk Forl.;Kristian...    novel
# 29             Gyldendal;Kristiania : Gyldendal, 1917    novel
# 30             Gyldendal;Kristiania : Gyldendal, 1917    novel
# 31             Gyldendal;Kristiania : Gyldendal, 1920  unknown
# 32             Gyldendal;Kristiania : Gyldendal, 1920  unknown
# 33             Gyldendal;Kristiania : Gyldendal, 1923  unknown
# 34             Gyldendal;Kristiania : Gyldendal, 1923  unknown
# 35                   Gyldendal;Oslo : Gyldendal, 1927  unknown
# 36                                          Gyldendal    novel
# 37                   Gyldendal;Oslo : Gyldendal, 1930  unknown
# 38                   Gyldendal;Oslo : Gyldendal, 1933  unknown
# 39                   Gyldendal;Oslo : Gyldendal, 1933  unknown
# 40                   Gyldendal;Oslo : Gyldendal, 1936  unknown
# 41                   Gyldendal;Oslo : Gyldendal, 1936  unknown
# 42                                          Gyldendal  unknown
# 43              Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 44              Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 45              Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 46              Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 47              Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 48              Gyldendal;Oslo : Gyldendal, 1994-2000  fiction
# 49            Gyldendal;[Oslo] : Gyldendal, 2007-2009  Artiler
# 50            Gyldendal;[Oslo] : Gyldendal, 2007-2009  Artiler
# 51                                          Philipsen  unknown
# 52                                            Litleré  unknown
#
#                              sesamid Unnamed: 8 Unnamed: 9
# 0   05b5fb8e2ffab70be305373f9857ee85        NaN        NaN
# 1   709614fcb48740925154af4130d7a26c        NaN        NaN
# 2   233ad96c3f3bedf1739ceb29a81534d4        NaN        NaN
# 3   b4a0a4c7765fa29eb4a1ba910405806e        NaN        NaN
# 4   9f41e621267dd5475db9b7e45cd00367        NaN        NaN
# 5   e09ea1ee062affda9ab9fdfde810517c        NaN        NaN
# 6   aca8b7840508f729920970a51fea6c05        NaN        NaN
# 7   8dab706553bacde19fa1a30c06896464        NaN        NaN
# 8   c8af50e6f92caeaa7742b651358e2b14        NaN        NaN
# 9   8637d081c40a6df2c59789f422b08c11        NaN        NaN
# 10  e7e8524d734b0bab8c2219d349be3c6e        NaN        NaN
# 11  a36c73ddd25674f39f55c7e233dd0770        NaN        NaN
# 12  f9d1cf36853110d6cf3206ccc0e2fc44        NaN        NaN
# 13  89ee1bececa7b691dafdf6f785b236b7        NaN        NaN
# 14  be5af477838b99c1ede33603bebc20c8        NaN        NaN
# 15  fc7c0e985dd11d120bebb9c3f15bffbc        NaN        NaN
# 16  2b981c264b0802a5fc53a8d432440e98        NaN        NaN
# 17  f7b71bb94d2eb6269ec46f7db668edc3        NaN        NaN
# 18  c6be34a1385f8e08463cedd6d8357210        NaN        NaN
# 19  5a7697d5ef98464f854bcd1ce7a0a66d        NaN        NaN
# 20  8444ebbd3ae76c073402385f4fb94eff        NaN        NaN
# 21  3217b178aebb23c537a7b079b6918c47        NaN        NaN
# 22  9d1f9278a5efbae4d4dd7974884f9b09        NaN        NaN
# 23  429be57bdf2c1e6fd7e93ff396bb0d93        NaN        NaN
# 24  e3c975a4d23b31c74aaf84b3dde8f6ac        NaN        NaN
# 25  ef5a096eec2b9dfd62804ca5206a0b86        NaN        NaN
# 26  3fc74605bf0797503d11e45bbe7ef46a        NaN        NaN
# 27  dda8bcfee25faf1e9ffef20ed82481ee        NaN        NaN
# 28  1817dddda3ff7813ed26ee2beeb92eca        NaN        NaN
# 29  13bb08ae191453c60f12d10e61b52d21        NaN        NaN
# 30  d390323bccea6638401abbbe56d29de9        NaN        NaN
# 31  3cd39d276984d99c14d910fc6ea831c3        NaN        NaN
# 32  db23307bbe720ef10d2cf491fbda2854        NaN        NaN
# 33  6b165f349c6d1ad8b10b12767d05af99        NaN        NaN
# 34  d620a47d78476aeb9ca3c6f559ced648        NaN        NaN
# 35  1c06629ee0ce402dabd1a3811a525f68        NaN        NaN
# 36  9c37b0255a568e33ba8881fb419a1ca9        NaN        NaN
# 37  0db115a4d4add3babdeb047424cbd9f7        NaN        NaN
# 38  d219a60217cd7f071f9b3cf0ae47764e        NaN        NaN
# 39  5315b3baf2bbf3bdab8f68e00afbfd45        NaN        NaN
# 40  09b45d357db99fa31238dfd8bdcba944        NaN        NaN
# 41  d52f345765f569fa7300c8f8e9d4a2d6        NaN        NaN
# 42  a49e4e77ab01e0e04aff4e71de753dbe        NaN        NaN
# 43  016db7c52214bce8e3612c2608b4b61c        nob        NaN
# 44  23df19922b203f588261e34304351de1        nob        NaN
# 45  3be2e2a46b0a788081c6e72cbf24761f        nob        NaN
# 46  131e85b5bbc3800dcb60bc9afd588459        nob        NaN
# 47  8206fe4a8ec2fac45ac6f3d2a9c7639c        mul        NaN
# 48  33b6512367fc496d55846e601217d98d        nob        NaN
# 49  8ef05f138ad5c6e53b221d9b537be8ef        NaN        NaN
# 50  41f5ddbb1a756b9f602e417058db88f8        NaN        NaN
# 51  949c8474bef0068c4d97f02c2f646284        NaN        NaN
# 52  9b6cc05c90fa5a5ccc27f018e2c27281        NaN        NaN

# %% [markdown]
# ## Sjekk innholdet
#
# Gjør noen søk for å se at alt er ok. Konkordanser er fine til det.

# %%
nb.urn_concordance(word = 'Ganges', urns = korpus)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122910001?searchText=Ganges' target='_blank' style='text-decoration:none'>Kratskog, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>. Kanske ved Bredden af</td>
#                 <td>Ganges</td>
#                 <td style='text-align:left'>hvor Lotosen aldrig visned .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009061010002?searchText=Ganges' target='_blank' style='text-decoration:none'>Men Livet lever, Hamsun, Knut, 1933</a>
#                 </td>
#                 <td>det var Sus , var</td>
#                 <td>Ganges</td>
#                 <td style='text-align:left'>og Amazonflod , Suset blev</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015090706177?searchText=Ganges' target='_blank' style='text-decoration:none'>Samlede verker, Hamsun, Knut, 2009</a>
#                 </td>
#                 <td>Syden , til breddene av</td>
#                 <td>Ganges</td>
#                 <td style='text-align:left'>der menneskets første vugge stod</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015090706177?searchText=Ganges' target='_blank' style='text-decoration:none'>Samlede verker, Hamsun, Knut, 2009</a>
#                 </td>
#                 <td>land , til bredden av</td>
#                 <td>Ganges</td>
#                 <td style='text-align:left'>hvor de første menneskers vugge</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015090706177?searchText=Ganges' target='_blank' style='text-decoration:none'>Samlede verker, Hamsun, Knut, 2009</a>
#                 </td>
#                 <td>land , til bredden av</td>
#                 <td>Ganges</td>
#                 <td style='text-align:left'>hvor de første menneskers vugge</td>
#             </tr>
# </table>

# %%
collword = 'Tyskland'

# %%
tot = nb.totals(50000)

# %%
coll = nb.urn_coll(collword, urns = list(korpus.urn), after = 5, before = 5, limit = 10)

# %%
coll/tot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-11243c70a4d3> in <module>
# ----> 1 coll/tot
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#    1486     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1487
# -> 1488         other = _align_method_FRAME(self, other, axis)
#    1489
#    1490         if isinstance(other, ABCDataFrame):
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _align_method_FRAME(left, right, axis)
#    1456     elif is_list_like(right) and not isinstance(right, (ABCSeries, ABCDataFrame)):
#    1457         # GH17901
# -> 1458         right = to_series(right)
#    1459
#    1460     return right
#
# D:\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in to_series(right)
#    1417             if len(left.columns) != len(right):
#    1418                 raise ValueError(
# -> 1419                     msg.format(req_len=len(left.columns), given_len=len(right))
#    1420                 )
#    1421             right = left._constructor_sliced(right, index=left.columns)
#
# ValueError: Unable to coerce to Series, length must be 1: given 50000

# %% [markdown]
# ### Hent redigert fil
#
# Husk at verdien på orient må være lik mellom lagring og lesing av excelfil. Typisk for den her type redigering er radorientering. Excel har en begrensning på 256 kolonner, som blir for smått for de fleste anvendelser. Det er tilnærmet ubegrenset kapasitet på antall rader.

# %%
redigerte_navn = tm.read_token_map_file('samledestedsnavn_Hamsunkorpus.xls', orient = "row")

# %% [markdown]
# ## Tell opp navn med hensyn til det som står i `redigerte_navn`
#
# Bruker hjelpekommando `tell_navn`. Det kan ta litt tid å telle opp, et par minutter.

# %%
opptelling = tell_navn(korpus, redigerte_navn)

# %% [markdown]
# Sånn ser opptellingen ut, en kolonne pr. bok.

# %%
opptelling.head()
# Out:
#           2008112113001  2009061013011  2009061013012  2015051929001  \
# Aabakken           20.0            NaN            NaN            NaN
# Aas                 6.0            NaN            NaN            NaN
# Afrika              NaN            NaN            NaN            NaN
# Amerika             NaN            NaN            NaN            NaN
# Ananur              NaN            NaN            NaN            NaN
#
#           2008123012002  2008123012003  2008123010002  2008082710002  \
# Aabakken            NaN            NaN            NaN            NaN
# Aas                 NaN            NaN            NaN            NaN
# Afrika              1.0            NaN            NaN            1.0
# Amerika             2.0            9.0            5.0            NaN
# Ananur              NaN            NaN            NaN            NaN
#
#           2008123010003  2009010210001      ...        2008091204050  \
# Aabakken            NaN            NaN      ...                  NaN
# Aas                 NaN            NaN      ...                  6.0
# Afrika              NaN            NaN      ...                  NaN
# Amerika             NaN            NaN      ...                 39.0
# Ananur              NaN            NaN      ...                  NaN
#
#           2010031603013  2009032400042  2008010400002  2008112804029  \
# Aabakken            NaN            NaN            NaN            NaN
# Aas                71.0            2.0           18.0            1.0
# Afrika              2.0            NaN            NaN            6.0
# Amerika            27.0           66.0          133.0           50.0
# Ananur              NaN            NaN            NaN            NaN
#
#           2008110500029  2015090706177  2014090308131  2009061012004  \
# Aabakken            NaN            NaN            NaN            NaN
# Aas                20.0            NaN            NaN            NaN
# Afrika              NaN            2.0            2.0            3.0
# Amerika            26.0          121.0           61.0          307.0
# Ananur              NaN            NaN            NaN            NaN
#
#           2009042313001
# Aabakken            NaN
# Aas                 NaN
# Afrika              NaN
# Amerika             4.0
# Ananur              NaN
#
# [5 rows x 53 columns]

# %% [markdown]
# Opptelling totalt for korpuset, summering over alle bøkene.

# %%
nb.frame_sort(nb.frame(opptelling.sum(axis=1)))
df = nb.frame_sort(nb.frame(opptelling.sum(axis=1)))

# %%
df.to_excel("tall.xls")

# %%
steder = nb.frame_sort(nb.frame(opptelling.sum(axis=1)))
steder.to_dict()[0]
# Out:
# {'Aabakken': 20.0,
#  'Aas': 128.0,
#  'Afrika': 31.0,
#  'Amerika': 1104.0,
#  'Ananur': 7.0,
#  'Argentina': 21.0,
#  'Armenia': 7.0,
#  'Asien': 23.0,
#  'Asker': 29.0,
#  'Atlanta': 3.0,
#  'Atlanterhavet': 27.0,
#  'Aurdal': 155.0,
#  'Australien': 33.0,
#  'Baku': 40.0,
#  'Balberg': 18.0,
#  'Baltimore': 1.0,
#  'Batum': 6.0,
#  'Bayern': 5.0,
#  'Belgien': 40.0,
#  'Bergen': 426.0,
#  'Berlin': 227.0,
#  'Bjærget': 38.0,
#  'Bodø': 102.0,
#  'Bokhara': 15.0,
#  'Bolivia': 9.0,
#  'Boston': 26.0,
#  'Brasil': 2.0,
#  'Breidablik': 48.0,
#  'Brevik': 6.0,
#  'Bryne': 2.0,
#  'Byen': 1633.0,
#  'Bygdø': 28.0,
#  'California': 5.0,
#  'Chicago': 72.0,
#  'Christiania': 2029.0,
#  'Cordilleras': 4.0,
#  'Dakota': 19.0,
#  'Danmark': 250.0,
#  'Danzig': 5.0,
#  'Doppen': 209.0,
#  'Drammen': 40.0,
#  'Drøbak': 82.0,
#  'Dubrovnik': 20.0,
#  'Egersund': 18.0,
#  'Egypten': 23.0,
#  'Elverum': 24.0,
#  'England': 404.0,
#  'Equador': 1.0,
#  'Europa': 213.0,
#  'Finland': 138.0,
#  'Finmarken': 40.0,
#  'Fjell': 20.0,
#  'Flandern': 2.0,
#  'Florø': 4.0,
#  'Fosenlandet': 40.0,
#  'Frankrike': 143.0,
#  'Fredrikstad': 9.0,
#  'Fuglværø': 14.0,
#  'Gaarden': 713.0,
#  'Gaden': 538.0,
#  'Ganges': 5.0,
#  'Garmo': 17.0,
#  'Gaustad': 9.0,
#  'Gjørvik': 10.0,
#  'Gjøvik': 52.0,
#  'Grand_Hotel': 136.0,
#  'Grekenland': 19.0,
#  'Grimstad': 716.0,
#  'Grønland': 67.0,
#  'Gudbrandsdalen': 21.0,
#  'Guinea': 4.0,
#  'Haag': 8.0,
#  'Hamar': 17.0,
#  'Hamarøy': 346.0,
#  'Hammerfest': 5.0,
#  'Hamsund': 73.0,
#  'Hannover': 55.0,
#  'Hardanger': 34.0,
#  'Harrow': 12.0,
#  'Harstad': 32.0,
#  'Haugesund': 12.0,
#  'Havet': 213.0,
#  'Heia': 23.0,
#  'Helsingfors': 117.0,
#  'Holmestrand': 10.0,
#  'Hornbæk': 25.0,
#  'Horten': 12.0,
#  'Hønefoss': 5.0,
#  'Hørup': 15.0,
#  'Indien': 67.0,
#  'Indrebygden': 62.0,
#  'Italien': 43.0,
#  'Japan': 28.0,
#  'Jerusalem': 28.0,
#  'Jorden': 714.0,
#  'Judea': 3.0,
#  'Kairo': 1.0,
#  'Kanada': 49.0,
#  'Kansas': 4.0,
#  'Kaukasien': 46.0,
#  'Kentucky': 26.0,
#  'Kina': 19.0,
#  'Kongsberg': 69.0,
#  'Konstantinopel': 41.0,
#  'Kreml': 5.0,
#  'Kristianssand': 52.0,
#  'Kristiansund': 66.0,
#  'Kvæfjord': 6.0,
#  'Kystby': 6.0,
#  'København': 621.0,
#  'Landvik': 199.0,
#  'Larvik': 206.0,
#  'Levanger': 16.0,
#  'Lillehammer': 33.0,
#  'Lillesand': 245.0,
#  'Lofoten': 154.0,
#  'Lom': 38.0,
#  'London': 79.0,
#  'Lyon': 6.0,
#  'Maaneland': 32.0,
#  'Mandal': 4.0,
#  'Marken': 531.0,
#  'Marseille': 3.0,
#  'Mexico': 31.0,
#  'Midtvesten': 1.0,
#  'Minneapolis': 100.0,
#  'Mleti': 6.0,
#  'Molde': 11.0,
#  'Montana': 3.0,
#  'Moskva': 69.0,
#  'Munchen': 30.0,
#  'Myren': 193.0,
#  'Narvik': 20.0,
#  'Natal': 14.0,
#  'Nationen': 74.0,
#  'Nevada': 5.0,
#  'New_Orleans': 9.0,
#  'New_Zealand': 8.0,
#  'Niam-Niam': 1.0,
#  'Norden': 101.0,
#  'Nordland': 193.0,
#  'Norge': 1168.0,
#  'Nuten': 15.0,
#  'Nørholmen': 1280.0,
#  'Odessa': 4.0,
#  'Ohio': 10.0,
#  'Orienten': 20.0,
#  'Ostende': 15.0,
#  'Otta': 2.0,
#  'Paris': 432.0,
#  'Pennsylvania': 1.0,
#  'Persien': 23.0,
#  'Peru': 4.0,
#  'Petersburg': 19.0,
#  'Polden': 524.0,
#  'Polen': 29.0,
#  'Portugal': 6.0,
#  'Prærien': 5.0,
#  'Quebec': 4.0,
#  'Rio': 7.0,
#  'Roma': 49.0,
#  'Rosengård': 20.0,
#  'Rostov': 1.0,
#  'Rusland': 202.0,
#  'Saba': 41.0,
#  'Sagvika': 30.0,
#  'Samsø': 36.0,
#  'Sarpsborg': 31.0,
#  'Segelfoss': 530.0,
#  'Sellanraa': 139.0,
#  'Serbien': 12.0,
#  'Sibir': 9.0,
#  'Sirilund': 212.0,
#  'Skandinavien': 29.0,
#  'Skogen': 609.0,
#  'Småbyen': 2.0,
#  'Sortehavet': 16.0,
#  'Spania': 27.0,
#  'Spitsbergen': 5.0,
#  'Stavanger': 48.0,
#  'Steppen': 21.0,
#  'Stockholm': 162.0,
#  'Stokmarknes': 20.0,
#  'Storborg': 42.0,
#  'Stordalen': 13.0,
#  'Stortinget': 124.0,
#  'Stranden': 3.0,
#  'Suezkanalen': 5.0,
#  'Sveits': 57.0,
#  'Sverige': 217.0,
#  'Svolvær': 9.0,
#  'Sydafrika': 3.0,
#  'Sydamerika': 48.0,
#  'Syden': 33.0,
#  'Sørlandet': 13.0,
#  'Theresegade': 38.0,
#  'Tiflis': 58.0,
#  'Torahus': 80.0,
#  'Toretind': 24.0,
#  'Torpelviken': 31.0,
#  'Tromsø': 60.0,
#  'Trondhjem': 171.0,
#  'Tvedestrand': 3.0,
#  'Tyrkia': 52.0,
#  'Tyskland': 685.0,
#  'Ungarn': 12.0,
#  'Ura': 23.0,
#  'Utvær': 22.0,
#  'Vadsø': 5.0,
#  'Valdres': 126.0,
#  'Vangen': 29.0,
#  'Venezia': 2.0,
#  'Verden': 1348.0,
#  'Vesteraalen': 19.0,
#  'Vestfjorden': 17.0,
#  'Vladikaukas': 26.0,
#  'Vælta': 17.0,
#  'Washington': 30.0,
#  'Wien': 71.0,
#  'Wisconsin': 42.0,
#  'Ytrepolden': 17.0,
#  'Ødemarken': 22.0,
#  'Østen': 71.0}

# %% [markdown]
# # Bygger grafer for alle bøkene
#
# Benytt hjelpekommandoen `bygg_allgraf` for å samle grafene i en stor total graf.

# %%
korpusgraf = bygg_allgraf(korpus)

# %% [markdown]
# Visualiser og analyser på vanlig måte.

# %%
gnl.show_graph(korpusgraf, spread= 1.9)

# %% [markdown]
# Forslag til clustre basert på grafen. Clusteralgoritmen for Louvain kan synes å være litt random, så resultatene kan varierere mellom kjøringer. Men det ser skapelig ut, og gir mening.

# %%
gnl.show_communities(korpusgraf)
# Out:
# Norge-Tyskland :  Norge, Tyskland, England, Danmark, Sverige, Rusland, Grønland, Norden, Belgien, Lillesand, Indien, Frankrike, Aas, Syden, Moskva, Sveits, Italien, Egypten, Polen, Japan, Haag, Kaukasien, Suezkanalen, Stortinget, Ganges, Sarpsborg, Kina, Stavanger, Petersburg, Drøbak, Serbien, Spitsbergen, New_Zealand, Sydamerika, Kreml, Saba, Dubrovnik, Asker, Hornbæk, Harrow, Aabakken, Armenia, Kristianssand, Mandal, Holmestrand, Kongsberg
#
# Verden-Byen :  Verden, Byen, Jorden, Marken, Gaarden, Polden, Sellanraa, Segelfoss, Skogen, Myren, Gaden, Grand_Hotel, Baku, Tyrkia, Tiflis, Havet, Breidablik, Maaneland, Storborg, Afrika, Roma, Sirilund, Lofoten, Konstantinopel, Grekenland, Drammen, Bjærget, Natal, Vladikaukas, New_Orleans, Sortehavet, Persien, Indrebygden, Ytrepolden, Toretind, Ødemarken, Orienten, Vestfjorden, Jerusalem, Bokhara, Rosengård, Fuglværø, Torahus, Vangen
#
# Amerika-Europa :  Amerika, Europa, Minneapolis, London, Doppen, Hamsund, Østen, Chicago, Boston, Kanada, Washington, Asien, Wisconsin, Fosenlandet, Nevada, Atlanterhavet, California, Prærien, Hannover, Garmo, Mexico, Dakota
#
# Christiania-København :  Christiania, København, Nørholmen, Grimstad, Paris, Lom, Stockholm, Finland, Berlin, Bergen, Nordland, Valdres, Tromsø, Gjøvik, Helsingfors, Hardanger, Gudbrandsdalen, Nationen, Landvik, Aurdal, Kristiansund, Wien, Hamar, Lillehammer, Narvik, Brevik, Theresegade, Vesteraalen, Balberg, Munchen, Lyon, Spania, Harstad, Bygdø, Fjell, Horten
#
# Hamarøy-Larvik :  Hamarøy, Larvik, Trondhjem, Bodø, Skandinavien, Elverum

# %%
collword = 'Tyskland'

# %%
coll = nb.urn_coll(collword, urns = korpus, after = 5, before = 5, limit = 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-e871a9e9a693> in <module>()
# ----> 1 coll = nb.urn_coll(collword, urns = korpus, after = 5, before = 5, limit = 1000)
#
# ~/anaconda3/lib/python3.6/site-packages/dhlab/nbtext.py in urn_coll(word, urns, after, before, limit)
#     487     """Find collocations for word in a set of book URNs. Only books at the moment"""
#     488
# --> 489     if isinstance(urns[0], list):  # urns assumed to be list of list with urn-serial as first element
#     490         urns = [u[0] for u in urns]
#     491
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
