# %% [markdown]
# ## Lag nye gazzetter

# %%
import dhlab.nbtext as nb

# %% [markdown]
# Bygg URN-er med ikke-oversatt materiale - det skal utelukke spesielt sære navn

# %%
urns = nb.book_corpus(limit=500000, trans='')

# %%
len(urns)
# Out:
# 382536

# %%
etternavn = list(map(lambda x: x.split(', ')[0], urns.author))
etternavn = list(set(etternavn))

# %%
navn = list(map(lambda x: x.split(', ')[-1], urns.author))

# %%
etternavn
# Out:
# ['',
#  'Bruheim',
#  'Price',
#  'Kumbhakar',
#  'Ula',
#  'Rummelhoff',
#  'Heijden',
#  'Lygren',
#  'Verdi',
#  'Seger',
#  'Bygballe',
#  'Dial',
#  'Sternberg',
#  'Pollen',
#  'Schein',
#  'Goderstad',
#  'Elverum',
#  'Bolkesjø',
#  'Krohn-Hansen',
#  'Engesæter',
#  'Paxton',
#  'Nord',
#  'Thunæs',
#  'I. (Orion)',
#  'Wendt',
#  'Torkelsgard',
#  'Røst',
#  'Heintges',
#  'Sundland',
#  'Hensrud',
#  'Lindvik',
#  'Lazonick',
#  'Gausvik',
#  'Fuldseth',
#  'Vislie',
#  'Haugeland',
#  'Tarrasón',
#  'Lucianus Samosatensis',
#  'Baumeister',
#  'Hjorth-Hansen',
#  'Andrésen',
#  'Kiøsterud',
#  'Søyseth',
#  'Morten',
#  'Bal',
#  'Himberg-Larsen',
#  'Overen',
#  'Langedal',
#  'Núñez',
#  'Poignant',
#  'Casagrande',
#  'Lamberg-Dahl,Trygve',
#  'Hillis',
#  'Kobro',
#  'Ugelvik',
#  'Ahmadi',
#  'Søhus',
#  'Barman',
#  'Tichy',
#  'Kringstad',
#  'Wiestad',
#  'Namtvedt',
#  'Sagan',
#  'Fridtun',
#  'Orvil',
#  'Jonason',
#  'Twena',
#  'Janner',
#  'Cerú',
#  'Weed',
#  'Steinbakk',
#  'Frederik',
#  'Norup',
#  'Casta',
#  'Jagadeesh',
#  'Riesman',
#  'Sollie',
#  'Hamm',
#  'Ones',
#  'Monsson',
#  'Rendell',
#  'Tranøy',
#  'McGarrighan',
#  'Fosstveit',
#  'Brosset',
#  'Gloppen',
#  'Bramming',
#  'Belden',
#  'Hasting',
#  'Olli',
#  'Frette',
#  'Andersen-Høntorp',
#  'Tørud',
#  'Jorand',
#  'Schöttler',
#  'Rekaa',
#  'Thargyal',
#  'Sydnes',
#  'Breiehagen',
#  'Simon',
#  'Holven',
#  'Barnéus',
#  'Rotabakk',
#  'Vartdal',
#  'Juan de la Cruz',
#  'Uhle',
#  'Ansari',
#  'Deursen',
#  'Bergson',
#  'Maastad',
#  'Lilløy',
#  'Dørge',
#  'Medgard',
#  'Esvall',
#  'Rønne',
#  'Lyshol',
#  'Skorgen',
#  'Saxi',
#  'Furberg',
#  'Widell',
#  'Deichmann',
#  'Šergin',
#  'Brandsegg',
#  'Vassnes',
#  'Nordkvelle',
#  'Brochmann',
#  'Ewensen',
#  'Valdersnes',
#  'Brekken',
#  'Ramasastry',
#  'En Forhenværende Kristiania-politimand',
#  'Windingstad',
#  'Ozick',
#  'Gershwin',
#  'Marø',
#  'Andreassen',
#  'L.',
#  'Tellnes',
#  'Gundeid',
#  'Holmefjord',
#  'Tronvold',
#  'Skjelkvåle',
#  'Ploug Hansen',
#  'Arntzen',
#  'Bugten',
#  'Kvittem',
#  'Abelson',
#  'Bruzell',
#  'Hjorthaug',
#  'Qvam',
#  'Linløkken',
#  'Thor',
#  'Skaflem',
#  'Elsness',
#  'Andersland',
#  'Liavåg',
#  'Carey',
#  'Bjørgo',
#  'Herheim',
#  'Gisle',
#  'Børkje',
#  'Hanken',
#  'Malmin',
#  'Ekroth',
#  'Eidsaa',
#  'Dybfest',
#  'Aanrud',
#  'Outis',
#  'Robertsen',
#  'Cowie',
#  'Linjordet',
#  'Gausel',
#  'Ligård',
#  'Teksum',
#  'Blegen',
#  'Arvin',
#  'Spencer',
#  'Åsteson',
#  'Aspdahl',
#  'Veflingstad',
#  'Theodorus',
#  'Kristinsson',
#  'Rybalka',
#  'Skottun',
#  'Willassen',
#  'Riste',
#  'Ingram',
#  'Vanem',
#  'Tong',
#  'Kaldestad',
#  'Nauni',
#  'Bøhren',
#  'Skårset',
#  'Opøien',
#  'Storlien',
#  'Pouchet',
#  'Torlei',
#  'Waterhouse',
#  'Le Brun',
#  'Ulseth',
#  'Aker',
#  'Evstigneev',
#  'Hogben',
#  'Svensgaard',
#  'Buvik',
#  'Novak',
#  'Josua Stylites',
#  'Munk Christiansen',
#  'Lysebraate',
#  'Greaker',
#  'Spitznogle',
#  'Engene',
#  'Engbers',
#  'Warren',
#  'Bjaalid',
#  'Nereid',
#  'Setreng',
#  'Breiland',
#  'Friis',
#  'Kyrkjebø',
#  'Samuelsen',
#  'Leren',
#  'Lightfoot',
#  'Bjørdal',
#  'Bringager',
#  'Clemens Romanus',
#  'Muskaug',
#  'Fossnes',
#  'Hundsnes',
#  'Hestness',
#  'Øidne',
#  'Trageton',
#  'Slåstad',
#  'Olafsen',
#  'Falch',
#  'Scheen',
#  'Bodal',
#  'Morterud',
#  'Skjørland',
#  'Mjøset',
#  'Bjørkøy',
#  'Kalenuik',
#  'Luger',
#  'Lundström',
#  'Sneve',
#  'Ydstebø',
#  'Tornow',
#  'Svartbekk',
#  'Nilson',
#  'Hetsch',
#  'Grahm-Haga',
#  'Reusch',
#  'Halgunset',
#  'Stenius',
#  'Syrrist',
#  'Lindem',
#  'Kjønaas',
#  'Disraeli',
#  'Skålin',
#  'Sandsund',
#  'Mascaro',
#  'Andonowati',
#  'Kinnapel',
#  'Salameh',
#  'Sommervoll',
#  'Edwien',
#  'Habermas',
#  'Hadwen',
#  'Høvding',
#  'Kvikstad',
#  'Ham',
#  'Sylvain',
#  'Hurum',
#  'Sudmann',
#  'Kibsgaard',
#  'Steinshylla',
#  'Bamrud',
#  'Martinovic',
#  'Charles',
#  'Myrmel',
#  'Grímur Jónsson Thorkelín',
#  'Passano',
#  'Kornmann',
#  'Tronslien',
#  'Gade',
#  'Songstad',
#  'Amama',
#  'Klinge',
#  'Lundetræ',
#  'Hestbråten',
#  'Swahn',
#  'Jørve',
#  'Heins',
#  'Jounge-Sturesson',
#  'Aldington',
#  'Sortland',
#  'Danesh',
#  'Petrov',
#  'Gamst',
#  'Hancock',
#  'Lønningen',
#  'Dobinson',
#  'Landråk',
#  'Gausemel',
#  'Deck',
#  'Hordnes',
#  'Uhlin',
#  'Fleischer',
#  'McCafferty',
#  'Sathananthan',
#  'Krossøy',
#  'Svedfelt',
#  'Neraas',
#  'Gunnerud',
#  'Mørk Petersen',
#  'Berggraf-Jacobsen',
#  'Svanæs',
#  'Harthug',
#  'Lysvåg',
#  'Vadla',
#  'Chlebnikov',
#  'Seglsten',
#  'Rygge',
#  'Horge',
#  'Torstensen',
#  'Puck',
#  'Godejord',
#  'Mosdøl',
#  'Borgsø',
#  'Nørve',
#  'Marlitt',
#  'Haarseth',
#  'Årflot',
#  'Klepešta',
#  'Nicholay',
#  'Bakke-Wiik',
#  'Sijthoff-Stray',
#  'Bjørneby',
#  'Buland',
#  'Fredh',
#  'Sandholtbråten',
#  'Colombine',
#  'Sælen',
#  'Tovman',
#  'Oklevik',
#  'Stephanius',
#  'Almvik',
#  'Pillay',
#  'Bargel',
#  'Hauge',
#  'Roren',
#  'Gulden',
#  'Olaug',
#  'Kongshøj Madsen',
#  'Øvstedal',
#  'Grip',
#  'Glette',
#  'Brubaker',
#  'Høvås',
#  'Berre',
#  'Mjåvatn',
#  'Vefald',
#  'Warakagoda',
#  'Hanssen',
#  'Stangeby',
#  'Coniglio',
#  'Bagøien',
#  'Skovholt',
#  'Kvendset',
#  'Sturm',
#  'Uthberg',
#  'Thorsnæs',
#  'Kegel Christensen',
#  'Bjorvatn',
#  'Gammel Feltpræst',
#  'Ulriksen',
#  'Marty',
#  'Glomsrød',
#  'Nordal-Pedersen',
#  'Bjellånes',
#  'Foosnæs',
#  'Plotinus',
#  'Stene-Johansen',
#  'Roaldset',
#  'Grønland',
#  'Ramnefalk',
#  'Ramstad',
#  'Aarne',
#  'Ólafsdóttir',
#  'Randsted',
#  'Hæstrup',
#  'Grynning',
#  'Bjørstad',
#  'Forbech',
#  'Geitung',
#  'Krishnamurti',
#  'Hotman',
#  'Mowat',
#  'Katz',
#  'Holsæter',
#  'Svalastog',
#  'Aasvik',
#  'Everett-Green',
#  'Burns',
#  'Parneman',
#  'Overaae',
#  'Hestmark',
#  'Gullteig',
#  'Kræmmer',
#  'Vibe',
#  'Skard',
#  'Gratt',
#  'Waage',
#  'Isbrekken',
#  'Staff',
#  'Stillingen',
#  'Siqveland',
#  'Bjørtomt',
#  'Friestad',
#  'Zetterquist',
#  'Hedgecoe',
#  'Nunn',
#  'Høgberg',
#  'Camus',
#  'Polaczek',
#  'Lambertz-Nilssen',
#  'Hemmingbye',
#  'Erdman',
#  'Oleivsgard',
#  'Langholm',
#  'Adekanye',
#  'Nome',
#  'Coxon',
#  'Byström',
#  'Opsal',
#  'Soler-Espiauba',
#  'Arnoldi',
#  'Liardon',
#  'Tengs',
#  'Måseidvåg',
#  'Tutvedt',
#  'Havrevold',
#  'Sarvig',
#  'Lindi',
#  'Dyken',
#  'Flammarion',
#  'Ellertsen',
#  'Wærhaug',
#  'Frøysa',
#  'Orlik',
#  'Warming',
#  'Asting',
#  'Øien',
#  'Ekerhovd',
#  'Sadolin',
#  'Bangum',
#  'Hellemsvik',
#  'Ourdahl',
#  'Nyhaug',
#  'Aae',
#  'Finslo',
#  'Silverstolpe',
#  'Riefling',
#  'Slungaard',
#  'Bilek',
#  'Ringdahl',
#  'Dahl-Goli',
#  'McLaren',
#  'Buckholm',
#  'Jeryis',
#  'Heyerdahl',
#  'Wirkola',
#  'Steinsvik',
#  'Eugen',
#  'Hoprekstad',
#  'Maråk',
#  'Hetmar',
#  'Key',
#  'Kjukum',
#  'Brande',
#  'Frame',
#  'Marschhäuser',
#  'Hordik',
#  'Andvord',
#  'Schäpers',
#  'Reff',
#  'Jiyad',
#  'Monssen',
#  'A.P.M.',
#  'Celdran',
#  'Melien',
#  'Reikerås',
#  'Steensholt',
#  'Hamar',
#  'Sulakshin',
#  'Hestholm',
#  'Godtfredsen',
#  'Yeats',
#  'Hansgård',
#  'Granlien',
#  'Veie',
#  'Dunne',
#  'Wirtz',
#  'Colleuille',
#  'Kjerschow',
#  'Lobstein',
#  'Vembe',
#  'Fritzner',
#  'Nørgaard',
#  'Valeberg',
#  'Sjåvaag',
#  'Karlöf',
#  'Utgaard',
#  'Hørthe',
#  'Brouwers',
#  'Kjetså',
#  'Norsk Skibsfører',
#  'Miljeteig-Olssen',
#  'Börestam Uhlmann',
#  'Niclas',
#  'Tinnen',
#  'Wijk-Andersson',
#  'Törner',
#  'Baggethun',
#  'Azadi',
#  'Bratlie-Jensen',
#  'Breidablik',
#  'Bégat',
#  'Gjerland',
#  'Tholuck',
#  'Grimset',
#  'Clostermann',
#  'Skyberg',
#  'Skarestad',
#  'Døvre',
#  'Čertkov',
#  'Budtz',
#  'Goodpasture',
#  'Stangeland',
#  'Ekra',
#  'Tjore',
#  'Bjork',
#  'Vannebo',
#  'Mørch',
#  'Westerman',
#  'Årva',
#  'Sandahl',
#  'Bolay',
#  'Pavlakovi?',
#  'Bjerk-Amundsen',
#  'Thune-Larsen',
#  'Vaktskjold',
#  'Tokle',
#  'Undstad',
#  'Hanström',
#  'Chochorowski',
#  'Røeggen',
#  'Søraker',
#  'Torjesen',
#  'Schubert',
#  'Botheim',
#  'Hagedal',
#  'Fett',
#  'Titlestad',
#  'Øvrebekk',
#  'Frichsen',
#  'Havnsund',
#  'Lersjö',
#  'Borchmann',
#  'Bonesmo',
#  'Bergquist',
#  'Bærland',
#  'Aano',
#  'Mead',
#  'Galapo',
#  'Skjerdal',
#  'Apalseth',
#  'Austlid',
#  'Staavi',
#  'Berdouaré',
#  'Jarbekk',
#  'Bruscia',
#  'Kvilhaug',
#  'Imerslund',
#  'Hare',
#  'Hylleraas',
#  'Vaagen',
#  'Krøgenes',
#  'Brotnov',
#  'Widerøe',
#  'Kilstad',
#  'Westrem',
#  'Myrvågnes',
#  'Omestad',
#  'Robøle',
#  'Ziesler',
#  'Vetvik',
#  'Raude',
#  'Wellek',
#  'Østervold',
#  'Myrtveit',
#  'Møllerup',
#  'Boaz',
#  'Pitts',
#  'Reilstad',
#  'Erslev',
#  'Moilanen',
#  'Jeshua ben Joseph ha-Levi',
#  'Hjort',
#  'Bjørkli',
#  'Lønningdal',
#  'Sundlöf',
#  'Hjorth-Jenssen',
#  'Kjesrud',
#  'Lauvås',
#  'Tafjord',
#  'Oniščik',
#  'Ulltang',
#  'Vivelid',
#  'Gjesbach',
#  'Miller',
#  'Wikshåland',
#  'Kielland',
#  'Raaholt',
#  'Knuteid',
#  'Rømmesmo',
#  'Aakre',
#  'Hogness',
#  'Sartorius',
#  'Tobiesen',
#  'Soknes',
#  'Havrøy',
#  'Hatle',
#  'Enerstvedt',
#  'Fredriksfryd',
#  'Erlingur Jóhannsson',
#  'Kimo',
#  'Vanderbilt',
#  'Bergstedt',
#  'Nedregård',
#  'Richter',
#  'Østlund',
#  'Arnvard',
#  'Racine',
#  'Steinert',
#  'Westergaard Andersen',
#  'Tørå',
#  'Dybdahl-Henriksen',
#  'Skogedal',
#  'Jarvoll',
#  'Kofoed-Olsen',
#  'Barfoed',
#  'Havnerås',
#  'Aursnes',
#  'Marsden',
#  'Sulutvedt',
#  'Vingen',
#  'Mikki',
#  'Harir',
#  'Wergeland',
#  'Leistad',
#  'Løftingsmo',
#  'Lehre',
#  'Fjellanger',
#  'Oksholen',
#  'Jiao',
#  'Vodahl',
#  'Torgals',
#  'Godeseth',
#  'Manes',
#  'Asschenfeldt-Hansen',
#  'Koivulehto',
#  'Thoner',
#  'Asmervik',
#  'Fricke',
#  'Naterop',
#  'Setten',
#  'Lilleskare',
#  'Skogvoll',
#  'Dragseth',
#  'Gresvig',
#  'Kollandsrud',
#  'Chambers',
#  'Marnor',
#  'Ellekjær',
#  'Gueltzer',
#  'Dubi',
#  'Meen',
#  'Buch',
#  'Friis Mogensen',
#  'Slupphaug',
#  'Brunborg',
#  'Osnes',
#  'Tettli',
#  'Lorem',
#  'Mitterer',
#  'Meiraak',
#  'Buisman',
#  'Gebremedhin',
#  'Stokseth',
#  'Flagestad',
#  'Veian',
#  "N'jie",
#  'Frost Andersen',
#  'Rikstad',
#  'Lyng',
#  'Bircherod',
#  'Bernardshaw',
#  'Lilienskiold',
#  'Bøsterud',
#  'Illeris',
#  'Firth',
#  'Prikler',
#  'Levold',
#  'Bøyesen',
#  'Kjæret',
#  'Duraturo',
#  'Bergsaune',
#  'Critobulus',
#  'Baach',
#  'Selvaag',
#  'Rosnes',
#  'Jaunn',
#  'Sotberg',
#  'Hertle',
#  'Furusjö',
#  'Morkemo',
#  'Ciano',
#  'Iversen',
#  'Ulsnæs',
#  'Midtsæter',
#  'Augdal',
#  'Skauge',
#  'Fjærestrand',
#  'Einarsson',
#  'Gunvik',
#  'Zorriassateiny',
#  'Sageie',
#  'Kaada',
#  'Quarsten',
#  'Haugsvær',
#  'Løbersli',
#  'Hidle',
#  'Bjørnaas',
#  'Gjøse',
#  'Storsveen',
#  'Bonsaksen',
#  'Kirchhoff',
#  'Hildebrandt',
#  'Monaldini',
#  'Grepperud',
#  'Bekana',
#  'Kjeldaas',
#  'Limstrand',
#  'Hastad',
#  'Fylling',
#  'Paulsson',
#  'Fabre',
#  'Rossetti',
#  'Bunn',
#  'Bokn',
#  'Tennung',
#  'Lefeber',
#  'Birkemoe',
#  'Beer',
#  'Glasser',
#  'Gjerdsjø',
#  'Devins',
#  'Skifjeld',
#  'Stielow',
#  'Storm-Nielsen',
#  'Thurmann-Moe',
#  'Rimbereid',
#  'Skåber',
#  'Kaikumo',
#  'Braad',
#  'Kindt',
#  'Borchgrevink',
#  'Kolnar',
#  'Hagenson',
#  'Løchen',
#  'Traaen',
#  'Ihre',
#  'Betzy',
#  'Hovd',
#  'Bhaduri',
#  'Saude',
#  'Oldgard',
#  'Rasmussen',
#  'Pethrus',
#  'Aarvik',
#  'Henningsmoen',
#  'Zürn',
#  'Heiene',
#  'Skar',
#  'McCormack',
#  'Quintilianus',
#  'Tøsse',
#  'Schneidemühl',
#  'Addo',
#  'Rua',
#  'Bruun-Kristensen',
#  'Thorkell Helgason',
#  'Guldberg',
#  'Gaasemyr',
#  'Ulsness',
#  'Denis',
#  'Julusmoen',
#  'Birkely',
#  'Klein',
#  'Rowe',
#  'Strømøy',
#  'Gjære',
#  'Osdalen',
#  'Margolis',
#  'Toivonen',
#  'Mjaavatn',
#  'Brundenius',
#  'Bjørnov',
#  'Alseth',
#  'Lund-Larsen',
#  'Brønlund',
#  'Kvæven',
#  'Krogshus',
#  'Kadison',
#  'Bårdseth',
#  'Falck-Hansen',
#  'Bollvåg',
#  'Barros',
#  'Germidis',
#  'Palamodov',
#  'Furuskjeg',
#  'Elgaaen',
#  'Millerjord',
#  'Parkin',
#  'Neskvern',
#  'Døcker-Smith',
#  'Brand',
#  'Aarefjord',
#  'Tandberg',
#  'Reinhardt',
#  'Dufseth',
#  'Tingstad',
#  'Aukland',
#  'Langlais',
#  'Gunnari',
#  'Heggen',
#  'Hanyga',
#  'Teslo',
#  'Capon',
#  'Nguyên',
#  'Fastvold',
#  'Tauler',
#  'Raknem',
#  'Ytterdal',
#  'Schjølberg-Gamnes',
#  'Bjerkem',
#  'Midtgarden',
#  'Saalbach',
#  'Notø',
#  'Andersen-Randberg',
#  'Hellingsrud',
#  'Baur',
#  'Teigum',
#  'Grogarn',
#  'Rishaug',
#  'Sanness',
#  'Cohen',
#  'Leithe',
#  'Hesjadalen',
#  'Pfaff',
#  'Kjøll',
#  'Bjørke',
#  'Borrebæk',
#  'Hardeland',
#  'Finnøy',
#  'Hepner',
#  'Giger',
#  'Bratrud',
#  'Collee',
#  'Mhagama',
#  'Forsyth',
#  'Reedtz',
#  'Deichman',
#  'Maze',
#  'Skyttermoen',
#  'Rishøi',
#  'Killingtveit',
#  'Coyne',
#  'Batem',
#  'Finckenhagen',
#  'Jiang',
#  'Bank',
#  'Ådna',
#  'Gauslaa',
#  'Arstein',
#  'Schie',
#  'Risdal',
#  'Ramfjord',
#  'Højgaard',
#  'Skau',
#  'Dinghas',
#  'Tiitta',
#  'Hugdahl',
#  'Fröhberg',
#  'Døhlie',
#  'Yazdankhah',
#  'Hagedorn',
#  'Lillelien',
#  'Lindqvist',
#  'Hedin',
#  'Bjørneberg',
#  'Kolbjørnsen',
#  'Folkman',
#  'Kuure',
#  'Tuhus',
#  'Derry',
#  'Le Maire',
#  'Uppheim',
#  'Franzen',
#  'Rawlett',
#  'Stig',
#  'Barrio',
#  'Midtsundstad',
#  'Inglar',
#  'Tornholm',
#  'Ditlew',
#  'Lanser',
#  'Wigg',
#  'Tvetbråten',
#  'Thomassen',
#  'Sandberg',
#  'Starosj',
#  'Petrini',
#  'Borch',
#  'Leite',
#  'Goldsmith',
#  'Wilhelmsen',
#  'Dønheim',
#  'Failla',
#  'Riesto',
#  'Østgård',
#  'Hannaas',
#  'Karim',
#  'Windsor',
#  'Langemyr',
#  'Hanssøn',
#  'Wiley',
#  'Svensson',
#  'Gjelseth',
#  'Prasolova-Førland',
#  'Kjæserud',
#  'Sandbukt',
#  'Justad',
#  'Sørlie',
#  'Fjørtoft-Godø',
#  'Herbert',
#  'Grundt-Pedersen',
#  'Nordvi',
#  'Lyngås',
#  'Bie-Johansen',
#  'Horsle',
#  'Fossåskaret',
#  'Stifjeld',
#  'Akerlie',
#  'Skogseid',
#  'Millar',
#  'Oterholt',
#  'Román',
#  'Sikakane',
#  'Etzelmüller',
#  'Åsbakk',
#  'Ek',
#  'Hellebostad',
#  'Ugelstad',
#  'Syversen',
#  'Matthiesen',
#  'Andresen',
#  'Westergård',
#  'Sherr',
#  'Lysklett',
#  'Waalen',
#  'Eriksrud',
#  'Horpestad',
#  'Hindhamar',
#  'Bjørgum',
#  'Smørholm',
#  'Taraldsen',
#  'Kongshavn',
#  'Mutukumira',
#  'Nielson',
#  'Meining',
#  'Martinussen',
#  'Brenning',
#  'Fredhøi',
#  'Klausen',
#  'Afdal',
#  'Dånmark',
#  'Wenneck',
#  'Brekstad',
#  ...]
