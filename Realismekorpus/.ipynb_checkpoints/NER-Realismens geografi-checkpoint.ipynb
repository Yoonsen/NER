# %% [markdown]
# ## Oppstart

# %%
from dhlab.module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Note that the file `nbtext.py` will be overwritten in the code below
#
# This is probably ok, though. If not, change `update('nbtext', overwrite = True)` to `update('nbtext', overwrite = False)` and the file will stay unchanged.

# %%
import dhlab.nbtext as nb
import dhlab.token_map as tm
from dhlab.nbtext import get_urn, make_graph, get_urn, relaterte_ord, navn, totals
import dhlab.graph_networkx_louvain as gnl
import pandas as pd
import networkx as nx
# %matplotlib inline

plot = lambda x,  lw=3, alpha= 0.7: x.plot(figsize=(15,6), lw=lw, alpha=alpha)

# %% [markdown]
# # Hjelpekommandoer
#
# `alle_korpusnavn` henter ut alle navn (eller forslag til) fra korpuset.
# `tell_navn` teller opp navnene på tvers av korpuset

# %%
import pandas as pd

def alle_korpusnavn(korpus):
    urner = nb.pure_urn(korpus)
    alle_navn = tm.combine_names(tm.corpus_names(urner))
    return alle_navn

def tell_navn(korpus, token_map):
    res = dict()
    for urn in korpus['urn']:
        res[urn] = tm.count_name_strings(str(urn), token_map).to_dict()[0]
    return pd.DataFrame(pd.DataFrame(res).sum(axis=1).sort_values(ascending=False))

# %% [markdown]
# ## Navn i bøker
#
#
# Vi søker etter navn i en bok, og en serie av bøker.
#
# Kommandoene er:
# 1. `names` henter et sett med forslag til navn, fra nbtext
# 1. `show_names` gir en oversikt over funnene, fra token_map
# 1. `names_to_token_map_file` lagrer navneforslagene til en excelfil (eller csv) for redigering (token_map)
# 1. `read_token_map_file` henter redigert fil tilbake for analyse (token_map)
# 1. `character_network` lager graf for navnene (token_map)
# 1. `show_graph`  tegner grafen (fra graph_networkx_louvain)
# 1. `show_communities` viser clustre i grafen (graph_networkx_louvain)

# %%
#korpus = nb.book_corpus(author='Skram%')

# %%
korpus = nb.restore_metadata_from_excel('Realismekorpus.xls')

# %%
nb.pure_urn(korpus)
# Out:
# ['2016091248055',
#  '2008012902003',
#  '2008072412004',
#  '2012092706021',
#  '2015102908007',
#  '2008072312006',
#  '2008072312008',
#  '2016061508006',
#  '2008072410002',
#  '2012081009561',
#  '2012112908109',
#  '2015102208205',
#  '2008072810001',
#  '2014060406030',
#  '2011011420015',
#  '2014090908158',
#  '2009102212006',
#  '2007060400004',
#  '2014111808073',
#  '2016092848113',
#  '2014100708075',
#  '2009111612018',
#  '2008040700041',
#  '2012012008212',
#  '2011062712001',
#  '2014102708091',
#  '2014090408112',
#  '2006082500032',
#  '2013031108025',
#  '2015090108020',
#  '2016111648042',
#  '2016111048509',
#  '2006081600054',
#  '2014111308208',
#  '2016111748516',
#  '2012030208159',
#  '2006082800025',
#  '2016020208028',
#  '2015062208117',
#  '2015011608151',
#  '2015120408050',
#  '2015102208207',
#  '2014030707087',
#  '2016101248085',
#  '2009020903024',
#  '2016061748037',
#  '2016040608138',
#  '2016060848064',
#  '2014090308001',
#  '2016042848118',
#  '2014012108004',
#  '2016063008131',
#  '2014032108017',
#  '2014031108073',
#  '2012101007041',
#  '2015110000000',
#  '2013040000000',
#  '2009040000000',
#  '2015060000000',
#  '2016090000000',
#  '2014020000000',
#  '2013070000000',
#  '2013010000000',
#  '2012050000000',
#  '2015070000000',
#  '2010070000000',
#  '2011070000000',
#  '2009040000000',
#  '2012020000000',
#  '2014010000000',
#  '2014010000000',
#  '2015050000000',
#  '2009040000000']

# %% [markdown]
# ## Sjekk innholdet
#
# Gjør noen søk for å se at alt er ok. Konkordanser er fine til det. Her går urnene gjennom `nb.pure_urn` -  i fremtiden skal det ikke være nødvendig.

# %%
nb.urn_concordance(word = 'Trondhjem', urns = nb.pure_urn(korpus))
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016091248055?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Bondefortellinger, Bjørnson, Bjørnstjerne, 1992</a>
#                 </td>
#                 <td>og bukser til meg i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>, som jeg skulle få</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014090408112?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Skipper Worse, Kielland, Alexander L., 1973</a>
#                 </td>
#                 <td>nordover - lenger enn til</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016020208028?searchText=Trondhjem' target='_blank' style='text-decoration:none'>fremsynte eller Billeder fra Nordland, Lie, Jonas, 1913</a>
#                 </td>
#                 <td>Han var egentlig fra</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>, hvorfra han som ubemidlet</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016020208028?searchText=Trondhjem' target='_blank' style='text-decoration:none'>fremsynte eller Billeder fra Nordland, Lie, Jonas, 1913</a>
#                 </td>
#                 <td>” eller „ Nu brænder</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>” .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016020208028?searchText=Trondhjem' target='_blank' style='text-decoration:none'>fremsynte eller Billeder fra Nordland, Lie, Jonas, 1913</a>
#                 </td>
#                 <td>for Anledningen pyntede Stuepige fra</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>havde Plads i den rummelige</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015062208117?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Gaa paa!, Lie, Jonas, 1911</a>
#                 </td>
#                 <td>til at ligge oppe i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015062208117?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Gaa paa!, Lie, Jonas, 1911</a>
#                 </td>
#                 <td>Udpramningen af endel Last fra</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>paagik, og Lind havde travlt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015062208117?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Gaa paa!, Lie, Jonas, 1911</a>
#                 </td>
#                 <td>har taget Eksamen oppe i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>. « » Ja er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016042848118?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Rutland, Lie, Jonas, 1906</a>
#                 </td>
#                 <td>Bergen , paa fire til</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>og paa halvanden Uge helt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016042848118?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Rutland, Lie, Jonas, 1906</a>
#                 </td>
#                 <td>Elven i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>nedenfor Broen var tæt pakket</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016042848118?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Rutland, Lie, Jonas, 1906</a>
#                 </td>
#                 <td>at vi har Penge i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>. ” — Hun begyndte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016042848118?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Rutland, Lie, Jonas, 1906</a>
#                 </td>
#                 <td>Daler , som staar i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>. Ser Du , saa</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016063008131?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Tremasteren "Fremtiden", Lie, Jonas, 1918</a>
#                 </td>
#                 <td>. Nede i Banken i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>skulde han have staaende paa</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016063008131?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Tremasteren "Fremtiden", Lie, Jonas, 1918</a>
#                 </td>
#                 <td>Lyst . Paa Latinskolen i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>havde han jo allerede i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016063008131?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Tremasteren "Fremtiden", Lie, Jonas, 1918</a>
#                 </td>
#                 <td>Aars Tid været nede i</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>og var der , som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016063008131?searchText=Trondhjem' target='_blank' style='text-decoration:none'>Tremasteren "Fremtiden", Lie, Jonas, 1918</a>
#                 </td>
#                 <td>fulgt en sydgaaende Jagt til</td>
#                 <td>Trondhjem</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# </table>

# %% [markdown]
# ## Navn
#
# Finn forslag til navn med `names`. Se på dem med `show_names`. Her er det muligheter til å skru litt på parametrene. Hvis ratioen skrus ned fjernes en del ord, og om cutoff settes høyere vil også enkelte navneforslag kunne forsvinne.

# %% [markdown]
# Velg hvilken bok som skal studeres (alle kan tas, men se under). Se på listen over korpus og sett den indeksen som passer. Her er det bare å føle seg frem.

# %%
korpus
# Out:
#               urn                    forf    år  \
# 1   2016091248055  Bjørnson, Bjørnstjerne  1992
# 2   2008012902003  Bjørnson, Bjørnstjerne  1877
# 3   2008072412004  Bjørnson, Bjørnstjerne  1884
# 4   2012092706021  Bjørnson, Bjørnstjerne  1968
# 5   2015102908007  Bjørnson, Bjørnstjerne  1888
# 6   2008072312006  Bjørnson, Bjørnstjerne  1879
# 7   2008072312008  Bjørnson, Bjørnstjerne  1877
# 8   2016061508006  Bjørnson, Bjørnstjerne  1922
# 9   2008072410002  Bjørnson, Bjørnstjerne  1894
# 10  2012081009561  Bjørnson, Bjørnstjerne  1999
# 11  2012112908109  Bjørnson, Bjørnstjerne  1928
# 12  2015102208205  Bjørnson, Bjørnstjerne  1862
# 13  2008072810001  Bjørnson, Bjørnstjerne  1882
# 14  2014060406030  Bjørnson, Bjørnstjerne  2010
# 15  2011011420015  Kielland, Alexander L.  1999
# 16  2014090908158  Kielland, Alexander L.  1913
# 17  2009102212006  Kielland, Alexander L.  1881
# 18  2007060400004  Kielland, Alexander L.  1965
# 19  2014111808073  Kielland, Alexander L.  2009
# 20  2016092848113  Kielland, Alexander L.  1969
# 21  2014100708075  Kielland, Alexander L.  1993
# 22  2009111612018  Kielland, Alexander L.  1949
# 23  2008040700041  Kielland, Alexander L.  1891
# 24  2012012008212  Kielland, Alexander L.  1959
# 25  2011062712001  Kielland, Alexander L.  1880
# 26  2014102708091  Kielland, Alexander L.  1887
# 27  2014090408112  Kielland, Alexander L.  1973
# 28  2006082500032  Kielland, Alexander L.  1886
# 29  2013031108025  Kielland, Alexander L.  1898
# 30  2015090108020  Kielland, Alexander L.  1958
# ..            ...                     ...   ...
# 44  2016101248085              Lie, Jonas  1884
# 45  2009020903024              Lie, Jonas  1893
# 46  2016061748037              Lie, Jonas  1901
# 47  2016040608138              Lie, Jonas  1925
# 48  2016060848064              Lie, Jonas  1909
# 49  2014090308001              Lie, Jonas  1885
# 50  2016042848118              Lie, Jonas  1906
# 51  2014012108004              Lie, Jonas  1920
# 52  2016063008131              Lie, Jonas  1918
# 53  2014032108017              Lie, Jonas  1958
# 54  2014031108073              Lie, Jonas  1903
# 55  2012101007041              Lie, Jonas  1905
# 56  2015110000000           Skram, Amalie  1929
# 57  2013040000000           Skram, Amalie  1975
# 58  2009040000000           Skram, Amalie  1890
# 59  2015060000000           Skram, Amalie  1987
# 60  2016090000000           Skram, Amalie  1911
# 61  2014020000000           Skram, Amalie  1993
# 62  2013070000000           Skram, Amalie  1993
# 63  2013010000000           Skram, Amalie  1965
# 64  2012050000000           Skram, Amalie  1966
# 65  2015070000000           Skram, Amalie  2011
# 66  2010070000000           Skram, Amalie  1998
# 67  2011070000000           Skram, Amalie  1900
# 68  2009040000000           Skram, Amalie  1891
# 69  2012020000000           Skram, Amalie  1888
# 70  2014010000000           Skram, Amalie  1992
# 71  2014010000000           Skram, Amalie  1895
# 72  2015050000000           Skram, Amalie  1975
# 73  2009040000000           Skram, Amalie  1899
#
#                                                tittel  \
# 1                                   Bondefortellinger
# 2                                      Brude-slaatten
# 3                      Det flager i byen og på havnen
# 4                                        Fiskerjenten
# 5                                              Godset
# 6                                     Kaptejn Mansana
# 7                                            Magnhild
# 8                                                Mary
# 9                                    Nye Fortællinger
# 10                        Paul Lange og Tora Parsberg
# 11                                       På Guds veje
# 12                                        Smaastykker
# 13                                               Støv
# 14                                           Vis-Knut
# 15                              "Journal for de smaa"
# 16                                        Arbeidsfolk
# 17                                               Else
# 18                                          Folkefest
# 19                                            Fortuna
# 20                                     Garman & Worse
# 21                                               Gift
# 22                                Haabet er lysegrønt
# 23                                              Jacob
# 24                                        Novelletter
# 25                                    Nye Novelletter
# 26                                    Sankt Hans Fest
# 27                                      Skipper Worse
# 28                                                Sne
# 29                          To Noveletter fra Danmark
# 30                                            Torvmyr
# ..                                                ...
# 44                                        En Malstrøm
# 45                                              Niobe
# 46                             Naar Jernteppet falder
# 47                                  Naar sol gaar ned
# 48                                        Onde Magter
# 49                                  Otte fortællinger
# 50                                            Rutland
# 51                                          Et Samliv
# 52                            Tremasteren "Fremtiden"
# 53                                              Troll
# 54                                        Ulfvungerne
# 55  Østenfor Sol, vestenfor Maane og bagom Babylon...
# 56                                              Afkom
# 57                                 Bønn og anfektelse
# 58                                  Børnefortællinger
# 59                                     Constance Ring
# 60                                           Forraadt
# 61                                       Fortellinger
# 62                                           Fru Inés
# 63                                    Hellemyrsfolket
# 64                                    Hellemyrsfolket
# 65                                    Hellemyrsfolket
# 66                                  I det Asovske hav
# 67                                           Julehelg
# 68                           Kjærlighed i nord og syd
# 69                                              Lucie
# 70                                          Mennesker
# 71                               Professor Hieronimus
# 72                                       På St.Jørgen
# 73                                             Sommer
#
#                       undertittel                                forlag  \
# 1                             NaN                             Gyldendal
# 2                             NaN        Gyldendalske Boghandels Forlag
# 3                             NaN                             Gyldendal
# 4                             NaN                             Gyldendal
# 5                           roman                               Rössing
# 6       en Fortælling fra Italien                             Gyldendal
# 7                   en Fortælling                             Gyldendal
# 8                      fortælling                             Gyldendal
# 9                             NaN                             Gyldendal
# 10                            NaN                      Nationaltheatret
# 11                            NaN                             Gyldendal
# 12                            NaN                     Giertsen's Forlag
# 13                     fortælling                                [s.n.]
# 14                            NaN                   Gausdal historielag
# 15                            NaN          Alexander Kielland-forbundet
# 16                          Roman  Gyldendalske boghandel;Nordisk forl.
# 17              en Julefortælling                             Gyldendal
# 18                            NaN                             Fabritius
# 19                            NaN                             Gyldendal
# 20                            NaN                    Samlerens bokklubb
# 21                            NaN                 Den norske bokklubben
# 22                            NaN                                 Grieg
# 23                          Roman                             Gyldendal
# 24                            NaN                             Gyldendal
# 25                            NaN                             Gyldendal
# 26                     Fortælling                             Gyldendal
# 27                            NaN                 Den Norske Bokklubben
# 28                            NaN                             Gyldendal
# 29                            NaN                             Gyldendal
# 30                            NaN                                   NaN
# ..                            ...                                   ...
# 44                     fortælling                             Gyldendal
# 45                    Nutidsroman                             Gyldendal
# 46              af Livets Komedie                             Gyldendal
# 47                     fortælling                             Gyldendal
# 48                            NaN                             Gyldendal
# 49                            NaN                             Gyldendal
# 50                     fortælling                             Gyldendal
# 51                            NaN                Gyldendalske Boghandel
# 52                            NaN                             Gyldendal
# 53                            NaN                             Gyldendal
# 54  et Blad af Lidenskabernes Bog                             Gyldendal
# 55         Streif paa Jagtgebetet                Gyldendalske Boghandel
# 56                          roman                             Gyldendal
# 57          og andre fortellinger                             Gyldendal
# 58                            NaN                             Schubothe
# 59                            NaN                             Aschehoug
# 60                            NaN                             Gyldendal
# 61                            NaN                                   Pax
# 62                            NaN                 Den Norske bokklubben
# 63      Sjur Gabriel : fortælling                                  Eide
# 64                            NaN      Gyldendal;Oslo : Gyldendal, 1966
# 65                            NaN                             Gyldendal
# 66                            NaN                                  Damm
# 67                     fortælling                             Gyldendal
# 68                       Noveller                      Schubothes Forl.
# 69                            NaN                  Schubothes boghandel
# 70                            NaN                                   Pax
# 71                            NaN                             Gyldendal
# 72                            NaN                                   Pax
# 73              smaa fortællinger                             Gyldendal
#
#     sjanger                           sesamid språk  oversatt
# 1       NaN  a729bd8342d6cf8ea4a73acedbdca60f   nob       NaN
# 2   unknown  676654c5df2f9be0e0dc38b720052f7a   nob       NaN
# 3   unknown  b60c34903e04edfd45cf4d5af720f923   dan       NaN
# 4   fiction  4091da9c51f492bd3664f562177159b5   nob       NaN
# 5   unknown  0e585c13f94908c440fc80bf09b6933b   dut       NaN
# 6   unknown  a21c93bc745d5204724af3293c993662   nob       NaN
# 7   unknown  bac744f8e3de71c02679c54468990254   nob       NaN
# 8   unknown  95ebd955c6eb8c0a6c8146a61a6a2dd3   nob       NaN
# 9   unknown  de75a2072556c9fdcb7d5080496854cf   nob       NaN
# 10    drama  54d5cf43b7a65782b6a36739c8fa313e   nob       NaN
# 11    novel  c7cd5832ac91ce6c7927421fba00abf3   nob       NaN
# 12    drama  6541e6285ac468c92286d6196b882da7   und       NaN
# 13  unknown  13a44a62c6674bb2b188942afaf06ffb   nob       NaN
# 14  fiction  549d6be4ad968df607885ea3c658867d   nob       NaN
# 15  fiction  be24e2d09c96e061bae0325bb79ef375   nob       NaN
# 16  unknown  ab3de390f26b6dfe736b865a5dfa1655   nob       NaN
# 17  unknown  2ff4bca5fce636eea8617c06434b358a   nob       NaN
# 18  fiction  bdab1bdd7003b050f813c62dd6826980   nob       NaN
# 19    novel  7a9558f0cd1e44b547ffcc12097d9510   nob       NaN
# 20      NaN  d9d7c3f42085ec30a356deaed27fd720   nob       NaN
# 21  fiction  aa21c2982cd0b0272e1e8232d221778f   nob       NaN
# 22  unknown  5dae21a31753acb996812e679c2016b5   nob       NaN
# 23    novel  2c90486842bf85f05cbd702123ea5df5   nob       NaN
# 24  unknown  f499a492eda28c51f298742bea6ef26c   nob       NaN
# 25  unknown  0c7f7b687c129a586b6b35402f5fa73e   nob       NaN
# 26  unknown  e6b7c84097dc737fe0a5c3b727756791   nob       NaN
# 27  fiction  8d6a4225d5305231bfb7d67779897031   nob       NaN
# 28  unknown  c544c412a6b7ddc4c1abe7f36e93f8e1   nob       NaN
# 29  unknown  188ce3902e6f9a722b4d74093fc137ba   nob       NaN
# 30  unknown  60611b352f2e03a72270103980f206ca   nob       NaN
# ..      ...                               ...   ...       ...
# 44      NaN  668394cf3cd5160d0648bc881160a507   nob       NaN
# 45  unknown  479afa1ce06b03e06d35447b56de0663   nob       NaN
# 46  fiction  8c65bd55db01895b8a4b830fed8e174c   nob       NaN
# 47  unknown  af17aabad044e311c2ee98aca9b26c98   nob       NaN
# 48  fiction  d315da41dea27e987d52a5453cec9446   nob       NaN
# 49  unknown  3383ec0ba5862344de0a111bba697607   nob       NaN
# 50  fiction  9d81c13f483bc72eff5fd865418736ff   nob       NaN
# 51  unknown  0070d057b9237560019fe5f2ac7b27b8   nob       NaN
# 52  unknown  c24e67327b89e3044c79b109b49b2dc5   nob       NaN
# 53  fiction  293a4766b443053925b2698a1bc017c0   nob       NaN
# 54  unknown  a0346c5d6af0d60cb6b09b0a64d7febe   nob       NaN
# 55  fiction  75bd1993469c91f72f0a3891629cf523   nob       NaN
# 56  fiction  4ff3d230cef147887eac8f4043b4f9ec   nob       NaN
# 57  fiction  e490e34cb0bf57c997ff759f9989e6de   nob       NaN
# 58  unknown  633cec464b78b21279b896f2a6c47ce2   nob       NaN
# 59  fiction  77a46ed37d71ec95d699868379d3e42e   nob       NaN
# 60  unknown  ed31026019be64c25bba8cafd47d40cc   nob       NaN
# 61  fiction  1b2a12e8750d1a6628f06bd1c071265e   nob       NaN
# 62  fiction  b8ac7eea1aa70f105873a1fc09a83c22   nob       NaN
# 63  unknown  c31387d6ca8de33a3c59ba5528daf740   nno       NaN
# 64  fiction  310476bc2c6be9cd8fd7d8bc3aaa20fc   nob       NaN
# 65    novel  8aee394be7e8495daa86a2b611d9e0f5   nob       NaN
# 66  fiction  6689dd0478af02f3916017dc904b762c   nob       NaN
# 67  unknown  51d667d6a81d3981e7583a626705fc0f   nob       NaN
# 68  unknown  57ba462b8cfc2b5e4d38c56452934f61   nob       NaN
# 69  unknown  a9d724b2afab0e34aaa58dec8bfcb231   dan       NaN
# 70  fiction  87308cefacd819a3168ea4b94881392e   nob       NaN
# 71  unknown  52e638f5cdb2b1460acedf8d3c347f26   nob       NaN
# 72    novel  74e2270ce45e6b2362575dd52924e0c8   nob       NaN
# 73  unknown  58583488095266194c46290b8f391db9   nob       NaN
#
# [73 rows x 10 columns]

# %% [markdown]
# Finn korpuset ved å sette inn en index tilsvarende den som står helt til venstre i listen over.

# %% [markdown]
# Hent ut navn fra boken

# %%
total_names = alle_korpusnavn(korpus)

# %% [markdown]
# # Ta en titt på navneforslagene
#
# Men redigere dem i excel for å se. Navnene er hentet fra hele korpuset.

# %%
total_names

# %% [markdown]
# ### Lagring og redigering
#
# Rediger filen fra cellen med lagringskommando (`names_to_token_map_file(....)`)
# Listen trenger litt redigering, og sammenslåing. Lagre til Excel, og benytt `orient = column` for å ha navn i kolonnner, eller `orient = row` for å redigere radvis. Noen store filer med over 256 navn krever `row`. Kommandoen sjekker om filen allerede fins, og vil ikke skrive over. Følg med på output.

# %%
tm.names_to_token_map_file(total_names, filename = "Stedsnavn_Realismekorpus.xls", orient = "row")
# Out:
# True

# %% [markdown]
# ### Redigeringsaktivitet
#
# Åpne i for eksempel i excel eller tilsvarende som for eksempel openoffice eller libreoffice. Etter redigering, kjøres cellen under. Husk bare å benytte riktig filnavn.
#
# Husk at verdien på orient må være lik mellom lagring og lesing av excelfil.

# %%
redigerte_navn = tm.read_token_map_file("Realismekorpus.xls", orient = "row")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b830ca8317f0> in <module>()
# ----> 1 redigerte_navn = tm.read_token_map_file("Realismekorpus.xls", orient = "row")
#
# ~/Dropbox/Realismens geografi/token_map.py in read_token_map_file(filename, sep, orient)
#     117     result = []
#     118     for x in res:
# --> 119         xt = tuple(x.split())
#     120         for value in res[x]:
#     121             vt = tuple(value.split())
#
# AttributeError: 'numpy.float64' object has no attribute 'split'

# %% [markdown]
# ## Tell opp navn med hensyn til det som står i `redigerte_navn`
#
# Bruker hjelpekommando `tell_navn`. Det kan ta litt tid, noen minutter å telle opp.

# %%
opptelling = tell_navn(korpus, redigerte_navn)
opptelling
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f31b4961dff9> in <module>()
# ----> 1 opptelling = tell_navn(korpus, redigerte_navn)
#       2 opptelling
#
# NameError: name 'redigerte_navn' is not defined

# %% [markdown]
# # Lag en graf for en bok
#
# Grafene kan legges sammen i etterkant om det ønskes en graf for hele korpuset.

# %%
# fyll inn en indeks fra korpuslisten 0 er første URN, 1 neste osv.

G = tm.character_network(str(korpus['urn'][0]), redigerte_navn)
gnl.show_graph(G)

# %% [markdown]
# Dernest kan den vises og analyseres med passende kommandoer
