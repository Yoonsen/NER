# %%
import sqlite3
import json
import pandas as pd

# %%
geo_no = pd.read_csv("./NO/NO.txt", sep='\t', header=None)

# %%
header =[x.split(":")[0].strip() for x in  """geonameid         : integer id of record in geonames database
name              : name of geographical point (utf8) varchar(200)
asciiname         : name of geographical point in plain ascii characters, varchar(200)
alternatenames    : alternatenames, comma separated, ascii names automatically transliterated, convenience attribute from alternatename table, varchar(10000)
latitude          : latitude in decimal degrees (wgs84)
longitude         : longitude in decimal degrees (wgs84)
feature class     : see http://www.geonames.org/export/codes.html, char(1)
feature code      : see http://www.geonames.org/export/codes.html, varchar(10)
country code      : ISO-3166 2-letter country code, 2 characters
cc2               : alternate country codes, comma separated, ISO-3166 2-letter country code, 200 characters
admin1 code       : fipscode (subject to change to iso code), see exceptions below, see file admin1Codes.txt for display names of this code; varchar(20)
admin2 code       : code for the second administrative division, a county in the US, see file admin2Codes.txt; varchar(80) 
admin3 code       : code for third level administrative division, varchar(20)
admin4 code       : code for fourth level administrative division, varchar(20)
population        : bigint (8 byte int) 
elevation         : in meters, integer
dem               : digital elevation model, srtm3 or gtopo30, average elevation of 3''x3'' (ca 90mx90m) or 30''x30'' (ca 900mx900m) area in meters, integer. srtm processed by cgiar/ciat.
timezone          : the iana timezone id (see file timeZone.txt) varchar(40)
modification date : date of last modification in yyyy-MM-dd format""".split("\n")]

# %%
header
# Out:
# ['geonameid',
#  'name',
#  'asciiname',
#  'alternatenames',
#  'latitude',
#  'longitude',
#  'feature class',
#  'feature code',
#  'country code',
#  'cc2',
#  'admin1 code',
#  'admin2 code',
#  'admin3 code',
#  'admin4 code',
#  'population',
#  'elevation',
#  'dem',
#  'timezone',
#  'modification date']

# %%
geo_no.columns = header

# %%
geo_no[geo_no.name == 'Trondheim']
# Out:
#        geonameid       name  asciiname  \
# 10097    3133880  Trondheim  Trondheim
# 10098    3133881  Trondheim  Trondheim
#
#                                           alternatenames  latitude  longitude  \
# 10097  Kommun Trondheim,Nidaros,Nidrosia,THrandheimur...  63.43049   10.39506
# 10098  Gorad Tronkhejm,Kommun Trondheim,Nidrosia,THra...  63.42811   10.39687
#
#       feature class feature code country code  cc2  admin1 code  admin2 code  \
# 10097             P        PPLA2           NO  NaN         21.0       5001.0
# 10098             A         ADM2           NO  NaN         21.0       5001.0
#
#        admin3 code  admin4 code  population  elevation  dem     timezone  \
# 10097          NaN          NaN      147139        NaN   18  Europe/Oslo
# 10098          NaN          NaN      168257        NaN   18  Europe/Oslo
#
#       modification date
# 10097        2019-09-05
# 10098        2019-03-08

# %%
geo_no[geo_no["alternatenames"].fillna('').str.contains('Christiania')]
# Out:
#        geonameid  name asciiname  \
# 19351    3143244  Oslo      Oslo
#
#                                           alternatenames  latitude  longitude  \
# 19351  Asloa,Christiania (historical),Kristiania (his...  59.91273   10.74609
#
#       feature class feature code country code  cc2  admin1 code  admin2 code  \
# 19351             P         PPLC           NO  NaN         12.0        301.0
#
#        admin3 code  admin4 code  population  elevation  dem     timezone  \
# 19351          NaN          NaN      580000        NaN   26  Europe/Oslo
#
#       modification date
# 19351        2019-09-05

# %%
geo_no[geo_no['name'] == "Trondheim"]
# Out:
#        geonameid       name  asciiname  \
# 10097    3133880  Trondheim  Trondheim
# 10098    3133881  Trondheim  Trondheim
#
#                                           alternatenames  latitude  longitude  \
# 10097  Kommun Trondheim,Nidaros,Nidrosia,THrandheimur...  63.43049   10.39506
# 10098  Gorad Tronkhejm,Kommun Trondheim,Nidrosia,THra...  63.42811   10.39687
#
#       feature class feature code country code  cc2  admin1 code  admin2 code  \
# 10097             P        PPLA2           NO  NaN         21.0       5001.0
# 10098             A         ADM2           NO  NaN         21.0       5001.0
#
#        admin3 code  admin4 code  population  elevation  dem     timezone  \
# 10097          NaN          NaN      147139        NaN   18  Europe/Oslo
# 10098          NaN          NaN      168257        NaN   18  Europe/Oslo
#
#       modification date
# 10097        2019-09-05
# 10098        2019-03-08

# %%
geo_no.loc[10097]['alternatenames']
# Out:
# True

# %%
geo_no.to_json('geo_norsk.json')

# %%
geo = pd.read_json('geo_norsk.json')

# %%
geo[geo.name == 'Lofoten']
# Out:
#        geonameid     name asciiname           alternatenames  latitude  \
# 23153    3147088  Lofoten   Lofoten  Lofoten,Lofoten Islands  68.20483
#
#        longitude feature class feature code country code cc2  admin1 code  \
# 23153   12.79496             T         ISLS           NO  NO          9.0
#
#        admin2 code  admin3 code  admin4 code  population  elevation   dem  \
# 23153       1865.0          NaN          NaN           0        NaN -9999
#
#           timezone modification date
# 23153  Europe/Oslo        2018-01-29

# %%
geo[geo.alternatenames.fillna('').str.contains('Christiania')]
# Out:
#        geonameid  name asciiname  \
# 19351    3143244  Oslo      Oslo
#
#                                           alternatenames  latitude  longitude  \
# 19351  Asloa,Christiania (historical),Kristiania (his...  59.91273   10.74609
#
#       feature class feature code country code   cc2  admin1 code  admin2 code  \
# 19351             P         PPLC           NO  None         12.0        301.0
#
#        admin3 code  admin4 code  population  elevation  dem     timezone  \
# 19351          NaN          NaN      580000        NaN   26  Europe/Oslo
#
#       modification date
# 19351        2019-09-05

# %%
geo[geo.alternatenames.fillna('').str.contains('Nidaros')]
# Out:
#        geonameid       name  asciiname  \
# 10097    3133880  Trondheim  Trondheim
#
#                                           alternatenames  latitude  longitude  \
# 10097  Kommun Trondheim,Nidaros,Nidrosia,THrandheimur...  63.43049   10.39506
#
#       feature class feature code country code   cc2  admin1 code  admin2 code  \
# 10097             P        PPLA2           NO  None         21.0       5001.0
#
#        admin3 code  admin4 code  population  elevation  dem     timezone  \
# 10097          NaN          NaN      147139        NaN   18  Europe/Oslo
#
#       modification date
# 10097        2019-09-05

# %%
geo[geo.alternatenames.fillna('').str.contains('Bergen')]
# Out:
#         geonameid                name           asciiname  \
# 100213    9069155          Bergeneset          Bergeneset
# 102235    9071189           Bergenget           Bergenget
# 10339     3134126        Tovdalsberga        Tovdalsberga
# 105831    9135735           Bergenipa           Bergenipa
# 107973    9137877       Longe Bergene       Longe Bergene
# 112882    9142790           Bergenden           Bergenden
# 115365    9145311      Slette Bergene      Slette Bergene
# 120447    9150413       Bergenussøyin       Bergenussoyin
# 123936    9153903           Bergenden           Bergenden
# 137309    9201608      Bergenn-gutune      Bergenn-gutune
# 155691    9220262          Bergenåsen          Bergenasen
# 157204    9221779      Bergendalsheia      Bergendalsheia
# 158120    9222705      Bergen Station      Bergen Station
# 162259    9227135         Bergengåsen         Bergengasen
# 166003    9230987         Bergenatten         Bergenatten
# ...

# %%
geo[geo.name=='Bergen']
# Out:
#         geonameid    name asciiname  \
# 342881    9463139  Bergen    Bergen
# 37618     3161732  Bergen    Bergen
# 37619     3161733  Bergen    Bergen
#
#                                            alternatenames  latitude  \
# 342881                                             Bergen  59.61085
# 37618   BGO,Bargen,Berga,Bergen,Bergen (Hordaland Fylk...  60.39299
# 37619   Bargen,Berga,Bergen,Bergen osh,Bergena,Bergena...  60.39200
#
#         longitude feature class feature code country code   cc2  admin1 code  \
# 342881    8.92091             S          FRM           NO  None         38.0
# 37618     5.32415             P         PPLA           NO  None         46.0
# 37619     5.32800             A         ADM2           NO  None         46.0
#
#         admin2 code  admin3 code  admin4 code  population  elevation  dem  \
# 342881       3819.0          NaN          NaN           0        NaN  138
# 37618        4601.0          NaN          NaN      213585        NaN   20
# ...

# %%
from dhlab.nbtext import ner
